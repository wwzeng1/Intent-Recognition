# %% [markdown]
# # LSTM model for predicting intent based on phonemes

# %%
# !nvidia-smi
# !git clone https://github.com/wwzeng1/Intent-Recognition.git
# Out:
# Sat May  8 17:00:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Cloning into 'Intent-Recognition'...
# remote: Enumerating objects: 190, done.
# remote: Counting objects: 100% (190/190), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 190 (delta 92), reused 60 (delta 20), pack-reused 0
# Receiving objects: 100% (190/190), 10.51 MiB | 4.58 MiB/s, done.
# Resolving deltas: 100% (92/92), done.

# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import time

import pandas as pd
import torch 
import torch.nn as nn
import torch.optim as optim
from google.colab import files

from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torch.utils.data import random_split
from more_itertools import sort_together

# %% [markdown]
# ## Hyperparams

# %%
all_phones = ['I', 'a', 'aː', 'ã', 'ă', 'b', 'bʲ', 'bʲj', 'bʷ', 'bʼ', 'bː', 'b̞',
              'b̤', 'b̥', 'c', 'd', 'dʒ', 'dʲ', 'dː', 'd̚', 'd̥', 'd̪', 'd̯', 'd͡z', 
              'd͡ʑ', 'd͡ʒ', 'd͡ʒː', 'd͡ʒ̤', 'e', 'eː', 'e̞', 'f', 'fʲ', 'fʷ', 'fː', 
              'g', 'gʲ', 'gʲj', 'gʷ', 'gː', 'h', 'hʷ', 'i', 'ij', 'iː', 'i̞', 
              'i̥', 'i̯', 'j', 'k', 'kx', 'kʰ', 'kʲ', 'kʲj', 'kʷ', 'kʷʼ', 'kʼ', 
              'kː', 'k̟ʲ', 'k̟̚', 'k͡p̚', 'l', 'lʲ', 'lː', 'l̪', 'm', 'mʲ', 'mʲj', 
              'mʷ', 'mː', 'n', 'nj', 'nʲ', 'nː', 'n̪', 'n̺', 'o', 'oː', 'o̞', 'o̥', 
              'p', 'pf', 'pʰ', 'pʲ', 'pʲj', 'pʷ', 'pʷʼ', 'pʼ', 'pː', 'p̚', 'q', 
              'r', 'rː', 's', 'sʲ', 'sʼ', 'sː', 's̪', 't', 'ts', 'tsʰ', 'tɕ', 
              'tɕʰ', 'tʂ', 'tʂʰ', 'tʃ', 'tʰ', 'tʲ', 'tʷʼ', 'tʼ', 'tː', 't̚', 
              't̪', 't̪ʰ', 't̪̚', 't͡s', 't͡sʼ', 't͡ɕ', 't͡ɬ', 't͡ʃ', 't͡ʃʲ', 't͡ʃʼ', 't͡ʃː',
              'u', 'uə', 'uː', 'u͡w', 'v', 'vʲ', 'vʷ', 'vː', 'v̞', 'v̞ʲ', 'w', 'x',
              'x̟ʲ', 'y', 'z', 'zj', 'zʲ', 'z̪', 'ä', 'æ', 'ç', 'çj', 'ð', 'ø', 'ŋ',
              'ŋ̟', 'ŋ͡m', 'œ', 'œ̃', 'ɐ', 'ɐ̞', 'ɑ', 'ɑ̱', 'ɒ', 'ɓ', 'ɔ', 'ɔ̃', 'ɕ', 
              'ɕː', 'ɖ̤', 'ɗ', 'ə', 'ɛ', 'ɛ̃', 'ɟ', 'ɡ', 'ɡʲ', 'ɡ̤', 'ɡ̥', 'ɣ', 'ɣj',
              'ɤ', 'ɤɐ̞', 'ɤ̆', 'ɥ', 'ɦ', 'ɨ', 'ɪ', 'ɫ', 'ɯ', 'ɯ̟', 'ɯ̥', 'ɰ', 'ɱ', 
              'ɲ', 'ɳ', 'ɴ', 'ɵ', 'ɸ', 'ɹ', 'ɹ̩', 'ɻ', 'ɻ̩', 'ɽ', 'ɾ', 'ɾj', 'ɾʲ',
              'ɾ̠', 'ʀ', 'ʁ', 'ʁ̝', 'ʂ', 'ʃ', 'ʃʲː', 'ʃ͡ɣ', 'ʈ', 'ʉ̞', 'ʊ', 'ʋ', 'ʋʲ',
              'ʌ', 'ʎ', 'ʏ', 'ʐ', 'ʑ', 'ʒ', 'ʒ͡ɣ', 'ʔ', 'ʝ', 'ː', 'β', 'β̞', 'θ', 
              'χ', 'ә', 'ḁ']
phone2index = {'':0}
for idx in range(0, len(all_phones)):
  phone = all_phones[idx]
  phone2index[phone] = idx + 1

# %%
# !cp /content/Intent-Recognition/Code/raw_corpus.npy .
# !cp /content/Intent-Recognition/Dutch/grabo_train_data.npy .
# !cp /content/Intent-Recognition/Dutch/grabo_train_labels.npy .
# !cp /content/Intent-Recognition/Dutch/grabo_dev_data.npy .
# !cp /content/Intent-Recognition/Dutch/grabo_dev_labels.npy .
# !cp /content/Intent-Recognition/Dutch/grabo_test_data.npy .
# !cp /content/Intent-Recognition/Dutch/grabo_test_labels.npy .

# %% [markdown]
# ## Dataset and Collate

# %%
X_pretrain = np.load('raw_corpus.npy', allow_pickle=True)
X_pretrain = np.vectorize(phone2index.get)(X_pretrain)
train_data = np.load('grabo_train_data.npy', allow_pickle=True)
train_labels = np.load('grabo_train_labels.npy', allow_pickle=True)
dev_data = np.load('grabo_dev_data.npy', allow_pickle=True)
dev_labels = np.load('grabo_dev_labels.npy', allow_pickle=True)
test_data = np.load('grabo_test_data.npy', allow_pickle=True)
test_labels = np.load('grabo_test_labels.npy', allow_pickle=True)

# %%
class PretrainDataset(Dataset):
    def __init__(self, X, seq_len, num_phones):
        self.X = X
        self.length = len(X)
        self.seq_len = seq_len
        self.total_len = seq_len + 2
        self.num_phones = num_phones
        self.index_mapping = [split for split in range(0, self.length, self.total_len)]
        self.index_mapping = self.index_mapping[:-2] # account for offset and incomplete sequences

    def __len__(self):
        return len(self.index_mapping)

    def __getitem__(self, item):
        # sample offset so we don't get the same items each time
        offset = np.random.randint(low=0, high=self.seq_len)
        start = self.index_mapping[item] + offset
        end = start + self.seq_len
        x = self.X[start+1:end+1]
        y1 = self.X[start]
        y2 = self.X[end + 1]
        x, y1, y2 = torch.Tensor(x), y1, y2
        x = x.long()
        return x, y1, y2
def pretrain_collate(batch):
    data = [x[0] for x in batch]
    prev_labels = [x[1] for x in batch]
    next_labels = [x[2] for x in batch]
    padded_data = pad_sequence(data, batch_first=True, padding_value=0.0) 
    data_lens = torch.from_numpy(np.array([len(x) for x in data]))

    return padded_data, data_lens, prev_labels, next_labels

# %% [markdown]
# ## Model

# %%
class CNN_LSTM(nn.Module):
    def __init__(self, in_features, num_classes, pretrain_classes, pretrain = False):
        super().__init__()
        
        self.dropout = nn.Dropout(p=0.6)
        embedding_dim = 128
        self.embedding = nn.Embedding(in_features, embedding_dim)
        self.conv1 = nn.Conv1d(embedding_dim, 128, kernel_size=3, stride=1, padding=1, bias=True)
        self.conv2 = nn.Conv1d(embedding_dim, 128, kernel_size=5, stride=1, padding=2, bias=True)
        
        self.bn1 = nn.BatchNorm1d(128)
        self.bn2 = nn.BatchNorm1d(128)

        self.lstm1 = nn.LSTM(input_size = 256, hidden_size = 128, num_layers = 6, batch_first = True,
                       bidirectional = True)
        
        # returns the final outputs
        self.lin1 = nn.Linear(1536, 256)
        self.relu = nn.ReLU()
        self.lin_out = nn.Linear(256, num_classes)
        
        self.pretrain_fwd = nn.Linear(128, 256)
        self.pretrain_bwd = nn.Linear(128, 256)
        self.pretrain_out = nn.Linear(256, pretrain_classes)

    def forward(self, x, x_lens, mode):
        # input is B, T, in_features
        x = self.embedding(x)
        x = x.permute(0, 2, 1)
        # x is B, embedding_dim, T
        out1 = self.conv1(x) # out1 is B, H, T
        out1 = self.bn1(out1)
        out2 = self.conv2(x) # out2 is B, H, T
        out2 = self.bn2(out2)
        # out is B, 2H, T
        out = torch.cat((out1, out2), dim = 1)
        if mode == 'train':
          out = self.dropout(out)
        out = out.permute(0, 2, 1) # out is B, T, H
        out = pack_padded_sequence(out, x_lens.cpu(), batch_first = True, \
          enforce_sorted=False)
        out, (hidden, cell) = self.lstm1(out)
        # will be batch_size, num_classes
        B = hidden.shape[2]
        if mode == 'pretrain':
          out, out_lens = pad_packed_sequence(out)
          hiddens = out.view(-1, B, 2, 128)
          prev_word = hiddens[0, :, 1, :]
          out_prev = self.pretrain_bwd(prev_word)
          out_prev = self.dropout(out_prev)
          out_prev = self.relu(out_prev)
          out_prev = self.pretrain_out(out_prev)
          next_word = hiddens[-1, :, 0, :]
          out_next = self.pretrain_fwd(next_word)
          out_next = self.dropout(out_next)
          out_next = self.relu(out_next)
          out_next = self.pretrain_out(out_next)
          return out_prev, out_next
        hidden = hidden.permute(1, 0, 2) # (batch, L*D, hidden_size)
        hidden = torch.flatten(hidden, start_dim = 1)
        out = self.lin1(hidden)
        if mode == 'train':
          out = self.dropout(out)
        out = self.relu(out)
        out = self.lin_out(out)
        return out

# %%
batch_size = 128
num_workers = 8
seq_len = 64
phoneme_num = len(all_phones)
pretrain_dataset = PretrainDataset(X_pretrain, seq_len, phoneme_num)
pretrain_loader = DataLoader(pretrain_dataset, batch_size = batch_size, shuffle = True,
                            collate_fn = pretrain_collate, num_workers = num_workers)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
# Pretraining hyperparameters
actions_num = 36
num_epochs = 250

learning_rate = 1e-4
weight_decay = 5e-5

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = CNN_LSTM(phoneme_num, actions_num, phoneme_num, pretrain = True)
network = network.to(device)

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(network.parameters(), lr = learning_rate, weight_decay=weight_decay)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, \
  patience=10, threshold=0.0001, threshold_mode='rel', cooldown=10, min_lr=0, eps=1e-08, verbose=True)

# %%
for epoch in range(num_epochs):
    
    # Pretrain
    network.train()
    correct = 0.0
    total = 0
    avg_loss = 0.0
    total_bwd_perplexity = 0.0
    total_fwd_perplexity = 0.0
    for batch_num, (x, x_lens, prev_labels, next_labels) in enumerate(pretrain_loader):
        optimizer.zero_grad()
        prev_labels = torch.Tensor(prev_labels)
        next_labels = torch.Tensor(next_labels)
        x, x_lens, prev_labels, next_labels = x.to(device), x_lens.to(device), prev_labels.to(device), next_labels.to(device)
        prev_out, next_out = network(x, x_lens, 'pretrain')

        prev_loss = criterion(prev_out, prev_labels.long())
        next_loss = criterion(next_out, next_labels.long())
        loss = prev_loss + next_loss
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()
        backward_perplexity = torch.exp(prev_loss)
        forward_perplexity = torch.exp(next_loss)
        total_bwd_perplexity += backward_perplexity.item()
        total_fwd_perplexity += forward_perplexity.item()

        prev_pred = torch.argmax(prev_out, dim = 1).cpu().numpy()
        prev_true = prev_labels.cpu().numpy()
        correct += np.sum(prev_pred == prev_true)
        next_pred = torch.argmax(next_out, dim = 1).cpu().numpy()
        next_true = next_labels.cpu().numpy()
        correct += np.sum(next_pred == next_true)
        total += batch_size * 2 # predicting both previous and next
        if batch_num % 50 == 0:
          print("BATCH NUM:", batch_num)
          print("BATCH LOSS:", loss.item())
          print("FORWARD PERPLEXITY:", forward_perplexity.item())
          print("BACKWARD PERPLEXITY:", backward_perplexity.item())

    print("EPOCH: ", epoch)
    print("LOSS: ", avg_loss / batch_num)
    print("TRAIN ACC: ", correct / total)
    print("AVG BWD PERPLEXITY:", total_bwd_perplexity / batch_num)
    print("AVG FWD PERPLEXITY:", total_fwd_perplexity / batch_num)


    scheduler.step(avg_loss)

# %%
from google.colab import files
torch.save(network.state_dict(), "pretrained_dutch.pt")
files.download('pretrained_dutch.pt')

# %% [markdown]
# ##Training the Model

# %%
from google.colab import files
files.upload()

# %%
dev_data = [item for item in dev_data if len(item) != 0]
min([len(item) for item in dev_data])
# Out:
# 3

# %%
class PhonesDataset(Dataset):
  def __init__(self, data, labels, num_phones, num_classes, mode="Train"):
    self.X = data
    self.Y = labels
    self.num_phones = num_phones
    self.num_classes = num_classes
  def __len__(self):
      return len(self.X)
  def __getitem__(self, idx):
      x = self.X[idx]
      y = self.Y[idx]
      x = np.vectorize(phone2index.get)(x)
      x = torch.Tensor(x).long()
      return x, y
def my_collate_fn(batch):
    x = [x_i for (x_i, _) in batch]
    y = [y_i for (_, y_i) in batch]
    x_len = [len(x_i) for x_i in x]
    
    x_len, x, y = sort_together([x_len, x, y], reverse=True)
    x_len, x, y = list(x_len), list(x), list(y)

    x_padded = torch.nn.utils.rnn.pad_sequence(x, batch_first = True)
    x_len = torch.Tensor(x_len)

    return x_padded, y, x_len

# %%
batch_size = 8 # decreasing this from 128 -> 16 helped
train_dataset = PhonesDataset(train_data, train_labels, phoneme_num, actions_num, mode="Train")
train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True, num_workers = num_workers, collate_fn = my_collate_fn)
dev_dataset = PhonesDataset(dev_data, dev_labels, phoneme_num, actions_num, mode="Valid")
dev_loader = DataLoader(dev_dataset, batch_size = batch_size, shuffle = True, num_workers = num_workers, collate_fn = my_collate_fn)
test_dataset = PhonesDataset(test_data, test_labels, phoneme_num, actions_num, mode="Test")
test_loader = DataLoader(test_dataset, batch_size = batch_size, shuffle = False, num_workers = num_workers, collate_fn = my_collate_fn)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
# Pretrained Model hyperparameters
actions_num = 36
num_epochs = 40

learning_rate = 1e-3
weight_decay = 5e-5

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = CNN_LSTM(phoneme_num, actions_num, phoneme_num, pretrain = True)
network = network.to(device)
network.load_state_dict(torch.load('/content/pretrained_dutch.pt'))
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(network.parameters(), lr = learning_rate, weight_decay=weight_decay)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, \
  patience=3, threshold=0.0001, threshold_mode='rel', cooldown=3, min_lr=0, eps=1e-08, verbose=True)

# %%
for epoch in range(num_epochs):
    # Train
    network.train()
    correct = 0.0
    total = 0
    avg_loss = 0.0
    for batch_num, (x, y, x_len) in enumerate(train_loader):
        optimizer.zero_grad()
        y = torch.Tensor(y)
        x, y = x.to(device), y.to(device)
        out = network(x, x_len, 'train')
        loss = criterion(out, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()
        pred = torch.argmax(out, dim = 1).cpu().numpy()
        true = y.cpu().numpy()
        correct += np.sum(pred == true)
        total += batch_size
        if batch_num % 10 == 0:
          print("BATCH NUM:", batch_num)
          print("BATCH LOSS:", loss.item())

    print("EPOCH: ", epoch)
    print("LOSS: ", avg_loss / batch_num)
    print("TRAIN ACC: ", correct / total)
    scheduler.step(avg_loss)
    correct = 0.0
    total = 0
    avg_loss = 0.0
    network.eval()
    with torch.no_grad():
      for batch_num, (x, y, x_len) in enumerate(dev_loader):
          y = torch.Tensor(y)
          x, y = x.to(device), y.to(device)
          out = network(x, x_len, 'dev')
          loss = criterion(out, y.long())
          avg_loss += loss.item()
          pred = torch.argmax(out, dim = 1).cpu().numpy()
          true = y.cpu().numpy()
          correct += np.sum(pred == true)
          total += batch_size
    print("EPOCH: ", epoch)
    print("LOSS: ", avg_loss / batch_num)
    print("VALID ACC: ", correct / total)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# BATCH NUM: 0
# BATCH LOSS: 3.590276002883911
# BATCH NUM: 10
# BATCH LOSS: 3.8581855297088623
# BATCH NUM: 20
# BATCH LOSS: 3.7033214569091797
# BATCH NUM: 30
# BATCH LOSS: 3.659391403198242
# BATCH NUM: 40
# BATCH LOSS: 3.4339118003845215
# BATCH NUM: 50
# BATCH LOSS: 3.46943998336792
# BATCH NUM: 60
# BATCH LOSS: 3.7407004833221436
# BATCH NUM: 70
# BATCH LOSS: 3.522886276245117
# BATCH NUM: 80
# BATCH LOSS: 3.5160555839538574
# BATCH NUM: 90
# BATCH LOSS: 3.518364906311035
# BATCH NUM: 100
# BATCH LOSS: 3.4357845783233643
# BATCH NUM: 110
# BATCH LOSS: 3.6865665912628174
# BATCH NUM: 120
# BATCH LOSS: 3.4749069213867188
# BATCH NUM: 130
# BATCH LOSS: 2.811558723449707
# BATCH NUM: 140
# BATCH LOSS: 3.58172345161438
# BATCH NUM: 150
# BATCH LOSS: 3.3634557723999023
# BATCH NUM: 160
# BATCH LOSS: 3.490199565887451
# BATCH NUM: 170
# BATCH LOSS: 3.372067928314209
# BATCH NUM: 180
# BATCH LOSS: 3.1473910808563232
# BATCH NUM: 190
# BATCH LOSS: 3.2416093349456787
# BATCH NUM: 200
# BATCH LOSS: 2.7390081882476807
# BATCH NUM: 210
# BATCH LOSS: 3.428964138031006
# BATCH NUM: 220
# BATCH LOSS: 3.609992742538452
# BATCH NUM: 230
# BATCH LOSS: 3.285053253173828
# BATCH NUM: 240
# BATCH LOSS: 3.2560954093933105
# BATCH NUM: 250
# BATCH LOSS: 3.106936454772949
# BATCH NUM: 260
# BATCH LOSS: 2.4555342197418213
# BATCH NUM: 270
# BATCH LOSS: 2.875530242919922
# BATCH NUM: 280
# BATCH LOSS: 2.872725009918213
# BATCH NUM: 290
# BATCH LOSS: 2.5366179943084717
# BATCH NUM: 300
# BATCH LOSS: 2.8202297687530518
# BATCH NUM: 310
# BATCH LOSS: 3.3045616149902344
# BATCH NUM: 320
# BATCH LOSS: 3.0447888374328613
# BATCH NUM: 330
# BATCH LOSS: 2.647953510284424
# BATCH NUM: 340
# BATCH LOSS: 2.805666923522949
# BATCH NUM: 350
# BATCH LOSS: 2.547024726867676
# BATCH NUM: 360
# BATCH LOSS: 2.866771697998047
# BATCH NUM: 370
# BATCH LOSS: 2.579514980316162
# BATCH NUM: 380
# BATCH LOSS: 3.164797067642212
# BATCH NUM: 390
# BATCH LOSS: 2.6457595825195312
# BATCH NUM: 400
# BATCH LOSS: 2.6043360233306885
# BATCH NUM: 410
# BATCH LOSS: 2.46596360206604
# BATCH NUM: 420
# BATCH LOSS: 2.6615443229675293
# BATCH NUM: 430
# BATCH LOSS: 1.4986426830291748
# BATCH NUM: 440
# BATCH LOSS: 2.7918825149536133
# BATCH NUM: 450
# BATCH LOSS: 2.0322110652923584
# EPOCH:  0
# LOSS:  3.033972875012292
# TRAIN ACC:  0.14523281596452328
# EPOCH:  0
# LOSS:  2.069994438414606
# VALID ACC:  0.4325
# BATCH NUM: 0
# BATCH LOSS: 3.1278600692749023
# BATCH NUM: 10
# BATCH LOSS: 1.881725549697876
# BATCH NUM: 20
# BATCH LOSS: 2.415954113006592
# BATCH NUM: 30
# BATCH LOSS: 3.1130306720733643
# BATCH NUM: 40
# BATCH LOSS: 1.4074866771697998
# BATCH NUM: 50
# BATCH LOSS: 1.756471037864685
# BATCH NUM: 60
# BATCH LOSS: 2.677737236022949
# BATCH NUM: 70
# BATCH LOSS: 1.6228907108306885
# BATCH NUM: 80
# BATCH LOSS: 2.378807783126831
# BATCH NUM: 90
# BATCH LOSS: 1.8238708972930908
# BATCH NUM: 100
# BATCH LOSS: 2.2627978324890137
# BATCH NUM: 110
# BATCH LOSS: 1.851259708404541
# BATCH NUM: 120
# BATCH LOSS: 2.193342447280884
# BATCH NUM: 130
# BATCH LOSS: 1.9455626010894775
# BATCH NUM: 140
# BATCH LOSS: 1.8093347549438477
# BATCH NUM: 150
# BATCH LOSS: 2.209390640258789
# BATCH NUM: 160
# BATCH LOSS: 1.8175644874572754
# BATCH NUM: 170
# BATCH LOSS: 2.0888493061065674
# BATCH NUM: 180
# BATCH LOSS: 2.615737199783325
# BATCH NUM: 190
# BATCH LOSS: 2.1313374042510986
# BATCH NUM: 200
# BATCH LOSS: 1.5899766683578491
# BATCH NUM: 210
# BATCH LOSS: 1.7517122030258179
# BATCH NUM: 220
# BATCH LOSS: 2.2348852157592773
# BATCH NUM: 230
# BATCH LOSS: 1.7243974208831787
# BATCH NUM: 240
# BATCH LOSS: 1.6397067308425903
# BATCH NUM: 250
# BATCH LOSS: 2.2743797302246094
# BATCH NUM: 260
# BATCH LOSS: 1.7559176683425903
# BATCH NUM: 270
# BATCH LOSS: 1.0979958772659302
# BATCH NUM: 280
# BATCH LOSS: 2.563441038131714
# BATCH NUM: 290
# BATCH LOSS: 1.3375319242477417
# BATCH NUM: 300
# BATCH LOSS: 2.2247931957244873
# BATCH NUM: 310
# BATCH LOSS: 1.5709643363952637
# BATCH NUM: 320
# BATCH LOSS: 1.7553764581680298
# BATCH NUM: 330
# BATCH LOSS: 1.1589998006820679
# BATCH NUM: 340
# BATCH LOSS: 1.7873334884643555
# BATCH NUM: 350
# BATCH LOSS: 1.9312225580215454
# BATCH NUM: 360
# BATCH LOSS: 1.7993062734603882
# BATCH NUM: 370
# BATCH LOSS: 1.3779217004776
# BATCH NUM: 380
# BATCH LOSS: 1.786491870880127
# BATCH NUM: 390
# BATCH LOSS: 1.6651086807250977
# BATCH NUM: 400
# BATCH LOSS: 1.8553296327590942
# BATCH NUM: 410
# BATCH LOSS: 1.879058837890625
# BATCH NUM: 420
# BATCH LOSS: 1.9553097486495972
# BATCH NUM: 430
# BATCH LOSS: 0.8826152086257935
# BATCH NUM: 440
# BATCH LOSS: 1.6509032249450684
# BATCH NUM: 450
# BATCH LOSS: 2.6464269161224365
# EPOCH:  1
# LOSS:  1.7753052266438802
# TRAIN ACC:  0.4259977827050998
# EPOCH:  1
# LOSS:  1.6921859515593356
# VALID ACC:  0.5633333333333334
# BATCH NUM: 0
# BATCH LOSS: 0.9418870210647583
# BATCH NUM: 10
# BATCH LOSS: 0.5229831337928772
# BATCH NUM: 20
# BATCH LOSS: 1.2776029109954834
# BATCH NUM: 30
# BATCH LOSS: 1.0491963624954224
# BATCH NUM: 40
# BATCH LOSS: 1.2579231262207031
# BATCH NUM: 50
# BATCH LOSS: 1.0137922763824463
# BATCH NUM: 60
# BATCH LOSS: 1.5087873935699463
# BATCH NUM: 70
# BATCH LOSS: 0.9827995896339417
# BATCH NUM: 80
# BATCH LOSS: 0.9429967403411865
# BATCH NUM: 90
# BATCH LOSS: 1.0872207880020142
# BATCH NUM: 100
# BATCH LOSS: 1.4583419561386108
# BATCH NUM: 110
# BATCH LOSS: 1.4084904193878174
# BATCH NUM: 120
# BATCH LOSS: 1.1986228227615356
# BATCH NUM: 130
# BATCH LOSS: 0.7560144066810608
# BATCH NUM: 140
# BATCH LOSS: 0.6221234202384949
# BATCH NUM: 150
# BATCH LOSS: 1.669468641281128
# BATCH NUM: 160
# BATCH LOSS: 1.279159665107727
# BATCH NUM: 170
# BATCH LOSS: 2.5057051181793213
# BATCH NUM: 180
# BATCH LOSS: 0.734397292137146
# BATCH NUM: 190
# BATCH LOSS: 2.0488779544830322
# BATCH NUM: 200
# BATCH LOSS: 1.5304811000823975
# BATCH NUM: 210
# BATCH LOSS: 0.5389880537986755
# BATCH NUM: 220
# BATCH LOSS: 1.0614985227584839
# BATCH NUM: 230
# BATCH LOSS: 1.5534871816635132
# BATCH NUM: 240
# BATCH LOSS: 1.1508231163024902
# BATCH NUM: 250
# BATCH LOSS: 0.5511156916618347
# BATCH NUM: 260
# BATCH LOSS: 1.2472871541976929
# BATCH NUM: 270
# BATCH LOSS: 1.2167752981185913
# BATCH NUM: 280
# BATCH LOSS: 1.5270259380340576
# BATCH NUM: 290
# BATCH LOSS: 1.2345597743988037
# BATCH NUM: 300
# BATCH LOSS: 1.1802140474319458
# BATCH NUM: 310
# BATCH LOSS: 0.7101238965988159
# BATCH NUM: 320
# BATCH LOSS: 2.0526154041290283
# BATCH NUM: 330
# BATCH LOSS: 2.507004737854004
# BATCH NUM: 340
# BATCH LOSS: 1.46370530128479
# BATCH NUM: 350
# BATCH LOSS: 1.0318127870559692
# BATCH NUM: 360
# BATCH LOSS: 1.378282904624939
# BATCH NUM: 370
# BATCH LOSS: 1.21035897731781
# BATCH NUM: 380
# BATCH LOSS: 0.9964491724967957
# BATCH NUM: 390
# BATCH LOSS: 1.337742567062378
# BATCH NUM: 400
# BATCH LOSS: 1.055188536643982
# BATCH NUM: 410
# BATCH LOSS: 1.0977061986923218
# BATCH NUM: 420
# BATCH LOSS: 1.6231105327606201
# BATCH NUM: 430
# BATCH LOSS: 1.301246166229248
# BATCH NUM: 440
# BATCH LOSS: 0.8412741422653198
# BATCH NUM: 450
# BATCH LOSS: 0.49608203768730164
# EPOCH:  2
# LOSS:  1.219491624236107
# TRAIN ACC:  0.5942350332594235
# EPOCH:  2
# LOSS:  1.5689831139557313
# VALID ACC:  0.6783333333333333
# BATCH NUM: 0
# BATCH LOSS: 1.2584192752838135
# BATCH NUM: 10
# BATCH LOSS: 0.9781519174575806
# BATCH NUM: 20
# BATCH LOSS: 1.4159135818481445
# BATCH NUM: 30
# BATCH LOSS: 0.1986577808856964
# BATCH NUM: 40
# BATCH LOSS: 0.6474905610084534
# BATCH NUM: 50
# BATCH LOSS: 0.527168869972229
# BATCH NUM: 60
# BATCH LOSS: 0.21236249804496765
# BATCH NUM: 70
# BATCH LOSS: 0.5916411280632019
# BATCH NUM: 80
# BATCH LOSS: 0.9406079053878784
# BATCH NUM: 90
# BATCH LOSS: 0.5823521614074707
# BATCH NUM: 100
# BATCH LOSS: 0.9813244342803955
# BATCH NUM: 110
# BATCH LOSS: 0.6620643734931946
# BATCH NUM: 120
# BATCH LOSS: 1.3845092058181763
# BATCH NUM: 130
# BATCH LOSS: 0.7214868068695068
# BATCH NUM: 140
# BATCH LOSS: 1.9006550312042236
# BATCH NUM: 150
# BATCH LOSS: 0.34121328592300415
# BATCH NUM: 160
# BATCH LOSS: 1.2536083459854126
# BATCH NUM: 170
# BATCH LOSS: 0.5870011448860168
# BATCH NUM: 180
# BATCH LOSS: 0.39302659034729004
# BATCH NUM: 190
# BATCH LOSS: 1.4965424537658691
# BATCH NUM: 200
# BATCH LOSS: 0.21200108528137207
# BATCH NUM: 210
# BATCH LOSS: 0.9617425203323364
# BATCH NUM: 220
# BATCH LOSS: 0.14486287534236908
# BATCH NUM: 230
# BATCH LOSS: 0.835658848285675
# BATCH NUM: 240
# BATCH LOSS: 0.8630912899971008
# BATCH NUM: 250
# BATCH LOSS: 1.2281875610351562
# BATCH NUM: 260
# BATCH LOSS: 0.9192154407501221
# BATCH NUM: 270
# BATCH LOSS: 1.168823003768921
# BATCH NUM: 280
# BATCH LOSS: 0.5988544225692749
# BATCH NUM: 290
# BATCH LOSS: 1.1026676893234253
# BATCH NUM: 300
# BATCH LOSS: 0.6340757012367249
# BATCH NUM: 310
# BATCH LOSS: 1.0548127889633179
# BATCH NUM: 320
# BATCH LOSS: 0.8521795868873596
# BATCH NUM: 330
# BATCH LOSS: 1.1425725221633911
# BATCH NUM: 340
# BATCH LOSS: 0.8371294140815735
# BATCH NUM: 350
# BATCH LOSS: 1.2461904287338257
# BATCH NUM: 360
# BATCH LOSS: 1.1929270029067993
# BATCH NUM: 370
# BATCH LOSS: 0.9148698449134827
# BATCH NUM: 380
# BATCH LOSS: 1.7501466274261475
# BATCH NUM: 390
# BATCH LOSS: 1.1127126216888428
# BATCH NUM: 400
# BATCH LOSS: 1.559819221496582
# BATCH NUM: 410
# BATCH LOSS: 0.5136151909828186
# BATCH NUM: 420
# BATCH LOSS: 0.9747702479362488
# BATCH NUM: 430
# BATCH LOSS: 0.3321895897388458
# BATCH NUM: 440
# BATCH LOSS: 0.3365231156349182
# BATCH NUM: 450
# BATCH LOSS: 0.8529800772666931
# EPOCH:  3
# LOSS:  0.9331416415050626
# TRAIN ACC:  0.6965077605321508
# EPOCH:  3
# LOSS:  1.610467663884863
# VALID ACC:  0.7275
# BATCH NUM: 0
# BATCH LOSS: 0.7107093334197998
# BATCH NUM: 10
# BATCH LOSS: 0.8208506107330322
# BATCH NUM: 20
# BATCH LOSS: 0.5423784852027893
# BATCH NUM: 30
# BATCH LOSS: 0.6283060312271118
# BATCH NUM: 40
# BATCH LOSS: 0.29610300064086914
# BATCH NUM: 50
# BATCH LOSS: 0.8990163207054138
# BATCH NUM: 60
# BATCH LOSS: 0.2705196440219879
# BATCH NUM: 70
# BATCH LOSS: 0.23649907112121582
# BATCH NUM: 80
# BATCH LOSS: 1.058537483215332
# BATCH NUM: 90
# BATCH LOSS: 0.3531629145145416
# BATCH NUM: 100
# BATCH LOSS: 0.5608053207397461
# BATCH NUM: 110
# BATCH LOSS: 1.3910402059555054
# BATCH NUM: 120
# BATCH LOSS: 1.0870460271835327
# BATCH NUM: 130
# BATCH LOSS: 0.7636244297027588
# BATCH NUM: 140
# BATCH LOSS: 0.6029350161552429
# BATCH NUM: 150
# BATCH LOSS: 1.0990134477615356
# BATCH NUM: 160
# BATCH LOSS: 0.10110708326101303
# BATCH NUM: 170
# BATCH LOSS: 0.27881863713264465
# BATCH NUM: 180
# BATCH LOSS: 1.7081687450408936
# BATCH NUM: 190
# BATCH LOSS: 0.24507540464401245
# BATCH NUM: 200
# BATCH LOSS: 0.6948782801628113
# BATCH NUM: 210
# BATCH LOSS: 1.098279595375061
# BATCH NUM: 220
# BATCH LOSS: 0.47396284341812134
# BATCH NUM: 230
# BATCH LOSS: 0.4174553155899048
# BATCH NUM: 240
# BATCH LOSS: 1.0157779455184937
# BATCH NUM: 250
# BATCH LOSS: 1.3764548301696777
# BATCH NUM: 260
# BATCH LOSS: 0.12366493046283722
# BATCH NUM: 270
# BATCH LOSS: 1.3397941589355469
# BATCH NUM: 280
# BATCH LOSS: 0.28542038798332214
# BATCH NUM: 290
# BATCH LOSS: 1.225210428237915
# BATCH NUM: 300
# BATCH LOSS: 0.8544002175331116
# BATCH NUM: 310
# BATCH LOSS: 0.9032514691352844
# BATCH NUM: 320
# BATCH LOSS: 1.0678341388702393
# BATCH NUM: 330
# BATCH LOSS: 1.4180940389633179
# BATCH NUM: 340
# BATCH LOSS: 0.7917554974555969
# BATCH NUM: 350
# BATCH LOSS: 0.5003663301467896
# BATCH NUM: 360
# BATCH LOSS: 0.783679723739624
# BATCH NUM: 370
# BATCH LOSS: 0.6841866970062256
# BATCH NUM: 380
# BATCH LOSS: 0.9360459446907043
# BATCH NUM: 390
# BATCH LOSS: 0.38503459095954895
# BATCH NUM: 400
# BATCH LOSS: 1.0628151893615723
# BATCH NUM: 410
# BATCH LOSS: 1.364353895187378
# BATCH NUM: 420
# BATCH LOSS: 0.23236483335494995
# BATCH NUM: 430
# BATCH LOSS: 0.4751453697681427
# BATCH NUM: 440
# BATCH LOSS: 0.8941395878791809
# BATCH NUM: 450
# BATCH LOSS: 1.9706180095672607
# EPOCH:  4
# LOSS:  0.7261101162185272
# TRAIN ACC:  0.7716186252771619
# EPOCH:  4
# LOSS:  1.6794261363953753
# VALID ACC:  0.7491666666666666
# BATCH NUM: 0
# BATCH LOSS: 0.4407719373703003
# BATCH NUM: 10
# BATCH LOSS: 2.0223076343536377
# BATCH NUM: 20
# BATCH LOSS: 0.04424574598670006
# BATCH NUM: 30
# BATCH LOSS: 0.3412938416004181
# BATCH NUM: 40
# BATCH LOSS: 0.8098975419998169
# BATCH NUM: 50
# BATCH LOSS: 0.3325575292110443
# BATCH NUM: 60
# BATCH LOSS: 1.9252212047576904
# BATCH NUM: 70
# BATCH LOSS: 0.3060747981071472
# BATCH NUM: 80
# BATCH LOSS: 0.291971355676651
# BATCH NUM: 90
# BATCH LOSS: 0.23105832934379578
# BATCH NUM: 100
# BATCH LOSS: 0.3850064277648926
# BATCH NUM: 110
# BATCH LOSS: 0.21028824150562286
# BATCH NUM: 120
# BATCH LOSS: 1.2443526983261108
# BATCH NUM: 130
# BATCH LOSS: 0.411582887172699
# BATCH NUM: 140
# BATCH LOSS: 0.23440003395080566
# BATCH NUM: 150
# BATCH LOSS: 0.1923602968454361
# BATCH NUM: 160
# BATCH LOSS: 0.08745186775922775
# BATCH NUM: 170
# BATCH LOSS: 0.8146783113479614
# BATCH NUM: 180
# BATCH LOSS: 0.06232568249106407
# BATCH NUM: 190
# BATCH LOSS: 0.36623430252075195
# BATCH NUM: 200
# BATCH LOSS: 0.7324092984199524
# BATCH NUM: 210
# BATCH LOSS: 0.8825130462646484
# BATCH NUM: 220
# BATCH LOSS: 0.13901694118976593
# BATCH NUM: 230
# BATCH LOSS: 1.1716245412826538
# BATCH NUM: 240
# BATCH LOSS: 0.33251363039016724
# BATCH NUM: 250
# BATCH LOSS: 0.6843482255935669
# BATCH NUM: 260
# BATCH LOSS: 0.31485798954963684
# BATCH NUM: 270
# BATCH LOSS: 0.7525460124015808
# BATCH NUM: 280
# BATCH LOSS: 0.8524125814437866
# BATCH NUM: 290
# BATCH LOSS: 0.6531788110733032
# BATCH NUM: 300
# BATCH LOSS: 0.3487154543399811
# BATCH NUM: 310
# BATCH LOSS: 0.6850985288619995
# BATCH NUM: 320
# BATCH LOSS: 0.27525144815444946
# BATCH NUM: 330
# BATCH LOSS: 0.016413699835538864
# BATCH NUM: 340
# BATCH LOSS: 0.2780458927154541
# BATCH NUM: 350
# BATCH LOSS: 0.5760287642478943
# BATCH NUM: 360
# BATCH LOSS: 1.4847195148468018
# BATCH NUM: 370
# BATCH LOSS: 0.5123177766799927
# BATCH NUM: 380
# BATCH LOSS: 0.6147499084472656
# BATCH NUM: 390
# BATCH LOSS: 0.5997605323791504
# BATCH NUM: 400
# BATCH LOSS: 0.4955160915851593
# BATCH NUM: 410
# BATCH LOSS: 0.7568120956420898
# BATCH NUM: 420
# BATCH LOSS: 0.0980750322341919
# BATCH NUM: 430
# BATCH LOSS: 1.554181694984436
# BATCH NUM: 440
# BATCH LOSS: 0.7236644625663757
# BATCH NUM: 450
# BATCH LOSS: 0.006136116571724415
# EPOCH:  5
# LOSS:  0.5934294733177456
# TRAIN ACC:  0.8048780487804879
# EPOCH:  5
# LOSS:  1.6863280799389886
# VALID ACC:  0.7616666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.29002612829208374
# BATCH NUM: 10
# BATCH LOSS: 0.7364462018013
# BATCH NUM: 20
# BATCH LOSS: 0.3384135067462921
# BATCH NUM: 30
# BATCH LOSS: 0.08619047701358795
# BATCH NUM: 40
# BATCH LOSS: 0.48967698216438293
# BATCH NUM: 50
# BATCH LOSS: 0.467817097902298
# BATCH NUM: 60
# BATCH LOSS: 0.9427852630615234
# BATCH NUM: 70
# BATCH LOSS: 0.38201069831848145
# BATCH NUM: 80
# BATCH LOSS: 1.2518937587738037
# BATCH NUM: 90
# BATCH LOSS: 0.2828254997730255
# BATCH NUM: 100
# BATCH LOSS: 0.19339878857135773
# BATCH NUM: 110
# BATCH LOSS: 0.2856582999229431
# BATCH NUM: 120
# BATCH LOSS: 0.1646014302968979
# BATCH NUM: 130
# BATCH LOSS: 0.590201199054718
# BATCH NUM: 140
# BATCH LOSS: 0.3953690528869629
# BATCH NUM: 150
# BATCH LOSS: 1.119343876838684
# BATCH NUM: 160
# BATCH LOSS: 0.5144777297973633
# BATCH NUM: 170
# BATCH LOSS: 1.0810378789901733
# BATCH NUM: 180
# BATCH LOSS: 0.39704427123069763
# BATCH NUM: 190
# BATCH LOSS: 0.13499683141708374
# BATCH NUM: 200
# BATCH LOSS: 0.21331629157066345
# BATCH NUM: 210
# BATCH LOSS: 0.6316073536872864
# BATCH NUM: 220
# BATCH LOSS: 0.4998059570789337
# BATCH NUM: 230
# BATCH LOSS: 0.11450760066509247
# BATCH NUM: 240
# BATCH LOSS: 0.3528183102607727
# BATCH NUM: 250
# BATCH LOSS: 0.6655943989753723
# BATCH NUM: 260
# BATCH LOSS: 0.5633553266525269
# BATCH NUM: 270
# BATCH LOSS: 0.19721414148807526
# BATCH NUM: 280
# BATCH LOSS: 0.9393627643585205
# BATCH NUM: 290
# BATCH LOSS: 0.448416531085968
# BATCH NUM: 300
# BATCH LOSS: 0.11513596773147583
# BATCH NUM: 310
# BATCH LOSS: 0.5119462013244629
# BATCH NUM: 320
# BATCH LOSS: 0.033506542444229126
# BATCH NUM: 330
# BATCH LOSS: 0.8359871506690979
# BATCH NUM: 340
# BATCH LOSS: 0.37064504623413086
# BATCH NUM: 350
# BATCH LOSS: 0.4561293423175812
# BATCH NUM: 360
# BATCH LOSS: 0.28460389375686646
# BATCH NUM: 370
# BATCH LOSS: 0.0177634134888649
# BATCH NUM: 380
# BATCH LOSS: 0.6487259864807129
# BATCH NUM: 390
# BATCH LOSS: 1.3104206323623657
# BATCH NUM: 400
# BATCH LOSS: 0.47207388281822205
# BATCH NUM: 410
# BATCH LOSS: 0.1892811805009842
# BATCH NUM: 420
# BATCH LOSS: 0.27401652932167053
# BATCH NUM: 430
# BATCH LOSS: 0.41520658135414124
# BATCH NUM: 440
# BATCH LOSS: 0.43223705887794495
# BATCH NUM: 450
# BATCH LOSS: 0.46568894386291504
# EPOCH:  6
# LOSS:  0.48993323127842614
# TRAIN ACC:  0.8489467849223947
# EPOCH:  6
# LOSS:  1.790937919282173
# VALID ACC:  0.7775
# BATCH NUM: 0
# BATCH LOSS: 0.6126253008842468
# BATCH NUM: 10
# BATCH LOSS: 0.07797704637050629
# BATCH NUM: 20
# BATCH LOSS: 0.20685335993766785
# BATCH NUM: 30
# BATCH LOSS: 0.2866673469543457
# BATCH NUM: 40
# BATCH LOSS: 0.5072979927062988
# BATCH NUM: 50
# BATCH LOSS: 0.4639264643192291
# BATCH NUM: 60
# BATCH LOSS: 0.19285301864147186
# BATCH NUM: 70
# BATCH LOSS: 0.04407495632767677
# BATCH NUM: 80
# BATCH LOSS: 0.6190377473831177
# BATCH NUM: 90
# BATCH LOSS: 1.1050007343292236
# BATCH NUM: 100
# BATCH LOSS: 0.665043294429779
# BATCH NUM: 110
# BATCH LOSS: 0.1652301549911499
# BATCH NUM: 120
# BATCH LOSS: 0.03675958514213562
# BATCH NUM: 130
# BATCH LOSS: 0.8982713222503662
# BATCH NUM: 140
# BATCH LOSS: 0.07187869399785995
# BATCH NUM: 150
# BATCH LOSS: 0.2372318059206009
# BATCH NUM: 160
# BATCH LOSS: 0.08538411557674408
# BATCH NUM: 170
# BATCH LOSS: 1.6174927949905396
# BATCH NUM: 180
# BATCH LOSS: 0.2738581597805023
# BATCH NUM: 190
# BATCH LOSS: 0.11329617351293564
# BATCH NUM: 200
# BATCH LOSS: 0.15103112161159515
# BATCH NUM: 210
# BATCH LOSS: 0.17410454154014587
# BATCH NUM: 220
# BATCH LOSS: 0.5665389895439148
# BATCH NUM: 230
# BATCH LOSS: 0.2381674200296402
# BATCH NUM: 240
# BATCH LOSS: 0.6507878303527832
# BATCH NUM: 250
# BATCH LOSS: 1.002706527709961
# BATCH NUM: 260
# BATCH LOSS: 0.09139559417963028
# BATCH NUM: 270
# BATCH LOSS: 0.5710934400558472
# BATCH NUM: 280
# BATCH LOSS: 0.8363215327262878
# BATCH NUM: 290
# BATCH LOSS: 0.6870700120925903
# BATCH NUM: 300
# BATCH LOSS: 0.2894623577594757
# BATCH NUM: 310
# BATCH LOSS: 0.20066724717617035
# BATCH NUM: 320
# BATCH LOSS: 0.03839678689837456
# BATCH NUM: 330
# BATCH LOSS: 0.3999333679676056
# BATCH NUM: 340
# BATCH LOSS: 0.06293503195047379
# BATCH NUM: 350
# BATCH LOSS: 0.3566405475139618
# BATCH NUM: 360
# BATCH LOSS: 1.4776965379714966
# BATCH NUM: 370
# BATCH LOSS: 0.7350553274154663
# BATCH NUM: 380
# BATCH LOSS: 0.15117138624191284
# BATCH NUM: 390
# BATCH LOSS: 0.26037466526031494
# BATCH NUM: 400
# BATCH LOSS: 0.5529212951660156
# BATCH NUM: 410
# BATCH LOSS: 0.04825815558433533
# BATCH NUM: 420
# BATCH LOSS: 0.7199800610542297
# BATCH NUM: 430
# BATCH LOSS: 0.9038185477256775
# BATCH NUM: 440
# BATCH LOSS: 0.1560257077217102
# BATCH NUM: 450
# BATCH LOSS: 0.2087743729352951
# EPOCH:  7
# LOSS:  0.4067555348016322
# TRAIN ACC:  0.8680709534368071
# EPOCH:  7
# LOSS:  1.8676470022542315
# VALID ACC:  0.7866666666666666
# BATCH NUM: 0
# BATCH LOSS: 0.26268190145492554
# BATCH NUM: 10
# BATCH LOSS: 0.8428425192832947
# BATCH NUM: 20
# BATCH LOSS: 0.2977132201194763
# BATCH NUM: 30
# BATCH LOSS: 0.3019722104072571
# BATCH NUM: 40
# BATCH LOSS: 0.21662698686122894
# BATCH NUM: 50
# BATCH LOSS: 0.04334532842040062
# BATCH NUM: 60
# BATCH LOSS: 0.6826590895652771
# BATCH NUM: 70
# BATCH LOSS: 0.045523952692747116
# BATCH NUM: 80
# BATCH LOSS: 0.8445760011672974
# BATCH NUM: 90
# BATCH LOSS: 0.38089853525161743
# BATCH NUM: 100
# BATCH LOSS: 0.3567822575569153
# BATCH NUM: 110
# BATCH LOSS: 0.38019320368766785
# BATCH NUM: 120
# BATCH LOSS: 0.4370710849761963
# BATCH NUM: 130
# BATCH LOSS: 0.40129274129867554
# BATCH NUM: 140
# BATCH LOSS: 0.39582687616348267
# BATCH NUM: 150
# BATCH LOSS: 0.20256954431533813
# BATCH NUM: 160
# BATCH LOSS: 0.11195272207260132
# BATCH NUM: 170
# BATCH LOSS: 0.7825965881347656
# BATCH NUM: 180
# BATCH LOSS: 0.3631955683231354
# BATCH NUM: 190
# BATCH LOSS: 0.28797560930252075
# BATCH NUM: 200
# BATCH LOSS: 1.3515630960464478
# BATCH NUM: 210
# BATCH LOSS: 1.0575119256973267
# BATCH NUM: 220
# BATCH LOSS: 0.9112645983695984
# BATCH NUM: 230
# BATCH LOSS: 0.85662841796875
# BATCH NUM: 240
# BATCH LOSS: 0.04980088397860527
# BATCH NUM: 250
# BATCH LOSS: 0.05758107826113701
# BATCH NUM: 260
# BATCH LOSS: 0.4860455393791199
# BATCH NUM: 270
# BATCH LOSS: 0.13317394256591797
# BATCH NUM: 280
# BATCH LOSS: 0.03818782418966293
# BATCH NUM: 290
# BATCH LOSS: 0.21131977438926697
# BATCH NUM: 300
# BATCH LOSS: 0.24639892578125
# BATCH NUM: 310
# BATCH LOSS: 0.08990869671106339
# BATCH NUM: 320
# BATCH LOSS: 0.3535362184047699
# BATCH NUM: 330
# BATCH LOSS: 0.07612936943769455
# BATCH NUM: 340
# BATCH LOSS: 0.3876801133155823
# BATCH NUM: 350
# BATCH LOSS: 0.17092831432819366
# BATCH NUM: 360
# BATCH LOSS: 0.0043704030103981495
# BATCH NUM: 370
# BATCH LOSS: 0.15750296413898468
# BATCH NUM: 380
# BATCH LOSS: 0.2356516271829605
# BATCH NUM: 390
# BATCH LOSS: 0.11638743430376053
# BATCH NUM: 400
# BATCH LOSS: 0.19841521978378296
# BATCH NUM: 410
# BATCH LOSS: 1.196291446685791
# BATCH NUM: 420
# BATCH LOSS: 0.32511106133461
# BATCH NUM: 430
# BATCH LOSS: 0.21111756563186646
# BATCH NUM: 440
# BATCH LOSS: 0.42959025502204895
# BATCH NUM: 450
# BATCH LOSS: 0.01763998530805111
# EPOCH:  8
# LOSS:  0.3936579227087916
# TRAIN ACC:  0.8691796008869179
# EPOCH:  8
# LOSS:  2.001248133715692
# VALID ACC:  0.7908333333333334
# BATCH NUM: 0
# BATCH LOSS: 0.7809343934059143
# BATCH NUM: 10
# BATCH LOSS: 0.19887082278728485
# BATCH NUM: 20
# BATCH LOSS: 0.8365238904953003
# BATCH NUM: 30
# BATCH LOSS: 0.27514347434043884
# BATCH NUM: 40
# BATCH LOSS: 0.2614026367664337
# BATCH NUM: 50
# BATCH LOSS: 0.1656314730644226
# BATCH NUM: 60
# BATCH LOSS: 0.3995751440525055
# BATCH NUM: 70
# BATCH LOSS: 0.48046132922172546
# BATCH NUM: 80
# BATCH LOSS: 0.12942615151405334
# BATCH NUM: 90
# BATCH LOSS: 0.2123958021402359
# BATCH NUM: 100
# BATCH LOSS: 0.03187805041670799
# BATCH NUM: 110
# BATCH LOSS: 0.10022781789302826
# BATCH NUM: 120
# BATCH LOSS: 0.40831196308135986
# BATCH NUM: 130
# BATCH LOSS: 0.07552993297576904
# BATCH NUM: 140
# BATCH LOSS: 0.0714460015296936
# BATCH NUM: 150
# BATCH LOSS: 0.471224844455719
# BATCH NUM: 160
# BATCH LOSS: 0.030966375023126602
# BATCH NUM: 170
# BATCH LOSS: 0.012533804401755333
# BATCH NUM: 180
# BATCH LOSS: 0.531493067741394
# BATCH NUM: 190
# BATCH LOSS: 0.5411563515663147
# BATCH NUM: 200
# BATCH LOSS: 0.09803792834281921
# BATCH NUM: 210
# BATCH LOSS: 0.15117813646793365
# BATCH NUM: 220
# BATCH LOSS: 0.38532060384750366
# BATCH NUM: 230
# BATCH LOSS: 0.09285341203212738
# BATCH NUM: 240
# BATCH LOSS: 0.5027673244476318
# BATCH NUM: 250
# BATCH LOSS: 0.0700683519244194
# BATCH NUM: 260
# BATCH LOSS: 0.3797772228717804
# BATCH NUM: 270
# BATCH LOSS: 0.6711283326148987
# BATCH NUM: 280
# BATCH LOSS: 0.011193091981112957
# BATCH NUM: 290
# BATCH LOSS: 0.3983951508998871
# BATCH NUM: 300
# BATCH LOSS: 1.186972975730896
# BATCH NUM: 310
# BATCH LOSS: 0.6163983345031738
# BATCH NUM: 320
# BATCH LOSS: 0.36371317505836487
# BATCH NUM: 330
# BATCH LOSS: 0.6957821846008301
# BATCH NUM: 340
# BATCH LOSS: 0.06640689074993134
# BATCH NUM: 350
# BATCH LOSS: 0.16618219017982483
# BATCH NUM: 360
# BATCH LOSS: 0.017306329682469368
# BATCH NUM: 370
# BATCH LOSS: 0.40344855189323425
# BATCH NUM: 380
# BATCH LOSS: 0.19476106762886047
# BATCH NUM: 390
# BATCH LOSS: 0.14358589053153992
# BATCH NUM: 400
# BATCH LOSS: 0.2694683372974396
# BATCH NUM: 410
# BATCH LOSS: 0.46957075595855713
# BATCH NUM: 420
# BATCH LOSS: 0.33072856068611145
# BATCH NUM: 430
# BATCH LOSS: 0.3937293291091919
# BATCH NUM: 440
# BATCH LOSS: 0.20776845514774323
# BATCH NUM: 450
# BATCH LOSS: 0.5622370839118958
# EPOCH:  9
# LOSS:  0.3202435052759635
# TRAIN ACC:  0.9002217294900222
# EPOCH:  9
# LOSS:  2.077074065157361
# VALID ACC:  0.7925
# BATCH NUM: 0
# BATCH LOSS: 0.14810989797115326
# BATCH NUM: 10
# BATCH LOSS: 0.05359465628862381
# BATCH NUM: 20
# BATCH LOSS: 0.1913490891456604
# BATCH NUM: 30
# BATCH LOSS: 0.3402048945426941
# BATCH NUM: 40
# BATCH LOSS: 0.23001909255981445
# BATCH NUM: 50
# BATCH LOSS: 0.14786051213741302
# BATCH NUM: 60
# BATCH LOSS: 0.28885617852211
# BATCH NUM: 70
# BATCH LOSS: 0.09895271807909012
# BATCH NUM: 80
# BATCH LOSS: 0.0557345449924469
# BATCH NUM: 90
# BATCH LOSS: 0.05801989883184433
# BATCH NUM: 100
# BATCH LOSS: 0.3227449655532837
# BATCH NUM: 110
# BATCH LOSS: 0.21694277226924896
# BATCH NUM: 120
# BATCH LOSS: 0.2535327970981598
# BATCH NUM: 130
# BATCH LOSS: 0.099732406437397
# BATCH NUM: 140
# BATCH LOSS: 0.41528406739234924
# BATCH NUM: 150
# BATCH LOSS: 0.08792518824338913
# BATCH NUM: 160
# BATCH LOSS: 0.08176159858703613
# BATCH NUM: 170
# BATCH LOSS: 0.18038232624530792
# BATCH NUM: 180
# BATCH LOSS: 0.047536786645650864
# BATCH NUM: 190
# BATCH LOSS: 0.019795028492808342
# BATCH NUM: 200
# BATCH LOSS: 0.08088121563196182
# BATCH NUM: 210
# BATCH LOSS: 0.0549948513507843
# BATCH NUM: 220
# BATCH LOSS: 0.10822156071662903
# BATCH NUM: 230
# BATCH LOSS: 0.16830319166183472
# BATCH NUM: 240
# BATCH LOSS: 0.035012416541576385
# BATCH NUM: 250
# BATCH LOSS: 0.04509498551487923
# BATCH NUM: 260
# BATCH LOSS: 0.08109207451343536
# BATCH NUM: 270
# BATCH LOSS: 0.2911998927593231
# BATCH NUM: 280
# BATCH LOSS: 0.21395035088062286
# BATCH NUM: 290
# BATCH LOSS: 0.43323513865470886
# BATCH NUM: 300
# BATCH LOSS: 0.5176921486854553
# BATCH NUM: 310
# BATCH LOSS: 0.40262937545776367
# BATCH NUM: 320
# BATCH LOSS: 0.7850674390792847
# BATCH NUM: 330
# BATCH LOSS: 0.5757081508636475
# BATCH NUM: 340
# BATCH LOSS: 1.068781852722168
# BATCH NUM: 350
# BATCH LOSS: 0.2842872142791748
# BATCH NUM: 360
# BATCH LOSS: 1.1462740898132324
# BATCH NUM: 370
# BATCH LOSS: 0.055788084864616394
# BATCH NUM: 380
# BATCH LOSS: 0.0033863927237689495
# BATCH NUM: 390
# BATCH LOSS: 0.3756253123283386
# BATCH NUM: 400
# BATCH LOSS: 0.006492277607321739
# BATCH NUM: 410
# BATCH LOSS: 0.06647535413503647
# BATCH NUM: 420
# BATCH LOSS: 0.7071600556373596
# BATCH NUM: 430
# BATCH LOSS: 0.598416805267334
# BATCH NUM: 440
# BATCH LOSS: 0.8620944619178772
# BATCH NUM: 450
# BATCH LOSS: 0.0016222450649365783
# EPOCH:  10
# LOSS:  0.3127429467975162
# TRAIN ACC:  0.9018847006651884
# EPOCH:  10
# LOSS:  2.05272706483347
# VALID ACC:  0.7991666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.22827120125293732
# BATCH NUM: 10
# BATCH LOSS: 0.5369535088539124
# BATCH NUM: 20
# BATCH LOSS: 0.2729588747024536
# BATCH NUM: 30
# BATCH LOSS: 0.08706057071685791
# BATCH NUM: 40
# BATCH LOSS: 0.4110443890094757
# BATCH NUM: 50
# BATCH LOSS: 0.21095779538154602
# BATCH NUM: 60
# BATCH LOSS: 0.36851853132247925
# BATCH NUM: 70
# BATCH LOSS: 0.06655218452215195
# BATCH NUM: 80
# BATCH LOSS: 0.20115311443805695
# BATCH NUM: 90
# BATCH LOSS: 0.7292203903198242
# BATCH NUM: 100
# BATCH LOSS: 0.28388866782188416
# BATCH NUM: 110
# BATCH LOSS: 0.020623033866286278
# BATCH NUM: 120
# BATCH LOSS: 0.5162755250930786
# BATCH NUM: 130
# BATCH LOSS: 0.633496880531311
# BATCH NUM: 140
# BATCH LOSS: 0.03483720123767853
# BATCH NUM: 150
# BATCH LOSS: 0.5962365865707397
# BATCH NUM: 160
# BATCH LOSS: 0.18041720986366272
# BATCH NUM: 170
# BATCH LOSS: 0.012139684520661831
# BATCH NUM: 180
# BATCH LOSS: 0.09405730664730072
# BATCH NUM: 190
# BATCH LOSS: 0.3397611975669861
# BATCH NUM: 200
# BATCH LOSS: 1.0374137163162231
# BATCH NUM: 210
# BATCH LOSS: 0.425148069858551
# BATCH NUM: 220
# BATCH LOSS: 0.23464840650558472
# BATCH NUM: 230
# BATCH LOSS: 0.23224225640296936
# BATCH NUM: 240
# BATCH LOSS: 0.7530184388160706
# BATCH NUM: 250
# BATCH LOSS: 0.6957914233207703
# BATCH NUM: 260
# BATCH LOSS: 0.43451830744743347
# BATCH NUM: 270
# BATCH LOSS: 0.6821425557136536
# BATCH NUM: 280
# BATCH LOSS: 0.3616093099117279
# BATCH NUM: 290
# BATCH LOSS: 0.07169975340366364
# BATCH NUM: 300
# BATCH LOSS: 0.053819261491298676
# BATCH NUM: 310
# BATCH LOSS: 0.5119339823722839
# BATCH NUM: 320
# BATCH LOSS: 0.1210828348994255
# BATCH NUM: 330
# BATCH LOSS: 0.10157933086156845
# BATCH NUM: 340
# BATCH LOSS: 0.08077863603830338
# BATCH NUM: 350
# BATCH LOSS: 1.2053930759429932
# BATCH NUM: 360
# BATCH LOSS: 0.11635184288024902
# BATCH NUM: 370
# BATCH LOSS: 0.016138024628162384
# BATCH NUM: 380
# BATCH LOSS: 0.6526975631713867
# BATCH NUM: 390
# BATCH LOSS: 0.5189229249954224
# BATCH NUM: 400
# BATCH LOSS: 0.45021599531173706
# BATCH NUM: 410
# BATCH LOSS: 0.10957922786474228
# BATCH NUM: 420
# BATCH LOSS: 0.29737022519111633
# BATCH NUM: 430
# BATCH LOSS: 0.06011781841516495
# BATCH NUM: 440
# BATCH LOSS: 0.30073413252830505
# BATCH NUM: 450
# BATCH LOSS: 0.003674618899822235
# EPOCH:  11
# LOSS:  0.30515583474292524
# TRAIN ACC:  0.9029933481152993
# EPOCH:  11
# LOSS:  2.1022558310545745
# VALID ACC:  0.81
# BATCH NUM: 0
# BATCH LOSS: 0.023458005860447884
# BATCH NUM: 10
# BATCH LOSS: 0.1291617453098297
# BATCH NUM: 20
# BATCH LOSS: 0.14547595381736755
# BATCH NUM: 30
# BATCH LOSS: 0.0861341580748558
# BATCH NUM: 40
# BATCH LOSS: 0.010810209438204765
# BATCH NUM: 50
# BATCH LOSS: 0.059477806091308594
# BATCH NUM: 60
# BATCH LOSS: 0.052542608231306076
# BATCH NUM: 70
# BATCH LOSS: 0.039929602295160294
# BATCH NUM: 80
# BATCH LOSS: 0.2362239807844162
# BATCH NUM: 90
# BATCH LOSS: 0.4177914261817932
# BATCH NUM: 100
# BATCH LOSS: 0.04656902328133583
# BATCH NUM: 110
# BATCH LOSS: 0.5228486657142639
# BATCH NUM: 120
# BATCH LOSS: 0.16595065593719482
# BATCH NUM: 130
# BATCH LOSS: 0.15422363579273224
# BATCH NUM: 140
# BATCH LOSS: 0.3700236976146698
# BATCH NUM: 150
# BATCH LOSS: 0.06776461750268936
# BATCH NUM: 160
# BATCH LOSS: 0.7416208982467651
# BATCH NUM: 170
# BATCH LOSS: 0.6564706563949585
# BATCH NUM: 180
# BATCH LOSS: 0.22890524566173553
# BATCH NUM: 190
# BATCH LOSS: 0.23895157873630524
# BATCH NUM: 200
# BATCH LOSS: 0.8670041561126709
# BATCH NUM: 210
# BATCH LOSS: 0.5686724781990051
# BATCH NUM: 220
# BATCH LOSS: 0.024363232776522636
# BATCH NUM: 230
# BATCH LOSS: 0.10600214451551437
# BATCH NUM: 240
# BATCH LOSS: 0.7944228649139404
# BATCH NUM: 250
# BATCH LOSS: 0.1371462345123291
# BATCH NUM: 260
# BATCH LOSS: 0.100064717233181
# BATCH NUM: 270
# BATCH LOSS: 0.8018990159034729
# BATCH NUM: 280
# BATCH LOSS: 0.008098534308373928
# BATCH NUM: 290
# BATCH LOSS: 0.03162701427936554
# BATCH NUM: 300
# BATCH LOSS: 0.014103047549724579
# BATCH NUM: 310
# BATCH LOSS: 0.1396063268184662
# BATCH NUM: 320
# BATCH LOSS: 0.006528730504214764
# BATCH NUM: 330
# BATCH LOSS: 0.008722036145627499
# BATCH NUM: 340
# BATCH LOSS: 0.2619553506374359
# BATCH NUM: 350
# BATCH LOSS: 0.06844223290681839
# BATCH NUM: 360
# BATCH LOSS: 0.20407480001449585
# BATCH NUM: 370
# BATCH LOSS: 0.26631006598472595
# BATCH NUM: 380
# BATCH LOSS: 0.2372821569442749
# BATCH NUM: 390
# BATCH LOSS: 0.23675595223903656
# BATCH NUM: 400
# BATCH LOSS: 0.39408135414123535
# BATCH NUM: 410
# BATCH LOSS: 0.01821444369852543
# BATCH NUM: 420
# BATCH LOSS: 0.15279141068458557
# BATCH NUM: 430
# BATCH LOSS: 0.4098545014858246
# BATCH NUM: 440
# BATCH LOSS: 0.41988587379455566
# BATCH NUM: 450
# BATCH LOSS: 0.012420965358614922
# EPOCH:  12
# LOSS:  0.25524539928210693
# TRAIN ACC:  0.9162971175166297
# EPOCH:  12
# LOSS:  2.1969289145916924
# VALID ACC:  0.7983333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.762606143951416
# BATCH NUM: 10
# BATCH LOSS: 0.227293461561203
# BATCH NUM: 20
# BATCH LOSS: 0.29692211747169495
# BATCH NUM: 30
# BATCH LOSS: 0.026310773566365242
# BATCH NUM: 40
# BATCH LOSS: 0.3035851716995239
# BATCH NUM: 50
# BATCH LOSS: 0.3839448392391205
# BATCH NUM: 60
# BATCH LOSS: 0.002549796598032117
# BATCH NUM: 70
# BATCH LOSS: 0.9119507670402527
# BATCH NUM: 80
# BATCH LOSS: 0.46323147416114807
# BATCH NUM: 90
# BATCH LOSS: 0.0224369615316391
# BATCH NUM: 100
# BATCH LOSS: 0.14793658256530762
# BATCH NUM: 110
# BATCH LOSS: 0.15158893167972565
# BATCH NUM: 120
# BATCH LOSS: 0.036049824208021164
# BATCH NUM: 130
# BATCH LOSS: 0.021071994677186012
# BATCH NUM: 140
# BATCH LOSS: 0.3568119406700134
# BATCH NUM: 150
# BATCH LOSS: 0.17185504734516144
# BATCH NUM: 160
# BATCH LOSS: 0.11443959176540375
# BATCH NUM: 170
# BATCH LOSS: 0.002078244462609291
# BATCH NUM: 180
# BATCH LOSS: 0.10691333562135696
# BATCH NUM: 190
# BATCH LOSS: 0.1416977047920227
# BATCH NUM: 200
# BATCH LOSS: 0.020078208297491074
# BATCH NUM: 210
# BATCH LOSS: 0.0998772457242012
# BATCH NUM: 220
# BATCH LOSS: 1.354055404663086
# BATCH NUM: 230
# BATCH LOSS: 0.10863984376192093
# BATCH NUM: 240
# BATCH LOSS: 0.047134000808000565
# BATCH NUM: 250
# BATCH LOSS: 0.018606947734951973
# BATCH NUM: 260
# BATCH LOSS: 0.013231126591563225
# BATCH NUM: 270
# BATCH LOSS: 0.20254024863243103
# BATCH NUM: 280
# BATCH LOSS: 0.08061438053846359
# BATCH NUM: 290
# BATCH LOSS: 0.37043464183807373
# BATCH NUM: 300
# BATCH LOSS: 0.014863397926092148
# BATCH NUM: 310
# BATCH LOSS: 0.1642732322216034
# BATCH NUM: 320
# BATCH LOSS: 0.154873326420784
# BATCH NUM: 330
# BATCH LOSS: 1.2898098230361938
# BATCH NUM: 340
# BATCH LOSS: 0.07422356307506561
# BATCH NUM: 350
# BATCH LOSS: 0.03422591835260391
# BATCH NUM: 360
# BATCH LOSS: 0.025188257917761803
# BATCH NUM: 370
# BATCH LOSS: 0.15229716897010803
# BATCH NUM: 380
# BATCH LOSS: 0.051525015383958817
# BATCH NUM: 390
# BATCH LOSS: 0.017684388905763626
# BATCH NUM: 400
# BATCH LOSS: 0.22098477184772491
# BATCH NUM: 410
# BATCH LOSS: 0.17380334436893463
# BATCH NUM: 420
# BATCH LOSS: 0.3262893855571747
# BATCH NUM: 430
# BATCH LOSS: 0.17349421977996826
# BATCH NUM: 440
# BATCH LOSS: 0.2272653579711914
# BATCH NUM: 450
# BATCH LOSS: 0.007935247384011745
# EPOCH:  13
# LOSS:  0.23058761266312408
# TRAIN ACC:  0.9271064301552107
# EPOCH:  13
# LOSS:  2.2670459930209566
# VALID ACC:  0.8091666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.08894935995340347
# BATCH NUM: 10
# BATCH LOSS: 0.7265796065330505
# BATCH NUM: 20
# BATCH LOSS: 0.23124542832374573
# BATCH NUM: 30
# BATCH LOSS: 0.12577176094055176
# BATCH NUM: 40
# BATCH LOSS: 0.29501575231552124
# BATCH NUM: 50
# BATCH LOSS: 0.21412791311740875
# BATCH NUM: 60
# BATCH LOSS: 0.21273458003997803
# BATCH NUM: 70
# BATCH LOSS: 0.38275986909866333
# BATCH NUM: 80
# BATCH LOSS: 0.011501030065119267
# BATCH NUM: 90
# BATCH LOSS: 0.09104660153388977
# BATCH NUM: 100
# BATCH LOSS: 0.0030866654124110937
# BATCH NUM: 110
# BATCH LOSS: 0.4670041501522064
# BATCH NUM: 120
# BATCH LOSS: 0.838886559009552
# BATCH NUM: 130
# BATCH LOSS: 0.3731347620487213
# BATCH NUM: 140
# BATCH LOSS: 0.11439460515975952
# BATCH NUM: 150
# BATCH LOSS: 0.7161784172058105
# BATCH NUM: 160
# BATCH LOSS: 0.13286623358726501
# BATCH NUM: 170
# BATCH LOSS: 0.22381944954395294
# BATCH NUM: 180
# BATCH LOSS: 1.1864486932754517
# BATCH NUM: 190
# BATCH LOSS: 0.44209784269332886
# BATCH NUM: 200
# BATCH LOSS: 0.9158416986465454
# BATCH NUM: 210
# BATCH LOSS: 0.04055594280362129
# BATCH NUM: 220
# BATCH LOSS: 0.5321592092514038
# BATCH NUM: 230
# BATCH LOSS: 0.160213902592659
# BATCH NUM: 240
# BATCH LOSS: 0.5947176218032837
# BATCH NUM: 250
# BATCH LOSS: 0.3297528326511383
# BATCH NUM: 260
# BATCH LOSS: 0.41941434144973755
# BATCH NUM: 270
# BATCH LOSS: 0.15816393494606018
# BATCH NUM: 280
# BATCH LOSS: 0.49153265357017517
# BATCH NUM: 290
# BATCH LOSS: 0.2340490221977234
# BATCH NUM: 300
# BATCH LOSS: 0.5216617584228516
# BATCH NUM: 310
# BATCH LOSS: 0.5942414999008179
# BATCH NUM: 320
# BATCH LOSS: 0.03418036550283432
# BATCH NUM: 330
# BATCH LOSS: 0.24000714719295502
# BATCH NUM: 340
# BATCH LOSS: 0.10631522536277771
# BATCH NUM: 350
# BATCH LOSS: 0.18261393904685974
# BATCH NUM: 360
# BATCH LOSS: 1.3778464794158936
# BATCH NUM: 370
# BATCH LOSS: 0.07006237655878067
# BATCH NUM: 380
# BATCH LOSS: 0.216195747256279
# BATCH NUM: 390
# BATCH LOSS: 0.12817539274692535
# BATCH NUM: 400
# BATCH LOSS: 0.06258279085159302
# BATCH NUM: 410
# BATCH LOSS: 0.0404585525393486
# BATCH NUM: 420
# BATCH LOSS: 0.2569776773452759
# BATCH NUM: 430
# BATCH LOSS: 0.47745734453201294
# BATCH NUM: 440
# BATCH LOSS: 0.794711709022522
# BATCH NUM: 450
# BATCH LOSS: 0.25471001863479614
# EPOCH:  14
# LOSS:  0.3616856774610157
# TRAIN ACC:  0.8905210643015521
# EPOCH:  14
# LOSS:  2.1919131552236624
# VALID ACC:  0.8016666666666666
# BATCH NUM: 0
# BATCH LOSS: 0.13049419224262238
# BATCH NUM: 10
# BATCH LOSS: 0.1598353385925293
# BATCH NUM: 20
# BATCH LOSS: 0.3619080185890198
# BATCH NUM: 30
# BATCH LOSS: 0.568106472492218
# BATCH NUM: 40
# BATCH LOSS: 0.03406183421611786
# BATCH NUM: 50
# BATCH LOSS: 0.04986833781003952
# BATCH NUM: 60
# BATCH LOSS: 0.03868689388036728
# BATCH NUM: 70
# BATCH LOSS: 0.03450940549373627
# BATCH NUM: 80
# BATCH LOSS: 0.020198017358779907
# BATCH NUM: 90
# BATCH LOSS: 0.05019485205411911
# BATCH NUM: 100
# BATCH LOSS: 0.2845880389213562
# BATCH NUM: 110
# BATCH LOSS: 0.013018994592130184
# BATCH NUM: 120
# BATCH LOSS: 0.10454293340444565
# BATCH NUM: 130
# BATCH LOSS: 0.007324766833335161
# BATCH NUM: 140
# BATCH LOSS: 0.6866085529327393
# BATCH NUM: 150
# BATCH LOSS: 0.005072374362498522
# BATCH NUM: 160
# BATCH LOSS: 0.1397062987089157
# BATCH NUM: 170
# BATCH LOSS: 0.928794801235199
# BATCH NUM: 180
# BATCH LOSS: 1.5096315145492554
# BATCH NUM: 190
# BATCH LOSS: 0.34683743119239807
# BATCH NUM: 200
# BATCH LOSS: 0.35045674443244934
# BATCH NUM: 210
# BATCH LOSS: 0.013681171461939812
# BATCH NUM: 220
# BATCH LOSS: 0.018165117129683495
# BATCH NUM: 230
# BATCH LOSS: 0.17514847218990326
# BATCH NUM: 240
# BATCH LOSS: 0.057687073945999146
# BATCH NUM: 250
# BATCH LOSS: 0.9338744282722473
# BATCH NUM: 260
# BATCH LOSS: 0.5995362997055054
# BATCH NUM: 270
# BATCH LOSS: 0.2344796359539032
# BATCH NUM: 280
# BATCH LOSS: 0.07764249294996262
# BATCH NUM: 290
# BATCH LOSS: 0.26225054264068604
# BATCH NUM: 300
# BATCH LOSS: 1.26321280002594
# BATCH NUM: 310
# BATCH LOSS: 0.024341261014342308
# BATCH NUM: 320
# BATCH LOSS: 0.018003884702920914
# BATCH NUM: 330
# BATCH LOSS: 0.09591658413410187
# BATCH NUM: 340
# BATCH LOSS: 0.052469685673713684
# BATCH NUM: 350
# BATCH LOSS: 0.11869866400957108
# BATCH NUM: 360
# BATCH LOSS: 0.061973702162504196
# BATCH NUM: 370
# BATCH LOSS: 0.061608973890542984
# BATCH NUM: 380
# BATCH LOSS: 0.03702399879693985
# BATCH NUM: 390
# BATCH LOSS: 0.015702107921242714
# BATCH NUM: 400
# BATCH LOSS: 0.3168160021305084
# BATCH NUM: 410
# BATCH LOSS: 0.2320849895477295
# BATCH NUM: 420
# BATCH LOSS: 0.06849846243858337
# BATCH NUM: 430
# BATCH LOSS: 0.0012521613389253616
# BATCH NUM: 440
# BATCH LOSS: 0.06539653986692429
# BATCH NUM: 450
# BATCH LOSS: 5.59659420105163e-05
# EPOCH:  15
# LOSS:  0.23798557229153328
# TRAIN ACC:  0.9185144124168514
# EPOCH:  15
# LOSS:  2.3396384832334745
# VALID ACC:  0.8091666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.03359444811940193
# BATCH NUM: 10
# BATCH LOSS: 0.013191784732043743
# BATCH NUM: 20
# BATCH LOSS: 1.3300367593765259
# BATCH NUM: 30
# BATCH LOSS: 0.0902683213353157
# BATCH NUM: 40
# BATCH LOSS: 0.01841099187731743
# BATCH NUM: 50
# BATCH LOSS: 0.04636595398187637
# BATCH NUM: 60
# BATCH LOSS: 0.1390899419784546
# BATCH NUM: 70
# BATCH LOSS: 0.1651138961315155
# BATCH NUM: 80
# BATCH LOSS: 0.015341175720095634
# BATCH NUM: 90
# BATCH LOSS: 0.02716728299856186
# BATCH NUM: 100
# BATCH LOSS: 0.4725755453109741
# BATCH NUM: 110
# BATCH LOSS: 0.07985665649175644
# BATCH NUM: 120
# BATCH LOSS: 0.18124350905418396
# BATCH NUM: 130
# BATCH LOSS: 0.06659219413995743
# BATCH NUM: 140
# BATCH LOSS: 0.47872260212898254
# BATCH NUM: 150
# BATCH LOSS: 0.04540129750967026
# BATCH NUM: 160
# BATCH LOSS: 0.15948565304279327
# BATCH NUM: 170
# BATCH LOSS: 0.004925019573420286
# BATCH NUM: 180
# BATCH LOSS: 0.0068536256439983845
# BATCH NUM: 190
# BATCH LOSS: 0.02848747931420803
# BATCH NUM: 200
# BATCH LOSS: 0.005368375219404697
# BATCH NUM: 210
# BATCH LOSS: 0.1683862954378128
# BATCH NUM: 220
# BATCH LOSS: 0.09978556632995605
# BATCH NUM: 230
# BATCH LOSS: 0.22278597950935364
# BATCH NUM: 240
# BATCH LOSS: 0.15781651437282562
# BATCH NUM: 250
# BATCH LOSS: 0.02375813014805317
# BATCH NUM: 260
# BATCH LOSS: 0.4674757122993469
# BATCH NUM: 270
# BATCH LOSS: 0.3963455557823181
# BATCH NUM: 280
# BATCH LOSS: 0.07384990155696869
# BATCH NUM: 290
# BATCH LOSS: 0.34420061111450195
# BATCH NUM: 300
# BATCH LOSS: 0.07071534544229507
# BATCH NUM: 310
# BATCH LOSS: 0.008920696564018726
# BATCH NUM: 320
# BATCH LOSS: 0.16729849576950073
# BATCH NUM: 330
# BATCH LOSS: 0.13491079211235046
# BATCH NUM: 340
# BATCH LOSS: 0.08528515696525574
# BATCH NUM: 350
# BATCH LOSS: 0.022266680374741554
# BATCH NUM: 360
# BATCH LOSS: 0.16735896468162537
# BATCH NUM: 370
# BATCH LOSS: 0.02865452691912651
# BATCH NUM: 380
# BATCH LOSS: 0.3974444568157196
# BATCH NUM: 390
# BATCH LOSS: 0.03481181338429451
# BATCH NUM: 400
# BATCH LOSS: 0.8567718863487244
# BATCH NUM: 410
# BATCH LOSS: 0.09747197479009628
# BATCH NUM: 420
# BATCH LOSS: 0.0008129545021802187
# BATCH NUM: 430
# BATCH LOSS: 0.02398865669965744
# BATCH NUM: 440
# BATCH LOSS: 0.020414581522345543
# BATCH NUM: 450
# BATCH LOSS: 0.0018370203906670213
# EPOCH:  16
# LOSS:  0.1844163045778017
# TRAIN ACC:  0.940410199556541
# EPOCH:  16
# LOSS:  2.4782889107518224
# VALID ACC:  0.8
# BATCH NUM: 0
# BATCH LOSS: 0.004724784754216671
# BATCH NUM: 10
# BATCH LOSS: 0.11665330082178116
# BATCH NUM: 20
# BATCH LOSS: 0.3986286222934723
# BATCH NUM: 30
# BATCH LOSS: 0.08160766959190369
# BATCH NUM: 40
# BATCH LOSS: 0.0502486377954483
# BATCH NUM: 50
# BATCH LOSS: 0.13362272083759308
# BATCH NUM: 60
# BATCH LOSS: 0.007994579151272774
# BATCH NUM: 70
# BATCH LOSS: 0.0796426385641098
# BATCH NUM: 80
# BATCH LOSS: 0.47777172923088074
# BATCH NUM: 90
# BATCH LOSS: 0.017287617549300194
# BATCH NUM: 100
# BATCH LOSS: 0.0006367034511640668
# BATCH NUM: 110
# BATCH LOSS: 0.17365723848342896
# BATCH NUM: 120
# BATCH LOSS: 0.000512161641381681
# BATCH NUM: 130
# BATCH LOSS: 0.41096094250679016
# BATCH NUM: 140
# BATCH LOSS: 0.2403627634048462
# BATCH NUM: 150
# BATCH LOSS: 0.0042757876217365265
# BATCH NUM: 160
# BATCH LOSS: 0.00024154096900019795
# BATCH NUM: 170
# BATCH LOSS: 0.45490968227386475
# BATCH NUM: 180
# BATCH LOSS: 0.05322462320327759
# BATCH NUM: 190
# BATCH LOSS: 0.024379415437579155
# BATCH NUM: 200
# BATCH LOSS: 0.05824747681617737
# BATCH NUM: 210
# BATCH LOSS: 0.21337498724460602
# BATCH NUM: 220
# BATCH LOSS: 0.013578026555478573
# BATCH NUM: 230
# BATCH LOSS: 0.0470132976770401
# BATCH NUM: 240
# BATCH LOSS: 0.20907418429851532
# BATCH NUM: 250
# BATCH LOSS: 0.19368641078472137
# BATCH NUM: 260
# BATCH LOSS: 0.818489134311676
# BATCH NUM: 270
# BATCH LOSS: 0.15299512445926666
# BATCH NUM: 280
# BATCH LOSS: 0.2602740526199341
# BATCH NUM: 290
# BATCH LOSS: 0.05625613033771515
# BATCH NUM: 300
# BATCH LOSS: 0.362993448972702
# BATCH NUM: 310
# BATCH LOSS: 0.043455228209495544
# BATCH NUM: 320
# BATCH LOSS: 0.18303117156028748
# BATCH NUM: 330
# BATCH LOSS: 0.015954269096255302
# BATCH NUM: 340
# BATCH LOSS: 0.1398559808731079
# BATCH NUM: 350
# BATCH LOSS: 0.1394646316766739
# BATCH NUM: 360
# BATCH LOSS: 0.6154248714447021
# BATCH NUM: 370
# BATCH LOSS: 0.002213788451626897
# BATCH NUM: 380
# BATCH LOSS: 0.23380742967128754
# BATCH NUM: 390
# BATCH LOSS: 0.262874037027359
# BATCH NUM: 400
# BATCH LOSS: 0.007193508092314005
# BATCH NUM: 410
# BATCH LOSS: 0.007218742743134499
# BATCH NUM: 420
# BATCH LOSS: 0.8181723356246948
# BATCH NUM: 430
# BATCH LOSS: 0.0006521938485093415
# BATCH NUM: 440
# BATCH LOSS: 0.014765986241400242
# BATCH NUM: 450
# BATCH LOSS: 0.00968688540160656
# EPOCH:  17
# LOSS:  0.1883968327352583
# TRAIN ACC:  0.9398558758314856
# EPOCH:  17
# LOSS:  2.416262739506353
# VALID ACC:  0.81
# BATCH NUM: 0
# BATCH LOSS: 0.04104376211762428
# BATCH NUM: 10
# BATCH LOSS: 0.126346617937088
# BATCH NUM: 20
# BATCH LOSS: 0.2636113166809082
# BATCH NUM: 30
# BATCH LOSS: 0.023044606670737267
# BATCH NUM: 40
# BATCH LOSS: 0.00526324100792408
# BATCH NUM: 50
# BATCH LOSS: 0.035665012896060944
# BATCH NUM: 60
# BATCH LOSS: 0.08295930176973343
# BATCH NUM: 70
# BATCH LOSS: 0.29224294424057007
# BATCH NUM: 80
# BATCH LOSS: 0.016708504408597946
# BATCH NUM: 90
# BATCH LOSS: 0.018527578562498093
# BATCH NUM: 100
# BATCH LOSS: 0.0627884566783905
# BATCH NUM: 110
# BATCH LOSS: 0.00910013634711504
# BATCH NUM: 120
# BATCH LOSS: 0.09250291436910629
# BATCH NUM: 130
# BATCH LOSS: 0.000786847376730293
# BATCH NUM: 140
# BATCH LOSS: 0.279716819524765
# BATCH NUM: 150
# BATCH LOSS: 0.013299849815666676
# BATCH NUM: 160
# BATCH LOSS: 0.0014931883197277784
# BATCH NUM: 170
# BATCH LOSS: 0.0029221954755485058
# BATCH NUM: 180
# BATCH LOSS: 0.33243873715400696
# BATCH NUM: 190
# BATCH LOSS: 0.003761494066566229
# BATCH NUM: 200
# BATCH LOSS: 0.2512551248073578
# BATCH NUM: 210
# BATCH LOSS: 0.13061298429965973
# BATCH NUM: 220
# BATCH LOSS: 0.001732338685542345
# BATCH NUM: 230
# BATCH LOSS: 0.17418240010738373
# BATCH NUM: 240
# BATCH LOSS: 0.03616337478160858
# BATCH NUM: 250
# BATCH LOSS: 0.5360944867134094
# BATCH NUM: 260
# BATCH LOSS: 0.021305132657289505
# BATCH NUM: 270
# BATCH LOSS: 0.03805966302752495
# BATCH NUM: 280
# BATCH LOSS: 0.042706284672021866
# BATCH NUM: 290
# BATCH LOSS: 0.06706904619932175
# BATCH NUM: 300
# BATCH LOSS: 0.214665025472641
# BATCH NUM: 310
# BATCH LOSS: 0.7697078585624695
# BATCH NUM: 320
# BATCH LOSS: 0.04072214663028717
# BATCH NUM: 330
# BATCH LOSS: 1.1301604509353638
# BATCH NUM: 340
# BATCH LOSS: 0.07345711439847946
# BATCH NUM: 350
# BATCH LOSS: 0.04884181544184685
# BATCH NUM: 360
# BATCH LOSS: 0.09018786996603012
# BATCH NUM: 370
# BATCH LOSS: 0.3897456228733063
# BATCH NUM: 380
# BATCH LOSS: 0.30622801184654236
# BATCH NUM: 390
# BATCH LOSS: 0.5715305805206299
# BATCH NUM: 400
# BATCH LOSS: 0.0002315980673301965
# BATCH NUM: 410
# BATCH LOSS: 0.41004836559295654
# BATCH NUM: 420
# BATCH LOSS: 0.34781336784362793
# BATCH NUM: 430
# BATCH LOSS: 0.06253735721111298
# BATCH NUM: 440
# BATCH LOSS: 0.021529508754611015
# BATCH NUM: 450
# BATCH LOSS: 1.5288238525390625
# EPOCH:  18
# LOSS:  0.1657169760447707
# TRAIN ACC:  0.9484478935698448
# EPOCH:  18
# LOSS:  2.5446544406323612
# VALID ACC:  0.8116666666666666
# BATCH NUM: 0
# BATCH LOSS: 0.011652962304651737
# BATCH NUM: 10
# BATCH LOSS: 0.0013786657946184278
# BATCH NUM: 20
# BATCH LOSS: 0.06803494691848755
# BATCH NUM: 30
# BATCH LOSS: 0.014786931686103344
# BATCH NUM: 40
# BATCH LOSS: 0.05250367149710655
# BATCH NUM: 50
# BATCH LOSS: 0.0761311799287796
# BATCH NUM: 60
# BATCH LOSS: 0.12515059113502502
# BATCH NUM: 70
# BATCH LOSS: 0.12418439984321594
# BATCH NUM: 80
# BATCH LOSS: 0.05253477394580841
# BATCH NUM: 90
# BATCH LOSS: 0.34011250734329224
# BATCH NUM: 100
# BATCH LOSS: 0.007179101463407278
# BATCH NUM: 110
# BATCH LOSS: 0.010071544907987118
# BATCH NUM: 120
# BATCH LOSS: 0.30962252616882324
# BATCH NUM: 130
# BATCH LOSS: 0.47293737530708313
# BATCH NUM: 140
# BATCH LOSS: 0.005393228493630886
# BATCH NUM: 150
# BATCH LOSS: 0.10088936984539032
# BATCH NUM: 160
# BATCH LOSS: 0.14838242530822754
# BATCH NUM: 170
# BATCH LOSS: 0.055077116936445236
# BATCH NUM: 180
# BATCH LOSS: 0.7098449468612671
# BATCH NUM: 190
# BATCH LOSS: 0.043828804045915604
# BATCH NUM: 200
# BATCH LOSS: 0.08202974498271942
# BATCH NUM: 210
# BATCH LOSS: 0.2884202003479004
# BATCH NUM: 220
# BATCH LOSS: 0.04698370024561882
# BATCH NUM: 230
# BATCH LOSS: 0.011276227422058582
# BATCH NUM: 240
# BATCH LOSS: 0.1252051591873169
# BATCH NUM: 250
# BATCH LOSS: 0.24363946914672852
# BATCH NUM: 260
# BATCH LOSS: 0.0013948478735983372
# BATCH NUM: 270
# BATCH LOSS: 0.20702305436134338
# BATCH NUM: 280
# BATCH LOSS: 0.8251128792762756
# BATCH NUM: 290
# BATCH LOSS: 0.19551357626914978
# BATCH NUM: 300
# BATCH LOSS: 0.27495625615119934
# BATCH NUM: 310
# BATCH LOSS: 0.07264475524425507
# BATCH NUM: 320
# BATCH LOSS: 0.010402245447039604
# BATCH NUM: 330
# BATCH LOSS: 0.0080898217856884
# BATCH NUM: 340
# BATCH LOSS: 0.4236522316932678
# BATCH NUM: 350
# BATCH LOSS: 0.012001054361462593
# BATCH NUM: 360
# BATCH LOSS: 1.4594234228134155
# BATCH NUM: 370
# BATCH LOSS: 0.011116422712802887
# BATCH NUM: 380
# BATCH LOSS: 0.8232086300849915
# BATCH NUM: 390
# BATCH LOSS: 0.11931650340557098
# BATCH NUM: 400
# BATCH LOSS: 0.03587600961327553
# BATCH NUM: 410
# BATCH LOSS: 0.24823960661888123
# BATCH NUM: 420
# BATCH LOSS: 0.023107104003429413
# BATCH NUM: 430
# BATCH LOSS: 0.9861762523651123
# BATCH NUM: 440
# BATCH LOSS: 0.01603352278470993
# BATCH NUM: 450
# BATCH LOSS: 0.020514506846666336
# EPOCH:  19
# LOSS:  0.16485602904909885
# TRAIN ACC:  0.9456762749445676
# EPOCH:  19
# LOSS:  2.627614689423097
# VALID ACC:  0.8108333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.18139109015464783
# BATCH NUM: 10
# BATCH LOSS: 0.12801317870616913
# BATCH NUM: 20
# BATCH LOSS: 0.44818463921546936
# BATCH NUM: 30
# BATCH LOSS: 1.1327221393585205
# BATCH NUM: 40
# BATCH LOSS: 1.057202696800232
# BATCH NUM: 50
# BATCH LOSS: 0.007577519863843918
# BATCH NUM: 60
# BATCH LOSS: 0.058101020753383636
# BATCH NUM: 70
# BATCH LOSS: 0.09522160142660141
# BATCH NUM: 80
# BATCH LOSS: 0.32960963249206543
# BATCH NUM: 90
# BATCH LOSS: 0.396584153175354
# BATCH NUM: 100
# BATCH LOSS: 0.03888290748000145
# BATCH NUM: 110
# BATCH LOSS: 0.012629514560103416
# BATCH NUM: 120
# BATCH LOSS: 0.2483919858932495
# BATCH NUM: 130
# BATCH LOSS: 0.23705953359603882
# BATCH NUM: 140
# BATCH LOSS: 0.07574336230754852
# BATCH NUM: 150
# BATCH LOSS: 0.014592471532523632
# BATCH NUM: 160
# BATCH LOSS: 0.014874834567308426
# BATCH NUM: 170
# BATCH LOSS: 0.3144415616989136
# BATCH NUM: 180
# BATCH LOSS: 0.016398204490542412
# BATCH NUM: 190
# BATCH LOSS: 0.037987202405929565
# BATCH NUM: 200
# BATCH LOSS: 0.43511271476745605
# BATCH NUM: 210
# BATCH LOSS: 0.16216900944709778
# BATCH NUM: 220
# BATCH LOSS: 0.01425798051059246
# BATCH NUM: 230
# BATCH LOSS: 0.01733531430363655
# BATCH NUM: 240
# BATCH LOSS: 0.3200499415397644
# BATCH NUM: 250
# BATCH LOSS: 0.466281533241272
# BATCH NUM: 260
# BATCH LOSS: 0.06076841801404953
# BATCH NUM: 270
# BATCH LOSS: 0.05176457017660141
# BATCH NUM: 280
# BATCH LOSS: 0.10545560717582703
# BATCH NUM: 290
# BATCH LOSS: 0.2307978719472885
# BATCH NUM: 300
# BATCH LOSS: 0.001254343893378973
# BATCH NUM: 310
# BATCH LOSS: 0.03894839808344841
# BATCH NUM: 320
# BATCH LOSS: 0.016953669488430023
# BATCH NUM: 330
# BATCH LOSS: 0.01703610084950924
# BATCH NUM: 340
# BATCH LOSS: 0.006449258420616388
# BATCH NUM: 350
# BATCH LOSS: 0.017144683748483658
# BATCH NUM: 360
# BATCH LOSS: 0.08239847421646118
# BATCH NUM: 370
# BATCH LOSS: 0.022101998329162598
# BATCH NUM: 380
# BATCH LOSS: 0.044698767364025116
# BATCH NUM: 390
# BATCH LOSS: 0.7937260866165161
# BATCH NUM: 400
# BATCH LOSS: 0.06890488415956497
# BATCH NUM: 410
# BATCH LOSS: 0.12673033773899078
# BATCH NUM: 420
# BATCH LOSS: 0.15255828201770782
# BATCH NUM: 430
# BATCH LOSS: 0.2626820504665375
# BATCH NUM: 440
# BATCH LOSS: 0.008113689720630646
# BATCH NUM: 450
# BATCH LOSS: 0.07468245178461075
# EPOCH:  20
# LOSS:  0.19083031170104126
# TRAIN ACC:  0.936529933481153
# EPOCH:  20
# LOSS:  2.6570966425545173
# VALID ACC:  0.8225
# BATCH NUM: 0
# BATCH LOSS: 0.3051907420158386
# BATCH NUM: 10
# BATCH LOSS: 0.210619255900383
# BATCH NUM: 20
# ...
# BATCH LOSS: 0.0370824858546257
# BATCH NUM: 100
# BATCH LOSS: 0.23482106626033783
# BATCH NUM: 110
# BATCH LOSS: 0.050297003239393234
# BATCH NUM: 120
# BATCH LOSS: 0.01932108961045742
# BATCH NUM: 130
# BATCH LOSS: 0.010268610902130604
# BATCH NUM: 140
# BATCH LOSS: 0.0056625171564519405
# BATCH NUM: 150
# BATCH LOSS: 0.14755195379257202
# BATCH NUM: 160
# BATCH LOSS: 0.15711458027362823
# BATCH NUM: 170
# BATCH LOSS: 0.04285118356347084
# BATCH NUM: 180
# BATCH LOSS: 0.0007344151381403208
# BATCH NUM: 190
# BATCH LOSS: 0.17626254260540009
# BATCH NUM: 200
# BATCH LOSS: 0.04288897663354874
# BATCH NUM: 210
# BATCH LOSS: 0.04102613031864166
# BATCH NUM: 220
# BATCH LOSS: 0.07085302472114563
# BATCH NUM: 230
# BATCH LOSS: 0.0250970758497715
# BATCH NUM: 240
# BATCH LOSS: 0.0001498829951742664
# BATCH NUM: 250
# BATCH LOSS: 0.001014895155094564
# BATCH NUM: 260
# BATCH LOSS: 0.0029034153558313847
# BATCH NUM: 270
# BATCH LOSS: 0.008833633735775948
# BATCH NUM: 280
# BATCH LOSS: 0.00785532221198082
# BATCH NUM: 290
# BATCH LOSS: 0.012075592763721943
# BATCH NUM: 300
# BATCH LOSS: 0.00017553710495121777
# BATCH NUM: 310
# BATCH LOSS: 0.0017138993134722114
# BATCH NUM: 320
# BATCH LOSS: 0.4612877368927002
# BATCH NUM: 330
# BATCH LOSS: 0.00275799841620028
# BATCH NUM: 340
# BATCH LOSS: 7.631835615029559e-05
# BATCH NUM: 350
# BATCH LOSS: 0.002696732524782419
# BATCH NUM: 360
# BATCH LOSS: 0.008008096367120743
# BATCH NUM: 370
# BATCH LOSS: 0.03109326958656311
# BATCH NUM: 380
# BATCH LOSS: 0.0013758809072896838
# BATCH NUM: 390
# BATCH LOSS: 0.27148208022117615
# BATCH NUM: 400
# BATCH LOSS: 0.0007520733051933348
# BATCH NUM: 410
# BATCH LOSS: 0.023141855373978615
# BATCH NUM: 420
# BATCH LOSS: 0.007242437452077866
# BATCH NUM: 430
# BATCH LOSS: 0.0026266479399055243
# BATCH NUM: 440
# BATCH LOSS: 0.0008479022071696818
# BATCH NUM: 450
# BATCH LOSS: 0.025079216808080673
# EPOCH:  33
# LOSS:  0.0611047374439699
# TRAIN ACC:  0.9803215077605322
# Epoch    34: reducing learning rate of group 0 to 2.5000e-04.
# EPOCH:  33
# LOSS:  2.9386827305030425
# VALID ACC:  0.8266666666666667
# BATCH NUM: 0
# BATCH LOSS: 7.375979294010904e-06
# BATCH NUM: 10
# BATCH LOSS: 0.001648343401029706
# BATCH NUM: 20
# BATCH LOSS: 0.0006712024915032089
# BATCH NUM: 30
# BATCH LOSS: 9.34934287215583e-05
# BATCH NUM: 40
# BATCH LOSS: 0.007021963130682707
# BATCH NUM: 50
# BATCH LOSS: 0.006759013514965773
# BATCH NUM: 60
# BATCH LOSS: 0.034255921840667725
# BATCH NUM: 70
# BATCH LOSS: 0.009233389981091022
# BATCH NUM: 80
# BATCH LOSS: 0.0004634288197848946
# BATCH NUM: 90
# BATCH LOSS: 0.13775037229061127
# BATCH NUM: 100
# BATCH LOSS: 0.02304708957672119
# BATCH NUM: 110
# BATCH LOSS: 0.0012790465261787176
# BATCH NUM: 120
# BATCH LOSS: 0.03671375662088394
# BATCH NUM: 130
# BATCH LOSS: 0.00012992892879992723
# BATCH NUM: 140
# BATCH LOSS: 0.00011064872524002567
# BATCH NUM: 150
# BATCH LOSS: 0.054443683475255966
# BATCH NUM: 160
# BATCH LOSS: 0.07534019649028778
# BATCH NUM: 170
# BATCH LOSS: 0.00023395275638904423
# BATCH NUM: 180
# BATCH LOSS: 0.007806069683283567
# BATCH NUM: 190
# BATCH LOSS: 0.05842893570661545
# BATCH NUM: 200
# BATCH LOSS: 0.002988042775541544
# BATCH NUM: 210
# BATCH LOSS: 0.004375732038170099
# BATCH NUM: 220
# BATCH LOSS: 0.000623657600954175
# BATCH NUM: 230
# BATCH LOSS: 0.022625375539064407
# BATCH NUM: 240
# BATCH LOSS: 0.002780256560072303
# BATCH NUM: 250
# BATCH LOSS: 0.012813818641006947
# BATCH NUM: 260
# BATCH LOSS: 0.0068325139582157135
# BATCH NUM: 270
# BATCH LOSS: 0.004141305107623339
# BATCH NUM: 280
# BATCH LOSS: 0.0021081415470689535
# BATCH NUM: 290
# BATCH LOSS: 0.0005018102237954736
# BATCH NUM: 300
# BATCH LOSS: 0.0020239371806383133
# BATCH NUM: 310
# BATCH LOSS: 0.0027652056887745857
# BATCH NUM: 320
# BATCH LOSS: 0.21388572454452515
# BATCH NUM: 330
# BATCH LOSS: 0.0013714460656046867
# BATCH NUM: 340
# BATCH LOSS: 0.27842941880226135
# BATCH NUM: 350
# BATCH LOSS: 0.04832393676042557
# BATCH NUM: 360
# BATCH LOSS: 0.0007296724361367524
# BATCH NUM: 370
# BATCH LOSS: 0.052104998379945755
# BATCH NUM: 380
# BATCH LOSS: 6.412081711459905e-05
# BATCH NUM: 390
# BATCH LOSS: 0.008402980864048004
# BATCH NUM: 400
# BATCH LOSS: 0.00011806789552792907
# BATCH NUM: 410
# BATCH LOSS: 0.011854803189635277
# BATCH NUM: 420
# BATCH LOSS: 0.20604293048381805
# BATCH NUM: 430
# BATCH LOSS: 0.001508851652033627
# BATCH NUM: 440
# BATCH LOSS: 0.0006681068334728479
# BATCH NUM: 450
# BATCH LOSS: 0.011042382568120956
# EPOCH:  34
# LOSS:  0.038422849953364875
# TRAIN ACC:  0.9864190687361419
# EPOCH:  34
# LOSS:  2.9901628374919165
# VALID ACC:  0.8266666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.375824511051178
# BATCH NUM: 10
# BATCH LOSS: 8.466494182357565e-05
# BATCH NUM: 20
# BATCH LOSS: 0.02989085577428341
# BATCH NUM: 30
# BATCH LOSS: 0.0009578509489074349
# BATCH NUM: 40
# BATCH LOSS: 0.019906898960471153
# BATCH NUM: 50
# BATCH LOSS: 0.020509950816631317
# BATCH NUM: 60
# BATCH LOSS: 0.0112858135253191
# BATCH NUM: 70
# BATCH LOSS: 0.003989934455603361
# BATCH NUM: 80
# BATCH LOSS: 0.006197663955390453
# BATCH NUM: 90
# BATCH LOSS: 0.0015614554286003113
# BATCH NUM: 100
# BATCH LOSS: 0.1687127947807312
# BATCH NUM: 110
# BATCH LOSS: 0.0034894440323114395
# BATCH NUM: 120
# BATCH LOSS: 0.001931629958562553
# BATCH NUM: 130
# BATCH LOSS: 0.08905023336410522
# BATCH NUM: 140
# BATCH LOSS: 0.020912183448672295
# BATCH NUM: 150
# BATCH LOSS: 0.15690436959266663
# BATCH NUM: 160
# BATCH LOSS: 0.03615335747599602
# BATCH NUM: 170
# BATCH LOSS: 0.0005370261496864259
# BATCH NUM: 180
# BATCH LOSS: 0.009978377260267735
# BATCH NUM: 190
# BATCH LOSS: 0.01543936412781477
# BATCH NUM: 200
# BATCH LOSS: 0.23380188643932343
# BATCH NUM: 210
# BATCH LOSS: 0.04054480046033859
# BATCH NUM: 220
# BATCH LOSS: 5.701631016563624e-05
# BATCH NUM: 230
# BATCH LOSS: 0.8805338740348816
# BATCH NUM: 240
# BATCH LOSS: 0.004469843115657568
# BATCH NUM: 250
# BATCH LOSS: 7.548728171968833e-05
# BATCH NUM: 260
# BATCH LOSS: 0.005479409359395504
# BATCH NUM: 270
# BATCH LOSS: 8.060312393354252e-05
# BATCH NUM: 280
# BATCH LOSS: 0.006145104765892029
# BATCH NUM: 290
# BATCH LOSS: 0.002221130533143878
# BATCH NUM: 300
# BATCH LOSS: 0.04941032826900482
# BATCH NUM: 310
# BATCH LOSS: 0.001076960819773376
# BATCH NUM: 320
# BATCH LOSS: 0.0003785514272749424
# BATCH NUM: 330
# BATCH LOSS: 0.0008213866385631263
# BATCH NUM: 340
# BATCH LOSS: 0.006887705065310001
# BATCH NUM: 350
# BATCH LOSS: 0.004519542679190636
# BATCH NUM: 360
# BATCH LOSS: 0.03625534102320671
# BATCH NUM: 370
# BATCH LOSS: 0.009476431645452976
# BATCH NUM: 380
# BATCH LOSS: 0.014008782804012299
# BATCH NUM: 390
# BATCH LOSS: 0.012963694520294666
# BATCH NUM: 400
# BATCH LOSS: 0.00012653981684707105
# BATCH NUM: 410
# BATCH LOSS: 0.0007575872587040067
# BATCH NUM: 420
# BATCH LOSS: 0.03633962944149971
# BATCH NUM: 430
# BATCH LOSS: 0.0018462386215105653
# BATCH NUM: 440
# BATCH LOSS: 0.0362970307469368
# BATCH NUM: 450
# BATCH LOSS: 0.24054116010665894
# EPOCH:  35
# LOSS:  0.04152980906324956
# TRAIN ACC:  0.9861419068736141
# EPOCH:  35
# LOSS:  2.9742361773740043
# VALID ACC:  0.8308333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.02517952211201191
# BATCH NUM: 10
# BATCH LOSS: 0.0014858171343803406
# BATCH NUM: 20
# BATCH LOSS: 0.0016765018226578832
# BATCH NUM: 30
# BATCH LOSS: 0.010956995189189911
# BATCH NUM: 40
# BATCH LOSS: 0.0017835317412391305
# BATCH NUM: 50
# BATCH LOSS: 0.0016497496981173754
# BATCH NUM: 60
# BATCH LOSS: 0.0014895679196342826
# BATCH NUM: 70
# BATCH LOSS: 0.0009203752852045
# BATCH NUM: 80
# BATCH LOSS: 0.010379672050476074
# BATCH NUM: 90
# BATCH LOSS: 0.009992384351789951
# BATCH NUM: 100
# BATCH LOSS: 0.0001430147822247818
# BATCH NUM: 110
# BATCH LOSS: 0.002325758570805192
# BATCH NUM: 120
# BATCH LOSS: 0.05011969432234764
# BATCH NUM: 130
# BATCH LOSS: 0.0003230573784094304
# BATCH NUM: 140
# BATCH LOSS: 7.169686432462186e-05
# BATCH NUM: 150
# BATCH LOSS: 0.0004394971183501184
# BATCH NUM: 160
# BATCH LOSS: 0.0009674420580267906
# BATCH NUM: 170
# BATCH LOSS: 0.01821371540427208
# BATCH NUM: 180
# BATCH LOSS: 0.008512970991432667
# BATCH NUM: 190
# BATCH LOSS: 0.016272053122520447
# BATCH NUM: 200
# BATCH LOSS: 0.0003844125894829631
# BATCH NUM: 210
# BATCH LOSS: 0.014252755790948868
# BATCH NUM: 220
# BATCH LOSS: 0.027169428765773773
# BATCH NUM: 230
# BATCH LOSS: 0.08617305010557175
# BATCH NUM: 240
# BATCH LOSS: 6.785578443668783e-05
# BATCH NUM: 250
# BATCH LOSS: 0.008910803124308586
# BATCH NUM: 260
# BATCH LOSS: 0.4738404452800751
# BATCH NUM: 270
# BATCH LOSS: 0.013732131570577621
# BATCH NUM: 280
# BATCH LOSS: 0.029466234147548676
# BATCH NUM: 290
# BATCH LOSS: 0.026384055614471436
# BATCH NUM: 300
# BATCH LOSS: 0.10703691095113754
# BATCH NUM: 310
# BATCH LOSS: 0.0015658001648262143
# BATCH NUM: 320
# BATCH LOSS: 0.3769960105419159
# BATCH NUM: 330
# BATCH LOSS: 0.5960482954978943
# BATCH NUM: 340
# BATCH LOSS: 0.0001173272539745085
# BATCH NUM: 350
# BATCH LOSS: 0.0013483439106494188
# BATCH NUM: 360
# BATCH LOSS: 0.0036524164024740458
# BATCH NUM: 370
# BATCH LOSS: 0.004579431843012571
# BATCH NUM: 380
# BATCH LOSS: 0.00025066579109989107
# BATCH NUM: 390
# BATCH LOSS: 0.0764697715640068
# BATCH NUM: 400
# BATCH LOSS: 0.0005441890098154545
# BATCH NUM: 410
# BATCH LOSS: 0.3150590658187866
# BATCH NUM: 420
# BATCH LOSS: 0.0004042100626975298
# BATCH NUM: 430
# BATCH LOSS: 0.00584015529602766
# BATCH NUM: 440
# BATCH LOSS: 0.0032602334395051003
# BATCH NUM: 450
# BATCH LOSS: 6.192352157086134e-05
# EPOCH:  36
# LOSS:  0.035206254045619466
# TRAIN ACC:  0.9886363636363636
# EPOCH:  36
# LOSS:  2.9708574678988127
# VALID ACC:  0.84
# BATCH NUM: 0
# BATCH LOSS: 0.017480337992310524
# BATCH NUM: 10
# BATCH LOSS: 0.0015737094217911363
# BATCH NUM: 20
# BATCH LOSS: 0.013902943581342697
# BATCH NUM: 30
# BATCH LOSS: 0.003581896424293518
# BATCH NUM: 40
# BATCH LOSS: 0.0094290217384696
# BATCH NUM: 50
# BATCH LOSS: 0.001387106953188777
# BATCH NUM: 60
# BATCH LOSS: 0.07521045953035355
# BATCH NUM: 70
# BATCH LOSS: 0.025455806404352188
# BATCH NUM: 80
# BATCH LOSS: 0.0036057205870747566
# BATCH NUM: 90
# BATCH LOSS: 0.0004036474274471402
# BATCH NUM: 100
# BATCH LOSS: 0.022182779386639595
# BATCH NUM: 110
# BATCH LOSS: 0.05838582664728165
# BATCH NUM: 120
# BATCH LOSS: 0.002295399783179164
# BATCH NUM: 130
# BATCH LOSS: 0.00012848051846958697
# BATCH NUM: 140
# BATCH LOSS: 0.0017581932479515672
# BATCH NUM: 150
# BATCH LOSS: 0.20380574464797974
# BATCH NUM: 160
# BATCH LOSS: 0.00037072552368044853
# BATCH NUM: 170
# BATCH LOSS: 0.005220669321715832
# BATCH NUM: 180
# BATCH LOSS: 0.1282861828804016
# BATCH NUM: 190
# BATCH LOSS: 0.007476812228560448
# BATCH NUM: 200
# BATCH LOSS: 0.004049144685268402
# BATCH NUM: 210
# BATCH LOSS: 0.006333800498396158
# BATCH NUM: 220
# BATCH LOSS: 0.0006609936244785786
# BATCH NUM: 230
# BATCH LOSS: 0.0027662161737680435
# BATCH NUM: 240
# BATCH LOSS: 0.0001377417502226308
# BATCH NUM: 250
# BATCH LOSS: 0.23295782506465912
# BATCH NUM: 260
# BATCH LOSS: 0.0009223300730809569
# BATCH NUM: 270
# BATCH LOSS: 0.008166573010385036
# BATCH NUM: 280
# BATCH LOSS: 0.0018454352393746376
# BATCH NUM: 290
# BATCH LOSS: 0.11053507030010223
# BATCH NUM: 300
# BATCH LOSS: 0.003369169542565942
# BATCH NUM: 310
# BATCH LOSS: 0.0016777785494923592
# BATCH NUM: 320
# BATCH LOSS: 0.014953050762414932
# BATCH NUM: 330
# BATCH LOSS: 0.00048800691729411483
# BATCH NUM: 340
# BATCH LOSS: 0.008613127283751965
# BATCH NUM: 350
# BATCH LOSS: 0.005818965379148722
# BATCH NUM: 360
# BATCH LOSS: 0.01589314080774784
# BATCH NUM: 370
# BATCH LOSS: 0.0010746748885139823
# BATCH NUM: 380
# BATCH LOSS: 0.003966720309108496
# BATCH NUM: 390
# BATCH LOSS: 0.00010944265522994101
# BATCH NUM: 400
# BATCH LOSS: 0.010810421779751778
# BATCH NUM: 410
# BATCH LOSS: 0.005174623802304268
# BATCH NUM: 420
# BATCH LOSS: 0.03095974214375019
# BATCH NUM: 430
# BATCH LOSS: 0.0014658012660220265
# BATCH NUM: 440
# BATCH LOSS: 0.0002840907545760274
# BATCH NUM: 450
# BATCH LOSS: 0.030285334214568138
# EPOCH:  37
# LOSS:  0.029304987814021945
# TRAIN ACC:  0.989190687361419
# EPOCH:  37
# LOSS:  2.962588306643967
# VALID ACC:  0.8358333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.0025831423699855804
# BATCH NUM: 10
# BATCH LOSS: 0.003761078929528594
# BATCH NUM: 20
# BATCH LOSS: 0.00716716144233942
# BATCH NUM: 30
# BATCH LOSS: 1.71657793544e-05
# BATCH NUM: 40
# BATCH LOSS: 0.00029144607833586633
# BATCH NUM: 50
# BATCH LOSS: 0.08249188214540482
# BATCH NUM: 60
# BATCH LOSS: 0.03306606039404869
# BATCH NUM: 70
# BATCH LOSS: 0.010469101369380951
# BATCH NUM: 80
# BATCH LOSS: 0.00028302258579060435
# BATCH NUM: 90
# BATCH LOSS: 0.0006963732303120196
# BATCH NUM: 100
# BATCH LOSS: 0.005108811426907778
# BATCH NUM: 110
# BATCH LOSS: 0.1316991150379181
# BATCH NUM: 120
# BATCH LOSS: 0.00018600963812787086
# BATCH NUM: 130
# BATCH LOSS: 0.039460502564907074
# BATCH NUM: 140
# BATCH LOSS: 0.027667198330163956
# BATCH NUM: 150
# BATCH LOSS: 0.005683954805135727
# BATCH NUM: 160
# BATCH LOSS: 0.0005015244241803885
# BATCH NUM: 170
# BATCH LOSS: 0.00046418540296144783
# BATCH NUM: 180
# BATCH LOSS: 0.0012449598871171474
# BATCH NUM: 190
# BATCH LOSS: 0.0001044033415382728
# BATCH NUM: 200
# BATCH LOSS: 0.0001936434127856046
# BATCH NUM: 210
# BATCH LOSS: 0.0005165446782484651
# BATCH NUM: 220
# BATCH LOSS: 0.0010213312925770879
# BATCH NUM: 230
# BATCH LOSS: 0.02094203792512417
# BATCH NUM: 240
# BATCH LOSS: 0.004387258552014828
# BATCH NUM: 250
# BATCH LOSS: 0.0012041173176839948
# BATCH NUM: 260
# BATCH LOSS: 0.05891023203730583
# BATCH NUM: 270
# BATCH LOSS: 0.006775503046810627
# BATCH NUM: 280
# BATCH LOSS: 5.213556869421154e-05
# BATCH NUM: 290
# BATCH LOSS: 3.069609874728485e-06
# BATCH NUM: 300
# BATCH LOSS: 0.001574019668623805
# BATCH NUM: 310
# BATCH LOSS: 0.18862700462341309
# BATCH NUM: 320
# BATCH LOSS: 0.00021650467533618212
# BATCH NUM: 330
# BATCH LOSS: 0.004717756994068623
# BATCH NUM: 340
# BATCH LOSS: 0.04027380421757698
# BATCH NUM: 350
# BATCH LOSS: 0.012582716532051563
# BATCH NUM: 360
# BATCH LOSS: 0.08488244563341141
# BATCH NUM: 370
# BATCH LOSS: 0.0006855471874587238
# BATCH NUM: 380
# BATCH LOSS: 0.009610801003873348
# BATCH NUM: 390
# BATCH LOSS: 8.069953764788806e-05
# BATCH NUM: 400
# BATCH LOSS: 0.0003812959184870124
# BATCH NUM: 410
# BATCH LOSS: 0.000490545469801873
# BATCH NUM: 420
# BATCH LOSS: 0.00014705030480399728
# BATCH NUM: 430
# BATCH LOSS: 0.006624309811741114
# BATCH NUM: 440
# BATCH LOSS: 0.001917842193506658
# BATCH NUM: 450
# BATCH LOSS: 6.976217991905287e-05
# EPOCH:  38
# LOSS:  0.02843463141776283
# TRAIN ACC:  0.991130820399113
# EPOCH:  38
# LOSS:  2.9903820587395535
# VALID ACC:  0.8383333333333334
# BATCH NUM: 0
# BATCH LOSS: 0.00014639402797911316
# BATCH NUM: 10
# BATCH LOSS: 0.008371532894670963
# BATCH NUM: 20
# BATCH LOSS: 9.594713628757745e-05
# BATCH NUM: 30
# BATCH LOSS: 0.0017320339102298021
# BATCH NUM: 40
# BATCH LOSS: 0.002450009807944298
# BATCH NUM: 50
# BATCH LOSS: 0.0004296400584280491
# BATCH NUM: 60
# BATCH LOSS: 4.808015000890009e-05
# BATCH NUM: 70
# BATCH LOSS: 0.3503130078315735
# BATCH NUM: 80
# BATCH LOSS: 0.0013452129205688834
# BATCH NUM: 90
# BATCH LOSS: 0.0012213388690724969
# BATCH NUM: 100
# BATCH LOSS: 0.0003715974744409323
# BATCH NUM: 110
# BATCH LOSS: 0.0034144027158617973
# BATCH NUM: 120
# BATCH LOSS: 0.028135597705841064
# BATCH NUM: 130
# BATCH LOSS: 0.013661966659128666
# BATCH NUM: 140
# BATCH LOSS: 0.0012103323824703693
# BATCH NUM: 150
# BATCH LOSS: 0.00038290856173262
# BATCH NUM: 160
# BATCH LOSS: 9.808121831156313e-05
# BATCH NUM: 170
# BATCH LOSS: 7.948763231979683e-05
# BATCH NUM: 180
# BATCH LOSS: 0.094084233045578
# BATCH NUM: 190
# BATCH LOSS: 0.006227714475244284
# BATCH NUM: 200
# BATCH LOSS: 5.804624015581794e-05
# BATCH NUM: 210
# BATCH LOSS: 0.0009344751015305519
# BATCH NUM: 220
# BATCH LOSS: 0.00010144902626052499
# BATCH NUM: 230
# BATCH LOSS: 0.00011706386430887505
# BATCH NUM: 240
# BATCH LOSS: 0.0011136524844914675
# BATCH NUM: 250
# BATCH LOSS: 0.00453193811699748
# BATCH NUM: 260
# BATCH LOSS: 0.008529801853001118
# BATCH NUM: 270
# BATCH LOSS: 0.004841282963752747
# BATCH NUM: 280
# BATCH LOSS: 1.6599049558863044e-05
# BATCH NUM: 290
# BATCH LOSS: 9.834685624809936e-05
# BATCH NUM: 300
# BATCH LOSS: 0.004640594590455294
# BATCH NUM: 310
# BATCH LOSS: 0.006895822938531637
# BATCH NUM: 320
# BATCH LOSS: 0.00031233011395670474
# BATCH NUM: 330
# BATCH LOSS: 0.0012655941536650062
# BATCH NUM: 340
# BATCH LOSS: 0.0009898697026073933
# BATCH NUM: 350
# BATCH LOSS: 0.10915597528219223
# BATCH NUM: 360
# BATCH LOSS: 0.0009190858108922839
# BATCH NUM: 370
# BATCH LOSS: 0.0011199199361726642
# BATCH NUM: 380
# BATCH LOSS: 0.0053693633526563644
# BATCH NUM: 390
# BATCH LOSS: 0.0002570846991147846
# BATCH NUM: 400
# BATCH LOSS: 0.008261622861027718
# BATCH NUM: 410
# BATCH LOSS: 0.01728091388940811
# BATCH NUM: 420
# BATCH LOSS: 0.08493859320878983
# BATCH NUM: 430
# BATCH LOSS: 0.312408447265625
# BATCH NUM: 440
# BATCH LOSS: 0.002077175071462989
# BATCH NUM: 450
# BATCH LOSS: 0.09599800407886505
# EPOCH:  39
# LOSS:  0.021875242808708006
# TRAIN ACC:  0.9925166297117517
# EPOCH:  39
# LOSS:  2.9761036493890582
# VALID ACC:  0.8358333333333333

# %%
network.eval()
correct = 0.0
total = 0.0
with torch.no_grad():
  for batch_num, (x, y, x_len) in enumerate(test_loader):
      y = torch.Tensor(y)
      x, y = x.to(device), y.to(device)
      out = network(x, x_len, 'test')
      loss = criterion(out, y.long())
      avg_loss += loss.item()
      pred = torch.argmax(out, dim = 1).cpu().numpy()
      true = y.cpu().numpy()
      correct += np.sum(pred == true)
      total += batch_size
print(correct/total)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 0.9006622516556292

# %%
# Baseline Model hyperparameters
actions_num = 36
num_epochs = 40

learning_rate = 1e-3
weight_decay = 5e-5

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = CNN_LSTM(phoneme_num, actions_num, phoneme_num, pretrain = True)
network = network.to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(network.parameters(), lr = learning_rate, weight_decay=weight_decay)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, \
  patience=3, threshold=0.0001, threshold_mode='rel', cooldown=3, min_lr=0, eps=1e-08, verbose=True)

# %%
for epoch in range(num_epochs):
    # Train
    network.train()
    correct = 0.0
    total = 0
    avg_loss = 0.0
    for batch_num, (x, y, x_len) in enumerate(train_loader):
        optimizer.zero_grad()
        y = torch.Tensor(y)
        x, y = x.to(device), y.to(device)
        out = network(x, x_len, 'train')
        loss = criterion(out, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()
        pred = torch.argmax(out, dim = 1).cpu().numpy()
        true = y.cpu().numpy()
        correct += np.sum(pred == true)
        total += batch_size
        if batch_num % 10 == 0:
          print("BATCH NUM:", batch_num)
          print("BATCH LOSS:", loss.item())

    print("EPOCH: ", epoch)
    print("LOSS: ", avg_loss / batch_num)
    print("TRAIN ACC: ", correct / total)
    scheduler.step(avg_loss)
    correct = 0.0
    total = 0
    avg_loss = 0.0
    network.eval()
    with torch.no_grad():
      for batch_num, (x, y, x_len) in enumerate(dev_loader):
          y = torch.Tensor(y)
          x, y = x.to(device), y.to(device)
          out = network(x, x_len, 'dev')
          loss = criterion(out, y.long())
          avg_loss += loss.item()
          pred = torch.argmax(out, dim = 1).cpu().numpy()
          true = y.cpu().numpy()
          correct += np.sum(pred == true)
          total += batch_size
    print("EPOCH: ", epoch)
    print("LOSS: ", avg_loss / batch_num)
    print("VALID ACC: ", correct / total)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# BATCH NUM: 0
# BATCH LOSS: 3.639611005783081
# BATCH NUM: 10
# BATCH LOSS: 3.6981654167175293
# BATCH NUM: 20
# BATCH LOSS: 3.5624847412109375
# BATCH NUM: 30
# BATCH LOSS: 3.5395774841308594
# BATCH NUM: 40
# BATCH LOSS: 3.56912899017334
# BATCH NUM: 50
# BATCH LOSS: 3.58838152885437
# BATCH NUM: 60
# BATCH LOSS: 3.6796164512634277
# BATCH NUM: 70
# BATCH LOSS: 3.5833353996276855
# BATCH NUM: 80
# BATCH LOSS: 3.5716745853424072
# BATCH NUM: 90
# BATCH LOSS: 3.584365129470825
# BATCH NUM: 100
# BATCH LOSS: 3.755573034286499
# BATCH NUM: 110
# BATCH LOSS: 3.5094223022460938
# BATCH NUM: 120
# BATCH LOSS: 3.6206047534942627
# BATCH NUM: 130
# BATCH LOSS: 3.5220744609832764
# BATCH NUM: 140
# BATCH LOSS: 3.0708060264587402
# BATCH NUM: 150
# BATCH LOSS: 3.349790096282959
# BATCH NUM: 160
# BATCH LOSS: 3.362287759780884
# BATCH NUM: 170
# BATCH LOSS: 3.2244904041290283
# BATCH NUM: 180
# BATCH LOSS: 3.5970730781555176
# BATCH NUM: 190
# BATCH LOSS: 2.688559055328369
# BATCH NUM: 200
# BATCH LOSS: 2.851349115371704
# BATCH NUM: 210
# BATCH LOSS: 3.357717990875244
# BATCH NUM: 220
# BATCH LOSS: 2.684115171432495
# BATCH NUM: 230
# BATCH LOSS: 2.5062291622161865
# BATCH NUM: 240
# BATCH LOSS: 2.6563873291015625
# BATCH NUM: 250
# BATCH LOSS: 2.3821775913238525
# BATCH NUM: 260
# BATCH LOSS: 3.012596368789673
# BATCH NUM: 270
# BATCH LOSS: 2.404778003692627
# BATCH NUM: 280
# BATCH LOSS: 2.400634527206421
# BATCH NUM: 290
# BATCH LOSS: 2.1284730434417725
# BATCH NUM: 300
# BATCH LOSS: 2.1125247478485107
# BATCH NUM: 310
# BATCH LOSS: 1.6944661140441895
# BATCH NUM: 320
# BATCH LOSS: 2.6401150226593018
# BATCH NUM: 330
# BATCH LOSS: 2.1775150299072266
# BATCH NUM: 340
# BATCH LOSS: 1.897870659828186
# BATCH NUM: 350
# BATCH LOSS: 1.6918351650238037
# BATCH NUM: 360
# BATCH LOSS: 1.9011774063110352
# BATCH NUM: 370
# BATCH LOSS: 1.5942946672439575
# BATCH NUM: 380
# BATCH LOSS: 2.1361396312713623
# BATCH NUM: 390
# BATCH LOSS: 2.114692211151123
# BATCH NUM: 400
# BATCH LOSS: 2.019657850265503
# BATCH NUM: 410
# BATCH LOSS: 1.5841060876846313
# BATCH NUM: 420
# BATCH LOSS: 2.2387547492980957
# BATCH NUM: 430
# BATCH LOSS: 1.8778125047683716
# BATCH NUM: 440
# BATCH LOSS: 1.801184058189392
# BATCH NUM: 450
# BATCH LOSS: 2.5084023475646973
# EPOCH:  0
# LOSS:  2.8935948509640164
# TRAIN ACC:  0.1812638580931264
# EPOCH:  0
# LOSS:  2.0783495270965884
# VALID ACC:  0.4125
# BATCH NUM: 0
# BATCH LOSS: 1.6903066635131836
# BATCH NUM: 10
# BATCH LOSS: 1.7936536073684692
# BATCH NUM: 20
# BATCH LOSS: 2.015578269958496
# BATCH NUM: 30
# BATCH LOSS: 1.9336376190185547
# BATCH NUM: 40
# BATCH LOSS: 1.9507588148117065
# BATCH NUM: 50
# BATCH LOSS: 1.8559062480926514
# BATCH NUM: 60
# BATCH LOSS: 1.7011487483978271
# BATCH NUM: 70
# BATCH LOSS: 2.193613290786743
# BATCH NUM: 80
# BATCH LOSS: 1.9681904315948486
# BATCH NUM: 90
# BATCH LOSS: 1.1775612831115723
# BATCH NUM: 100
# BATCH LOSS: 2.2329959869384766
# BATCH NUM: 110
# BATCH LOSS: 2.084836483001709
# BATCH NUM: 120
# BATCH LOSS: 1.9304909706115723
# BATCH NUM: 130
# BATCH LOSS: 1.8593074083328247
# BATCH NUM: 140
# BATCH LOSS: 1.453641653060913
# BATCH NUM: 150
# BATCH LOSS: 2.7272279262542725
# BATCH NUM: 160
# BATCH LOSS: 1.8816267251968384
# BATCH NUM: 170
# BATCH LOSS: 2.9312069416046143
# BATCH NUM: 180
# BATCH LOSS: 2.188833475112915
# BATCH NUM: 190
# BATCH LOSS: 1.3463451862335205
# BATCH NUM: 200
# BATCH LOSS: 2.1800577640533447
# BATCH NUM: 210
# BATCH LOSS: 1.3559987545013428
# BATCH NUM: 220
# BATCH LOSS: 2.530383586883545
# BATCH NUM: 230
# BATCH LOSS: 1.8816673755645752
# BATCH NUM: 240
# BATCH LOSS: 1.4423259496688843
# BATCH NUM: 250
# BATCH LOSS: 1.626743197441101
# BATCH NUM: 260
# BATCH LOSS: 2.130963087081909
# BATCH NUM: 270
# BATCH LOSS: 1.0624010562896729
# BATCH NUM: 280
# BATCH LOSS: 1.870396614074707
# BATCH NUM: 290
# BATCH LOSS: 1.055802822113037
# BATCH NUM: 300
# BATCH LOSS: 1.3742307424545288
# BATCH NUM: 310
# BATCH LOSS: 1.495426893234253
# BATCH NUM: 320
# BATCH LOSS: 1.7142202854156494
# BATCH NUM: 330
# BATCH LOSS: 2.6439828872680664
# BATCH NUM: 340
# BATCH LOSS: 1.4301025867462158
# BATCH NUM: 350
# BATCH LOSS: 0.5059388875961304
# BATCH NUM: 360
# BATCH LOSS: 1.4541568756103516
# BATCH NUM: 370
# BATCH LOSS: 2.2134413719177246
# BATCH NUM: 380
# BATCH LOSS: 2.224808692932129
# BATCH NUM: 390
# BATCH LOSS: 1.5123791694641113
# BATCH NUM: 400
# BATCH LOSS: 1.5813950300216675
# BATCH NUM: 410
# BATCH LOSS: 1.8931940793991089
# BATCH NUM: 420
# BATCH LOSS: 1.6323357820510864
# BATCH NUM: 430
# BATCH LOSS: 1.8429522514343262
# BATCH NUM: 440
# BATCH LOSS: 1.1083481311798096
# BATCH NUM: 450
# BATCH LOSS: 0.6574943661689758
# EPOCH:  1
# LOSS:  1.6377295044395659
# TRAIN ACC:  0.4526053215077605
# EPOCH:  1
# LOSS:  1.9097792598225127
# VALID ACC:  0.535
# BATCH NUM: 0
# BATCH LOSS: 1.1259559392929077
# BATCH NUM: 10
# BATCH LOSS: 1.2327862977981567
# BATCH NUM: 20
# BATCH LOSS: 1.0828887224197388
# BATCH NUM: 30
# BATCH LOSS: 1.3190150260925293
# BATCH NUM: 40
# BATCH LOSS: 0.7291123270988464
# BATCH NUM: 50
# BATCH LOSS: 0.6933245062828064
# BATCH NUM: 60
# BATCH LOSS: 1.602097988128662
# BATCH NUM: 70
# BATCH LOSS: 0.6840997934341431
# BATCH NUM: 80
# BATCH LOSS: 0.4858890771865845
# BATCH NUM: 90
# BATCH LOSS: 0.775083065032959
# BATCH NUM: 100
# BATCH LOSS: 1.22099769115448
# BATCH NUM: 110
# BATCH LOSS: 0.847217857837677
# BATCH NUM: 120
# BATCH LOSS: 2.6926333904266357
# BATCH NUM: 130
# BATCH LOSS: 1.0885519981384277
# BATCH NUM: 140
# BATCH LOSS: 1.353281855583191
# BATCH NUM: 150
# BATCH LOSS: 0.7947874069213867
# BATCH NUM: 160
# BATCH LOSS: 1.2009963989257812
# BATCH NUM: 170
# BATCH LOSS: 1.3090572357177734
# BATCH NUM: 180
# BATCH LOSS: 0.6778356432914734
# BATCH NUM: 190
# BATCH LOSS: 1.1583305597305298
# BATCH NUM: 200
# BATCH LOSS: 0.9868122935295105
# BATCH NUM: 210
# BATCH LOSS: 1.181700348854065
# BATCH NUM: 220
# BATCH LOSS: 1.6932690143585205
# BATCH NUM: 230
# BATCH LOSS: 1.3984886407852173
# BATCH NUM: 240
# BATCH LOSS: 0.991683304309845
# BATCH NUM: 250
# BATCH LOSS: 1.4273263216018677
# BATCH NUM: 260
# BATCH LOSS: 0.17440931499004364
# BATCH NUM: 270
# BATCH LOSS: 1.4572911262512207
# BATCH NUM: 280
# BATCH LOSS: 1.3385820388793945
# BATCH NUM: 290
# BATCH LOSS: 0.5967264771461487
# BATCH NUM: 300
# BATCH LOSS: 2.136784553527832
# BATCH NUM: 310
# BATCH LOSS: 1.9479284286499023
# BATCH NUM: 320
# BATCH LOSS: 1.947770357131958
# BATCH NUM: 330
# BATCH LOSS: 1.6023824214935303
# BATCH NUM: 340
# BATCH LOSS: 1.9900315999984741
# BATCH NUM: 350
# BATCH LOSS: 1.017671823501587
# BATCH NUM: 360
# BATCH LOSS: 1.1083797216415405
# BATCH NUM: 370
# BATCH LOSS: 1.2786788940429688
# BATCH NUM: 380
# BATCH LOSS: 0.8616281151771545
# BATCH NUM: 390
# BATCH LOSS: 1.402549386024475
# BATCH NUM: 400
# BATCH LOSS: 0.7317033410072327
# BATCH NUM: 410
# BATCH LOSS: 0.8602456450462341
# BATCH NUM: 420
# BATCH LOSS: 0.647236168384552
# BATCH NUM: 430
# BATCH LOSS: 1.2806257009506226
# BATCH NUM: 440
# BATCH LOSS: 1.3043372631072998
# BATCH NUM: 450
# BATCH LOSS: 1.5286695957183838
# EPOCH:  2
# LOSS:  1.2005033140381178
# TRAIN ACC:  0.595620842572062
# EPOCH:  2
# LOSS:  1.7768014519406645
# VALID ACC:  0.62
# BATCH NUM: 0
# BATCH LOSS: 1.0179474353790283
# BATCH NUM: 10
# BATCH LOSS: 0.6468251347541809
# BATCH NUM: 20
# BATCH LOSS: 1.5583648681640625
# BATCH NUM: 30
# BATCH LOSS: 1.0416367053985596
# BATCH NUM: 40
# BATCH LOSS: 1.6259925365447998
# BATCH NUM: 50
# BATCH LOSS: 1.0092792510986328
# BATCH NUM: 60
# BATCH LOSS: 1.479600429534912
# BATCH NUM: 70
# BATCH LOSS: 0.5583871006965637
# BATCH NUM: 80
# BATCH LOSS: 0.5131564140319824
# BATCH NUM: 90
# BATCH LOSS: 0.2724311351776123
# BATCH NUM: 100
# BATCH LOSS: 0.3924061357975006
# BATCH NUM: 110
# BATCH LOSS: 0.595668613910675
# BATCH NUM: 120
# BATCH LOSS: 1.776808738708496
# BATCH NUM: 130
# BATCH LOSS: 1.743923544883728
# BATCH NUM: 140
# BATCH LOSS: 0.2862743139266968
# BATCH NUM: 150
# BATCH LOSS: 1.3857247829437256
# BATCH NUM: 160
# BATCH LOSS: 0.998457133769989
# BATCH NUM: 170
# BATCH LOSS: 0.550686240196228
# BATCH NUM: 180
# BATCH LOSS: 0.7108155488967896
# BATCH NUM: 190
# BATCH LOSS: 1.5825639963150024
# BATCH NUM: 200
# BATCH LOSS: 1.195014476776123
# BATCH NUM: 210
# BATCH LOSS: 0.6881597638130188
# BATCH NUM: 220
# BATCH LOSS: 0.5145706534385681
# BATCH NUM: 230
# BATCH LOSS: 0.8948824405670166
# BATCH NUM: 240
# BATCH LOSS: 0.9679082036018372
# BATCH NUM: 250
# BATCH LOSS: 0.9269657731056213
# BATCH NUM: 260
# BATCH LOSS: 1.8947476148605347
# BATCH NUM: 270
# BATCH LOSS: 0.6656842827796936
# BATCH NUM: 280
# BATCH LOSS: 0.22464202344417572
# BATCH NUM: 290
# BATCH LOSS: 0.7785556316375732
# BATCH NUM: 300
# BATCH LOSS: 1.0167253017425537
# BATCH NUM: 310
# BATCH LOSS: 0.28887447714805603
# BATCH NUM: 320
# BATCH LOSS: 0.583754301071167
# BATCH NUM: 330
# BATCH LOSS: 0.6756759881973267
# BATCH NUM: 340
# BATCH LOSS: 0.9104381203651428
# BATCH NUM: 350
# BATCH LOSS: 1.6272392272949219
# BATCH NUM: 360
# BATCH LOSS: 0.29901304841041565
# BATCH NUM: 370
# BATCH LOSS: 0.5304449200630188
# BATCH NUM: 380
# BATCH LOSS: 2.383148670196533
# BATCH NUM: 390
# BATCH LOSS: 1.140583872795105
# BATCH NUM: 400
# BATCH LOSS: 0.6365414261817932
# BATCH NUM: 410
# BATCH LOSS: 0.5902833342552185
# BATCH NUM: 420
# BATCH LOSS: 1.1619153022766113
# BATCH NUM: 430
# BATCH LOSS: 1.3691210746765137
# BATCH NUM: 440
# BATCH LOSS: 0.6018156409263611
# BATCH NUM: 450
# BATCH LOSS: 1.3098664283752441
# EPOCH:  3
# LOSS:  0.9461564276946915
# TRAIN ACC:  0.6812638580931264
# EPOCH:  3
# LOSS:  1.7489503621555014
# VALID ACC:  0.6991666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.3622468411922455
# BATCH NUM: 10
# BATCH LOSS: 1.4257782697677612
# BATCH NUM: 20
# BATCH LOSS: 0.8368451595306396
# BATCH NUM: 30
# BATCH LOSS: 1.962808609008789
# BATCH NUM: 40
# BATCH LOSS: 1.3444193601608276
# BATCH NUM: 50
# BATCH LOSS: 0.6388684511184692
# BATCH NUM: 60
# BATCH LOSS: 0.34916287660598755
# BATCH NUM: 70
# BATCH LOSS: 0.38362616300582886
# BATCH NUM: 80
# BATCH LOSS: 0.8657517433166504
# BATCH NUM: 90
# BATCH LOSS: 1.941296100616455
# BATCH NUM: 100
# BATCH LOSS: 0.31371018290519714
# BATCH NUM: 110
# BATCH LOSS: 0.9102975130081177
# BATCH NUM: 120
# BATCH LOSS: 0.5907819867134094
# BATCH NUM: 130
# BATCH LOSS: 0.4911973774433136
# BATCH NUM: 140
# BATCH LOSS: 0.9391947984695435
# BATCH NUM: 150
# BATCH LOSS: 0.7149912714958191
# BATCH NUM: 160
# BATCH LOSS: 0.929404616355896
# BATCH NUM: 170
# BATCH LOSS: 2.081512689590454
# BATCH NUM: 180
# BATCH LOSS: 0.8721621036529541
# BATCH NUM: 190
# BATCH LOSS: 0.2982839345932007
# BATCH NUM: 200
# BATCH LOSS: 1.1894416809082031
# BATCH NUM: 210
# BATCH LOSS: 1.0001291036605835
# BATCH NUM: 220
# BATCH LOSS: 0.3335409462451935
# BATCH NUM: 230
# BATCH LOSS: 0.3014334738254547
# BATCH NUM: 240
# BATCH LOSS: 0.45029890537261963
# BATCH NUM: 250
# BATCH LOSS: 1.1362864971160889
# BATCH NUM: 260
# BATCH LOSS: 0.2670309841632843
# BATCH NUM: 270
# BATCH LOSS: 1.1745566129684448
# BATCH NUM: 280
# BATCH LOSS: 0.7625156044960022
# BATCH NUM: 290
# BATCH LOSS: 0.2916978895664215
# BATCH NUM: 300
# BATCH LOSS: 0.2778663635253906
# BATCH NUM: 310
# BATCH LOSS: 0.9549020528793335
# BATCH NUM: 320
# BATCH LOSS: 1.1195335388183594
# BATCH NUM: 330
# BATCH LOSS: 1.859879732131958
# BATCH NUM: 340
# BATCH LOSS: 0.939113974571228
# BATCH NUM: 350
# BATCH LOSS: 0.4492667019367218
# BATCH NUM: 360
# BATCH LOSS: 0.4142388105392456
# BATCH NUM: 370
# BATCH LOSS: 0.9679577350616455
# BATCH NUM: 380
# BATCH LOSS: 0.10769487917423248
# BATCH NUM: 390
# BATCH LOSS: 0.3544986844062805
# BATCH NUM: 400
# BATCH LOSS: 0.6054893732070923
# BATCH NUM: 410
# BATCH LOSS: 0.6823022365570068
# BATCH NUM: 420
# BATCH LOSS: 0.11437132209539413
# BATCH NUM: 430
# BATCH LOSS: 0.19314263761043549
# BATCH NUM: 440
# BATCH LOSS: 1.491335153579712
# BATCH NUM: 450
# BATCH LOSS: 1.7242134809494019
# EPOCH:  4
# LOSS:  0.7446711260245906
# TRAIN ACC:  0.7577605321507761
# EPOCH:  4
# LOSS:  1.704181404771821
# VALID ACC:  0.7408333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.6643058061599731
# BATCH NUM: 10
# BATCH LOSS: 0.5603823661804199
# BATCH NUM: 20
# BATCH LOSS: 1.532727599143982
# BATCH NUM: 30
# BATCH LOSS: 0.18709354102611542
# BATCH NUM: 40
# BATCH LOSS: 1.5584838390350342
# BATCH NUM: 50
# BATCH LOSS: 0.15316037833690643
# BATCH NUM: 60
# BATCH LOSS: 0.7611502408981323
# BATCH NUM: 70
# BATCH LOSS: 0.025159090757369995
# BATCH NUM: 80
# BATCH LOSS: 0.5938330888748169
# BATCH NUM: 90
# BATCH LOSS: 0.9751445055007935
# BATCH NUM: 100
# BATCH LOSS: 0.386459618806839
# BATCH NUM: 110
# BATCH LOSS: 0.5601820349693298
# BATCH NUM: 120
# BATCH LOSS: 0.11215595155954361
# BATCH NUM: 130
# BATCH LOSS: 0.4762820601463318
# BATCH NUM: 140
# BATCH LOSS: 0.37257903814315796
# BATCH NUM: 150
# BATCH LOSS: 0.7026087641716003
# BATCH NUM: 160
# BATCH LOSS: 0.4674306809902191
# BATCH NUM: 170
# BATCH LOSS: 0.43986788392066956
# BATCH NUM: 180
# BATCH LOSS: 0.7505974769592285
# BATCH NUM: 190
# BATCH LOSS: 0.6329131126403809
# BATCH NUM: 200
# BATCH LOSS: 0.5634364485740662
# BATCH NUM: 210
# BATCH LOSS: 0.6538524031639099
# BATCH NUM: 220
# BATCH LOSS: 0.6184879541397095
# BATCH NUM: 230
# BATCH LOSS: 0.7429722547531128
# BATCH NUM: 240
# BATCH LOSS: 0.401409775018692
# BATCH NUM: 250
# BATCH LOSS: 0.8162822723388672
# BATCH NUM: 260
# BATCH LOSS: 1.5601204633712769
# BATCH NUM: 270
# BATCH LOSS: 0.8817968964576721
# BATCH NUM: 280
# BATCH LOSS: 1.121810793876648
# BATCH NUM: 290
# BATCH LOSS: 0.08855769038200378
# BATCH NUM: 300
# BATCH LOSS: 0.3788779079914093
# BATCH NUM: 310
# BATCH LOSS: 0.6099111437797546
# BATCH NUM: 320
# BATCH LOSS: 0.6095670461654663
# BATCH NUM: 330
# BATCH LOSS: 0.6578694581985474
# BATCH NUM: 340
# BATCH LOSS: 0.30413952469825745
# BATCH NUM: 350
# BATCH LOSS: 0.20868420600891113
# BATCH NUM: 360
# BATCH LOSS: 0.735497236251831
# BATCH NUM: 370
# BATCH LOSS: 0.706415593624115
# BATCH NUM: 380
# BATCH LOSS: 0.5871667861938477
# BATCH NUM: 390
# BATCH LOSS: 0.7279053926467896
# BATCH NUM: 400
# BATCH LOSS: 1.168208360671997
# BATCH NUM: 410
# BATCH LOSS: 1.0589298009872437
# BATCH NUM: 420
# BATCH LOSS: 0.44717392325401306
# BATCH NUM: 430
# BATCH LOSS: 0.7447839975357056
# BATCH NUM: 440
# BATCH LOSS: 0.08687035739421844
# BATCH NUM: 450
# BATCH LOSS: 0.07778247445821762
# EPOCH:  5
# LOSS:  0.5986302919189135
# TRAIN ACC:  0.8143015521064302
# EPOCH:  5
# LOSS:  1.6634386630053788
# VALID ACC:  0.7666666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.6739711761474609
# BATCH NUM: 10
# BATCH LOSS: 0.08417706191539764
# BATCH NUM: 20
# BATCH LOSS: 0.92622309923172
# BATCH NUM: 30
# BATCH LOSS: 0.8446906208992004
# BATCH NUM: 40
# BATCH LOSS: 0.9092686176300049
# BATCH NUM: 50
# BATCH LOSS: 0.2592897117137909
# BATCH NUM: 60
# BATCH LOSS: 0.171879380941391
# BATCH NUM: 70
# BATCH LOSS: 0.3458786904811859
# BATCH NUM: 80
# BATCH LOSS: 0.3911437690258026
# BATCH NUM: 90
# BATCH LOSS: 0.5112922191619873
# BATCH NUM: 100
# BATCH LOSS: 1.524410367012024
# BATCH NUM: 110
# BATCH LOSS: 0.36393871903419495
# BATCH NUM: 120
# BATCH LOSS: 0.36495548486709595
# BATCH NUM: 130
# BATCH LOSS: 0.6051771640777588
# BATCH NUM: 140
# BATCH LOSS: 0.12566909193992615
# BATCH NUM: 150
# BATCH LOSS: 1.4792829751968384
# BATCH NUM: 160
# BATCH LOSS: 0.19292734563350677
# BATCH NUM: 170
# BATCH LOSS: 0.07904613018035889
# BATCH NUM: 180
# BATCH LOSS: 0.49819275736808777
# BATCH NUM: 190
# BATCH LOSS: 0.8071966767311096
# BATCH NUM: 200
# BATCH LOSS: 1.455509066581726
# BATCH NUM: 210
# BATCH LOSS: 0.30950379371643066
# BATCH NUM: 220
# BATCH LOSS: 0.5897083878517151
# BATCH NUM: 230
# BATCH LOSS: 0.22157356142997742
# BATCH NUM: 240
# BATCH LOSS: 0.5659733414649963
# BATCH NUM: 250
# BATCH LOSS: 0.6372671723365784
# BATCH NUM: 260
# BATCH LOSS: 0.8420947194099426
# BATCH NUM: 270
# BATCH LOSS: 0.20476935803890228
# BATCH NUM: 280
# BATCH LOSS: 1.409308671951294
# BATCH NUM: 290
# BATCH LOSS: 0.29994404315948486
# BATCH NUM: 300
# BATCH LOSS: 0.37172552943229675
# BATCH NUM: 310
# BATCH LOSS: 0.4313808083534241
# BATCH NUM: 320
# BATCH LOSS: 0.041480742394924164
# BATCH NUM: 330
# BATCH LOSS: 0.9003922343254089
# BATCH NUM: 340
# BATCH LOSS: 0.4830980896949768
# BATCH NUM: 350
# BATCH LOSS: 1.3963828086853027
# BATCH NUM: 360
# BATCH LOSS: 0.538996696472168
# BATCH NUM: 370
# BATCH LOSS: 1.581764817237854
# BATCH NUM: 380
# BATCH LOSS: 0.18768200278282166
# BATCH NUM: 390
# BATCH LOSS: 0.013824768364429474
# BATCH NUM: 400
# BATCH LOSS: 0.4941556751728058
# BATCH NUM: 410
# BATCH LOSS: 0.6964211463928223
# BATCH NUM: 420
# BATCH LOSS: 0.2526789605617523
# BATCH NUM: 430
# BATCH LOSS: 0.22462935745716095
# BATCH NUM: 440
# BATCH LOSS: 0.03365936502814293
# BATCH NUM: 450
# BATCH LOSS: 0.005330197513103485
# EPOCH:  6
# LOSS:  0.5120572000534998
# TRAIN ACC:  0.8331485587583148
# EPOCH:  6
# LOSS:  1.8270342364257215
# VALID ACC:  0.76
# BATCH NUM: 0
# BATCH LOSS: 0.5275177955627441
# BATCH NUM: 10
# BATCH LOSS: 0.5703578591346741
# BATCH NUM: 20
# BATCH LOSS: 0.35501229763031006
# BATCH NUM: 30
# BATCH LOSS: 0.5943507552146912
# BATCH NUM: 40
# BATCH LOSS: 0.016331689432263374
# BATCH NUM: 50
# BATCH LOSS: 0.026178821921348572
# BATCH NUM: 60
# BATCH LOSS: 0.19250549376010895
# BATCH NUM: 70
# BATCH LOSS: 0.5364615321159363
# BATCH NUM: 80
# BATCH LOSS: 0.19163593649864197
# BATCH NUM: 90
# BATCH LOSS: 0.37834179401397705
# BATCH NUM: 100
# BATCH LOSS: 0.20002804696559906
# BATCH NUM: 110
# BATCH LOSS: 0.5364021062850952
# BATCH NUM: 120
# BATCH LOSS: 0.3369939625263214
# BATCH NUM: 130
# BATCH LOSS: 0.28359997272491455
# BATCH NUM: 140
# BATCH LOSS: 0.34055817127227783
# BATCH NUM: 150
# BATCH LOSS: 1.857938528060913
# BATCH NUM: 160
# BATCH LOSS: 0.29697084426879883
# BATCH NUM: 170
# BATCH LOSS: 0.054923199117183685
# BATCH NUM: 180
# BATCH LOSS: 0.21764454245567322
# BATCH NUM: 190
# BATCH LOSS: 1.0346169471740723
# BATCH NUM: 200
# BATCH LOSS: 0.337226003408432
# BATCH NUM: 210
# BATCH LOSS: 0.13786281645298004
# BATCH NUM: 220
# BATCH LOSS: 0.9228945970535278
# BATCH NUM: 230
# BATCH LOSS: 0.5861103534698486
# BATCH NUM: 240
# BATCH LOSS: 0.15155531466007233
# BATCH NUM: 250
# BATCH LOSS: 0.19467978179454803
# BATCH NUM: 260
# BATCH LOSS: 0.2045382559299469
# BATCH NUM: 270
# BATCH LOSS: 0.3704317510128021
# BATCH NUM: 280
# BATCH LOSS: 0.1905088722705841
# BATCH NUM: 290
# BATCH LOSS: 0.3807273507118225
# BATCH NUM: 300
# BATCH LOSS: 0.22355283796787262
# BATCH NUM: 310
# BATCH LOSS: 0.15233469009399414
# BATCH NUM: 320
# BATCH LOSS: 0.5206235647201538
# BATCH NUM: 330
# BATCH LOSS: 0.5995634198188782
# BATCH NUM: 340
# BATCH LOSS: 0.5761176347732544
# BATCH NUM: 350
# BATCH LOSS: 0.18909424543380737
# BATCH NUM: 360
# BATCH LOSS: 0.21774117648601532
# BATCH NUM: 370
# BATCH LOSS: 0.45316317677497864
# BATCH NUM: 380
# BATCH LOSS: 0.7559280395507812
# BATCH NUM: 390
# BATCH LOSS: 0.8245922327041626
# BATCH NUM: 400
# BATCH LOSS: 0.7043065428733826
# BATCH NUM: 410
# BATCH LOSS: 0.027467677369713783
# BATCH NUM: 420
# BATCH LOSS: 0.39733439683914185
# BATCH NUM: 430
# BATCH LOSS: 0.11920405924320221
# BATCH NUM: 440
# BATCH LOSS: 0.5892297625541687
# BATCH NUM: 450
# BATCH LOSS: 0.042641621083021164
# EPOCH:  7
# LOSS:  0.4439253395464685
# TRAIN ACC:  0.8597560975609756
# EPOCH:  7
# LOSS:  1.8860300848660554
# VALID ACC:  0.7691666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.22391243278980255
# BATCH NUM: 10
# BATCH LOSS: 0.04284472018480301
# BATCH NUM: 20
# BATCH LOSS: 0.3959556221961975
# BATCH NUM: 30
# BATCH LOSS: 0.2959803640842438
# BATCH NUM: 40
# BATCH LOSS: 0.04088175296783447
# BATCH NUM: 50
# BATCH LOSS: 0.1503572165966034
# BATCH NUM: 60
# BATCH LOSS: 0.10172469913959503
# BATCH NUM: 70
# BATCH LOSS: 0.3575144112110138
# BATCH NUM: 80
# BATCH LOSS: 0.028118830174207687
# BATCH NUM: 90
# BATCH LOSS: 0.06550291180610657
# BATCH NUM: 100
# BATCH LOSS: 0.011509377509355545
# BATCH NUM: 110
# BATCH LOSS: 0.0780206024646759
# BATCH NUM: 120
# BATCH LOSS: 0.26280680298805237
# BATCH NUM: 130
# BATCH LOSS: 0.23756496608257294
# BATCH NUM: 140
# BATCH LOSS: 0.7164518237113953
# BATCH NUM: 150
# BATCH LOSS: 0.5485369563102722
# BATCH NUM: 160
# BATCH LOSS: 0.17250540852546692
# BATCH NUM: 170
# BATCH LOSS: 0.12779968976974487
# BATCH NUM: 180
# BATCH LOSS: 0.9918450117111206
# BATCH NUM: 190
# BATCH LOSS: 0.037626102566719055
# BATCH NUM: 200
# BATCH LOSS: 0.15428434312343597
# BATCH NUM: 210
# BATCH LOSS: 1.3553863763809204
# BATCH NUM: 220
# BATCH LOSS: 0.29212045669555664
# BATCH NUM: 230
# BATCH LOSS: 0.46216076612472534
# BATCH NUM: 240
# BATCH LOSS: 0.06230844929814339
# BATCH NUM: 250
# BATCH LOSS: 0.5858748555183411
# BATCH NUM: 260
# BATCH LOSS: 0.04418507218360901
# BATCH NUM: 270
# BATCH LOSS: 0.1265403926372528
# BATCH NUM: 280
# BATCH LOSS: 0.05707486346364021
# BATCH NUM: 290
# BATCH LOSS: 0.5337050557136536
# BATCH NUM: 300
# BATCH LOSS: 0.1950971633195877
# BATCH NUM: 310
# BATCH LOSS: 0.3060385584831238
# BATCH NUM: 320
# BATCH LOSS: 0.5216982960700989
# BATCH NUM: 330
# BATCH LOSS: 0.018449831753969193
# BATCH NUM: 340
# BATCH LOSS: 1.7327629327774048
# BATCH NUM: 350
# BATCH LOSS: 0.13756924867630005
# BATCH NUM: 360
# BATCH LOSS: 0.23950551450252533
# BATCH NUM: 370
# BATCH LOSS: 1.0214030742645264
# BATCH NUM: 380
# BATCH LOSS: 0.44065582752227783
# BATCH NUM: 390
# BATCH LOSS: 0.7210984826087952
# BATCH NUM: 400
# BATCH LOSS: 0.33980730175971985
# BATCH NUM: 410
# BATCH LOSS: 0.12218412011861801
# BATCH NUM: 420
# BATCH LOSS: 0.4038468599319458
# BATCH NUM: 430
# BATCH LOSS: 0.3953154981136322
# BATCH NUM: 440
# BATCH LOSS: 0.17702549695968628
# BATCH NUM: 450
# BATCH LOSS: 0.42090800404548645
# EPOCH:  8
# LOSS:  0.34006292757319495
# TRAIN ACC:  0.8944013303769401
# EPOCH:  8
# LOSS:  1.9200458697546523
# VALID ACC:  0.7816666666666666
# BATCH NUM: 0
# BATCH LOSS: 0.19791434705257416
# BATCH NUM: 10
# BATCH LOSS: 0.0903567224740982
# BATCH NUM: 20
# BATCH LOSS: 0.40521320700645447
# BATCH NUM: 30
# BATCH LOSS: 0.105052150785923
# BATCH NUM: 40
# BATCH LOSS: 0.0909111350774765
# BATCH NUM: 50
# BATCH LOSS: 0.0490214042365551
# BATCH NUM: 60
# BATCH LOSS: 0.1025320440530777
# BATCH NUM: 70
# BATCH LOSS: 0.3332592248916626
# BATCH NUM: 80
# BATCH LOSS: 0.1538712978363037
# BATCH NUM: 90
# BATCH LOSS: 0.6861563324928284
# BATCH NUM: 100
# BATCH LOSS: 0.08305501192808151
# BATCH NUM: 110
# BATCH LOSS: 0.8551144003868103
# BATCH NUM: 120
# BATCH LOSS: 0.033653225749731064
# BATCH NUM: 130
# BATCH LOSS: 0.014796962961554527
# BATCH NUM: 140
# BATCH LOSS: 0.6001257300376892
# BATCH NUM: 150
# BATCH LOSS: 0.8368880748748779
# BATCH NUM: 160
# BATCH LOSS: 0.48058706521987915
# BATCH NUM: 170
# BATCH LOSS: 0.029902376234531403
# BATCH NUM: 180
# BATCH LOSS: 0.19840803742408752
# BATCH NUM: 190
# BATCH LOSS: 0.07781004905700684
# BATCH NUM: 200
# BATCH LOSS: 0.1963634043931961
# BATCH NUM: 210
# BATCH LOSS: 0.17237265408039093
# BATCH NUM: 220
# BATCH LOSS: 0.07063661515712738
# BATCH NUM: 230
# BATCH LOSS: 0.07819851487874985
# BATCH NUM: 240
# BATCH LOSS: 0.510472297668457
# BATCH NUM: 250
# BATCH LOSS: 0.4536309242248535
# BATCH NUM: 260
# BATCH LOSS: 0.13124407827854156
# BATCH NUM: 270
# BATCH LOSS: 0.5344052910804749
# BATCH NUM: 280
# BATCH LOSS: 0.19727571308612823
# BATCH NUM: 290
# BATCH LOSS: 0.2016681283712387
# BATCH NUM: 300
# BATCH LOSS: 0.2862873077392578
# BATCH NUM: 310
# BATCH LOSS: 0.27989405393600464
# BATCH NUM: 320
# BATCH LOSS: 0.12066232413053513
# BATCH NUM: 330
# BATCH LOSS: 0.05690349265933037
# BATCH NUM: 340
# BATCH LOSS: 0.3988616466522217
# BATCH NUM: 350
# BATCH LOSS: 0.055492546409368515
# BATCH NUM: 360
# BATCH LOSS: 0.27109020948410034
# BATCH NUM: 370
# BATCH LOSS: 0.11097252368927002
# BATCH NUM: 380
# BATCH LOSS: 0.6917617321014404
# BATCH NUM: 390
# BATCH LOSS: 0.015367523767054081
# BATCH NUM: 400
# BATCH LOSS: 1.246077060699463
# BATCH NUM: 410
# BATCH LOSS: 1.0446202754974365
# BATCH NUM: 420
# BATCH LOSS: 0.218541219830513
# BATCH NUM: 430
# BATCH LOSS: 1.025636911392212
# BATCH NUM: 440
# BATCH LOSS: 0.401927649974823
# BATCH NUM: 450
# BATCH LOSS: 0.026729237288236618
# EPOCH:  9
# LOSS:  0.35665087365390113
# TRAIN ACC:  0.8871951219512195
# EPOCH:  9
# LOSS:  2.015388963248693
# VALID ACC:  0.7875
# BATCH NUM: 0
# BATCH LOSS: 0.027471724897623062
# BATCH NUM: 10
# BATCH LOSS: 0.11132464557886124
# BATCH NUM: 20
# BATCH LOSS: 0.5788671970367432
# BATCH NUM: 30
# BATCH LOSS: 0.15115322172641754
# BATCH NUM: 40
# BATCH LOSS: 1.3623524904251099
# BATCH NUM: 50
# BATCH LOSS: 0.40878936648368835
# BATCH NUM: 60
# BATCH LOSS: 0.11298304051160812
# BATCH NUM: 70
# BATCH LOSS: 0.6940451860427856
# BATCH NUM: 80
# BATCH LOSS: 0.17641258239746094
# BATCH NUM: 90
# BATCH LOSS: 1.225595474243164
# BATCH NUM: 100
# BATCH LOSS: 0.2096630036830902
# BATCH NUM: 110
# BATCH LOSS: 0.08840200304985046
# BATCH NUM: 120
# BATCH LOSS: 0.03801608458161354
# BATCH NUM: 130
# BATCH LOSS: 0.32703253626823425
# BATCH NUM: 140
# BATCH LOSS: 0.07853233069181442
# BATCH NUM: 150
# BATCH LOSS: 0.11291039735078812
# BATCH NUM: 160
# BATCH LOSS: 0.5847887992858887
# BATCH NUM: 170
# BATCH LOSS: 0.16748680174350739
# BATCH NUM: 180
# BATCH LOSS: 0.1682802140712738
# BATCH NUM: 190
# BATCH LOSS: 0.5512043237686157
# BATCH NUM: 200
# BATCH LOSS: 0.0851118192076683
# BATCH NUM: 210
# BATCH LOSS: 1.140263319015503
# BATCH NUM: 220
# BATCH LOSS: 0.36983707547187805
# BATCH NUM: 230
# BATCH LOSS: 0.644783079624176
# BATCH NUM: 240
# BATCH LOSS: 0.6868557929992676
# BATCH NUM: 250
# BATCH LOSS: 0.035489704459905624
# BATCH NUM: 260
# BATCH LOSS: 0.8297821283340454
# BATCH NUM: 270
# BATCH LOSS: 0.5737108588218689
# BATCH NUM: 280
# BATCH LOSS: 0.8905254602432251
# BATCH NUM: 290
# BATCH LOSS: 0.451803982257843
# BATCH NUM: 300
# BATCH LOSS: 0.2545510530471802
# BATCH NUM: 310
# BATCH LOSS: 0.303384006023407
# BATCH NUM: 320
# BATCH LOSS: 0.06742021441459656
# BATCH NUM: 330
# BATCH LOSS: 0.3821483850479126
# BATCH NUM: 340
# BATCH LOSS: 0.3302728235721588
# BATCH NUM: 350
# BATCH LOSS: 0.20922231674194336
# BATCH NUM: 360
# BATCH LOSS: 0.6073025465011597
# BATCH NUM: 370
# BATCH LOSS: 0.12793660163879395
# BATCH NUM: 380
# BATCH LOSS: 0.04614303261041641
# BATCH NUM: 390
# BATCH LOSS: 0.1422950178384781
# BATCH NUM: 400
# BATCH LOSS: 0.25235968828201294
# BATCH NUM: 410
# BATCH LOSS: 0.23722249269485474
# BATCH NUM: 420
# BATCH LOSS: 0.4929661452770233
# BATCH NUM: 430
# BATCH LOSS: 0.38076093792915344
# BATCH NUM: 440
# BATCH LOSS: 0.8723882436752319
# BATCH NUM: 450
# BATCH LOSS: 0.2985724210739136
# EPOCH:  10
# LOSS:  0.3521643252393955
# TRAIN ACC:  0.8907982261640798
# EPOCH:  10
# LOSS:  1.9203551615879015
# VALID ACC:  0.8
# BATCH NUM: 0
# BATCH LOSS: 0.10508045554161072
# BATCH NUM: 10
# BATCH LOSS: 0.2741793096065521
# BATCH NUM: 20
# BATCH LOSS: 0.09482002258300781
# BATCH NUM: 30
# BATCH LOSS: 0.15953688323497772
# BATCH NUM: 40
# BATCH LOSS: 0.013956686481833458
# BATCH NUM: 50
# BATCH LOSS: 0.0890357568860054
# BATCH NUM: 60
# BATCH LOSS: 0.5356879830360413
# BATCH NUM: 70
# BATCH LOSS: 0.1168869286775589
# BATCH NUM: 80
# BATCH LOSS: 0.38002458214759827
# BATCH NUM: 90
# BATCH LOSS: 0.11353754252195358
# BATCH NUM: 100
# BATCH LOSS: 0.14127637445926666
# BATCH NUM: 110
# BATCH LOSS: 0.1548936665058136
# BATCH NUM: 120
# BATCH LOSS: 0.8667396903038025
# BATCH NUM: 130
# BATCH LOSS: 0.01576530933380127
# BATCH NUM: 140
# BATCH LOSS: 1.188416600227356
# BATCH NUM: 150
# BATCH LOSS: 0.0679740160703659
# BATCH NUM: 160
# BATCH LOSS: 0.04695276543498039
# BATCH NUM: 170
# BATCH LOSS: 0.24679335951805115
# BATCH NUM: 180
# BATCH LOSS: 0.19874528050422668
# BATCH NUM: 190
# BATCH LOSS: 0.5695915818214417
# BATCH NUM: 200
# BATCH LOSS: 0.8326151967048645
# BATCH NUM: 210
# BATCH LOSS: 0.12414911389350891
# BATCH NUM: 220
# BATCH LOSS: 0.4744718074798584
# BATCH NUM: 230
# BATCH LOSS: 0.37152931094169617
# BATCH NUM: 240
# BATCH LOSS: 0.1200501099228859
# BATCH NUM: 250
# BATCH LOSS: 0.7905616164207458
# BATCH NUM: 260
# BATCH LOSS: 0.6724059581756592
# BATCH NUM: 270
# BATCH LOSS: 0.42382675409317017
# BATCH NUM: 280
# BATCH LOSS: 0.003840741701424122
# BATCH NUM: 290
# BATCH LOSS: 0.2812153398990631
# BATCH NUM: 300
# BATCH LOSS: 0.007980076596140862
# BATCH NUM: 310
# BATCH LOSS: 0.15829086303710938
# BATCH NUM: 320
# BATCH LOSS: 0.10033655166625977
# BATCH NUM: 330
# BATCH LOSS: 0.14004828035831451
# BATCH NUM: 340
# BATCH LOSS: 0.0672338455915451
# BATCH NUM: 350
# BATCH LOSS: 0.2904126048088074
# BATCH NUM: 360
# BATCH LOSS: 0.5025805830955505
# BATCH NUM: 370
# BATCH LOSS: 0.5053737163543701
# BATCH NUM: 380
# BATCH LOSS: 0.019021930173039436
# BATCH NUM: 390
# BATCH LOSS: 0.046673484146595
# BATCH NUM: 400
# BATCH LOSS: 0.08034446090459824
# BATCH NUM: 410
# BATCH LOSS: 0.1565134972333908
# BATCH NUM: 420
# BATCH LOSS: 0.36844781041145325
# BATCH NUM: 430
# BATCH LOSS: 0.28017306327819824
# BATCH NUM: 440
# BATCH LOSS: 1.0029648542404175
# BATCH NUM: 450
# BATCH LOSS: 0.0030042403377592564
# EPOCH:  11
# LOSS:  0.28563332931914676
# TRAIN ACC:  0.9104767184035477
# EPOCH:  11
# LOSS:  2.114435131328365
# VALID ACC:  0.7925
# BATCH NUM: 0
# BATCH LOSS: 0.2694653570652008
# BATCH NUM: 10
# BATCH LOSS: 0.09108200669288635
# BATCH NUM: 20
# BATCH LOSS: 1.037563443183899
# BATCH NUM: 30
# BATCH LOSS: 0.1156122162938118
# BATCH NUM: 40
# BATCH LOSS: 0.08361159265041351
# BATCH NUM: 50
# BATCH LOSS: 0.07431494444608688
# BATCH NUM: 60
# BATCH LOSS: 0.02360154688358307
# BATCH NUM: 70
# BATCH LOSS: 0.29337412118911743
# BATCH NUM: 80
# BATCH LOSS: 0.005004843696951866
# BATCH NUM: 90
# BATCH LOSS: 0.005131538026034832
# BATCH NUM: 100
# BATCH LOSS: 0.12692464888095856
# BATCH NUM: 110
# BATCH LOSS: 0.622435450553894
# BATCH NUM: 120
# BATCH LOSS: 0.27764251828193665
# BATCH NUM: 130
# BATCH LOSS: 0.5239637494087219
# BATCH NUM: 140
# BATCH LOSS: 0.4681358337402344
# BATCH NUM: 150
# BATCH LOSS: 0.24730512499809265
# BATCH NUM: 160
# BATCH LOSS: 0.44199496507644653
# BATCH NUM: 170
# BATCH LOSS: 0.1857965737581253
# BATCH NUM: 180
# BATCH LOSS: 0.07018236815929413
# BATCH NUM: 190
# BATCH LOSS: 0.007955456152558327
# BATCH NUM: 200
# BATCH LOSS: 0.042335767298936844
# BATCH NUM: 210
# BATCH LOSS: 0.04381726682186127
# BATCH NUM: 220
# BATCH LOSS: 0.184406578540802
# BATCH NUM: 230
# BATCH LOSS: 0.01893548294901848
# BATCH NUM: 240
# BATCH LOSS: 0.15501171350479126
# BATCH NUM: 250
# BATCH LOSS: 0.503456175327301
# BATCH NUM: 260
# BATCH LOSS: 0.18391519784927368
# BATCH NUM: 270
# BATCH LOSS: 0.3175007700920105
# BATCH NUM: 280
# BATCH LOSS: 0.09447341412305832
# BATCH NUM: 290
# BATCH LOSS: 0.4883975386619568
# BATCH NUM: 300
# BATCH LOSS: 0.032046373933553696
# BATCH NUM: 310
# BATCH LOSS: 0.07522381097078323
# BATCH NUM: 320
# BATCH LOSS: 0.09949299693107605
# BATCH NUM: 330
# BATCH LOSS: 0.1508532017469406
# BATCH NUM: 340
# BATCH LOSS: 0.44532665610313416
# BATCH NUM: 350
# BATCH LOSS: 0.24253541231155396
# BATCH NUM: 360
# BATCH LOSS: 0.36352047324180603
# BATCH NUM: 370
# BATCH LOSS: 0.08446698635816574
# BATCH NUM: 380
# BATCH LOSS: 0.04586588591337204
# BATCH NUM: 390
# BATCH LOSS: 0.10846835374832153
# BATCH NUM: 400
# BATCH LOSS: 0.05604231730103493
# BATCH NUM: 410
# BATCH LOSS: 0.020511040464043617
# BATCH NUM: 420
# BATCH LOSS: 0.27455735206604004
# BATCH NUM: 430
# BATCH LOSS: 0.13628070056438446
# BATCH NUM: 440
# BATCH LOSS: 0.6184803247451782
# BATCH NUM: 450
# BATCH LOSS: 0.014220262877643108
# EPOCH:  12
# LOSS:  0.24442538573044456
# TRAIN ACC:  0.9204545454545454
# EPOCH:  12
# LOSS:  2.235924898873352
# VALID ACC:  0.8
# BATCH NUM: 0
# BATCH LOSS: 0.25014758110046387
# BATCH NUM: 10
# BATCH LOSS: 0.02282572165131569
# BATCH NUM: 20
# BATCH LOSS: 0.11620574444532394
# BATCH NUM: 30
# BATCH LOSS: 0.005419983994215727
# BATCH NUM: 40
# BATCH LOSS: 0.21361038088798523
# BATCH NUM: 50
# BATCH LOSS: 0.06854727864265442
# BATCH NUM: 60
# BATCH LOSS: 0.1631564050912857
# BATCH NUM: 70
# BATCH LOSS: 0.3459208309650421
# BATCH NUM: 80
# BATCH LOSS: 0.16668972373008728
# BATCH NUM: 90
# BATCH LOSS: 0.014114052057266235
# BATCH NUM: 100
# BATCH LOSS: 0.09401401877403259
# BATCH NUM: 110
# BATCH LOSS: 0.6463727951049805
# BATCH NUM: 120
# BATCH LOSS: 0.17363865673542023
# BATCH NUM: 130
# BATCH LOSS: 0.13009600341320038
# BATCH NUM: 140
# BATCH LOSS: 0.7207174301147461
# BATCH NUM: 150
# BATCH LOSS: 0.42530161142349243
# BATCH NUM: 160
# BATCH LOSS: 0.15857098996639252
# BATCH NUM: 170
# BATCH LOSS: 0.0016463168431073427
# BATCH NUM: 180
# BATCH LOSS: 0.011088057421147823
# BATCH NUM: 190
# BATCH LOSS: 0.049370910972356796
# BATCH NUM: 200
# BATCH LOSS: 0.34302589297294617
# BATCH NUM: 210
# BATCH LOSS: 0.794906497001648
# BATCH NUM: 220
# BATCH LOSS: 0.02246895432472229
# BATCH NUM: 230
# BATCH LOSS: 0.13985805213451385
# BATCH NUM: 240
# BATCH LOSS: 0.1968245506286621
# BATCH NUM: 250
# BATCH LOSS: 0.3032466471195221
# BATCH NUM: 260
# BATCH LOSS: 0.09696517884731293
# BATCH NUM: 270
# BATCH LOSS: 0.2079065442085266
# BATCH NUM: 280
# BATCH LOSS: 0.2802306115627289
# BATCH NUM: 290
# BATCH LOSS: 1.2860450744628906
# BATCH NUM: 300
# BATCH LOSS: 0.875558614730835
# BATCH NUM: 310
# BATCH LOSS: 0.09373810887336731
# BATCH NUM: 320
# BATCH LOSS: 0.17368961870670319
# BATCH NUM: 330
# BATCH LOSS: 0.7823672890663147
# BATCH NUM: 340
# BATCH LOSS: 0.17641037702560425
# BATCH NUM: 350
# BATCH LOSS: 0.0060685561038553715
# BATCH NUM: 360
# BATCH LOSS: 0.2825719118118286
# BATCH NUM: 370
# BATCH LOSS: 0.05106853321194649
# BATCH NUM: 380
# BATCH LOSS: 0.1057092547416687
# BATCH NUM: 390
# BATCH LOSS: 0.3842456638813019
# BATCH NUM: 400
# BATCH LOSS: 0.39785265922546387
# BATCH NUM: 410
# BATCH LOSS: 0.6259372234344482
# BATCH NUM: 420
# BATCH LOSS: 0.8721513748168945
# BATCH NUM: 430
# BATCH LOSS: 0.0368732325732708
# BATCH NUM: 440
# BATCH LOSS: 0.8842464089393616
# BATCH NUM: 450
# BATCH LOSS: 0.14153215289115906
# EPOCH:  13
# LOSS:  0.2752652033965569
# TRAIN ACC:  0.9146341463414634
# EPOCH:  13
# LOSS:  2.203935491571874
# VALID ACC:  0.7966666666666666
# BATCH NUM: 0
# BATCH LOSS: 0.2610305845737457
# BATCH NUM: 10
# BATCH LOSS: 0.01454099826514721
# BATCH NUM: 20
# BATCH LOSS: 0.5578132271766663
# BATCH NUM: 30
# BATCH LOSS: 0.0198869239538908
# BATCH NUM: 40
# BATCH LOSS: 0.025280950590968132
# BATCH NUM: 50
# BATCH LOSS: 0.06879404187202454
# BATCH NUM: 60
# BATCH LOSS: 0.2727528214454651
# BATCH NUM: 70
# BATCH LOSS: 0.3233788013458252
# BATCH NUM: 80
# BATCH LOSS: 0.0999966412782669
# BATCH NUM: 90
# BATCH LOSS: 0.04071244224905968
# BATCH NUM: 100
# BATCH LOSS: 0.11795584857463837
# BATCH NUM: 110
# BATCH LOSS: 0.037912964820861816
# BATCH NUM: 120
# BATCH LOSS: 0.04177476838231087
# BATCH NUM: 130
# BATCH LOSS: 0.042873889207839966
# BATCH NUM: 140
# BATCH LOSS: 0.10751453042030334
# BATCH NUM: 150
# BATCH LOSS: 0.14141471683979034
# BATCH NUM: 160
# BATCH LOSS: 0.3163275420665741
# BATCH NUM: 170
# BATCH LOSS: 1.518757939338684
# BATCH NUM: 180
# BATCH LOSS: 0.10349899530410767
# BATCH NUM: 190
# BATCH LOSS: 0.08345875889062881
# BATCH NUM: 200
# BATCH LOSS: 0.018627755343914032
# BATCH NUM: 210
# BATCH LOSS: 0.5221778154373169
# BATCH NUM: 220
# BATCH LOSS: 0.12034565955400467
# BATCH NUM: 230
# BATCH LOSS: 0.13902340829372406
# BATCH NUM: 240
# BATCH LOSS: 0.5534781217575073
# BATCH NUM: 250
# BATCH LOSS: 0.03879871591925621
# BATCH NUM: 260
# BATCH LOSS: 0.2311704009771347
# BATCH NUM: 270
# BATCH LOSS: 0.0062283980660140514
# BATCH NUM: 280
# BATCH LOSS: 0.1369548887014389
# BATCH NUM: 290
# BATCH LOSS: 0.17821833491325378
# BATCH NUM: 300
# BATCH LOSS: 0.03823879733681679
# BATCH NUM: 310
# BATCH LOSS: 0.4237514138221741
# BATCH NUM: 320
# BATCH LOSS: 0.1369197815656662
# BATCH NUM: 330
# BATCH LOSS: 0.06850539892911911
# BATCH NUM: 340
# BATCH LOSS: 0.6320487856864929
# BATCH NUM: 350
# BATCH LOSS: 0.32555490732192993
# BATCH NUM: 360
# BATCH LOSS: 0.028758492320775986
# BATCH NUM: 370
# BATCH LOSS: 0.05465179681777954
# BATCH NUM: 380
# BATCH LOSS: 0.8858581185340881
# BATCH NUM: 390
# BATCH LOSS: 0.6336856484413147
# BATCH NUM: 400
# BATCH LOSS: 0.03617515414953232
# BATCH NUM: 410
# BATCH LOSS: 0.09916296601295471
# BATCH NUM: 420
# BATCH LOSS: 0.02038506418466568
# BATCH NUM: 430
# BATCH LOSS: 0.07523459941148758
# BATCH NUM: 440
# BATCH LOSS: 0.027178363874554634
# BATCH NUM: 450
# BATCH LOSS: 0.45303666591644287
# EPOCH:  14
# LOSS:  0.26662026432679137
# TRAIN ACC:  0.9171286031042128
# EPOCH:  14
# LOSS:  2.119664304534242
# VALID ACC:  0.7891666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.030685877427458763
# BATCH NUM: 10
# BATCH LOSS: 0.015583541244268417
# BATCH NUM: 20
# BATCH LOSS: 0.5228543281555176
# BATCH NUM: 30
# BATCH LOSS: 0.7228144407272339
# BATCH NUM: 40
# BATCH LOSS: 0.2681109607219696
# BATCH NUM: 50
# BATCH LOSS: 0.09011227637529373
# BATCH NUM: 60
# BATCH LOSS: 0.3793506324291229
# BATCH NUM: 70
# BATCH LOSS: 0.42374178767204285
# BATCH NUM: 80
# BATCH LOSS: 0.13972972333431244
# BATCH NUM: 90
# BATCH LOSS: 0.47273024916648865
# BATCH NUM: 100
# BATCH LOSS: 0.20695264637470245
# BATCH NUM: 110
# BATCH LOSS: 0.13959196209907532
# BATCH NUM: 120
# BATCH LOSS: 0.0036053715739399195
# BATCH NUM: 130
# BATCH LOSS: 0.3427239954471588
# BATCH NUM: 140
# BATCH LOSS: 0.03194145858287811
# BATCH NUM: 150
# BATCH LOSS: 0.1295543611049652
# BATCH NUM: 160
# BATCH LOSS: 0.5440436601638794
# BATCH NUM: 170
# BATCH LOSS: 0.016652772203087807
# BATCH NUM: 180
# BATCH LOSS: 0.3710443377494812
# BATCH NUM: 190
# BATCH LOSS: 0.3782901465892792
# BATCH NUM: 200
# BATCH LOSS: 0.378023236989975
# BATCH NUM: 210
# BATCH LOSS: 0.03871892765164375
# BATCH NUM: 220
# BATCH LOSS: 0.35817357897758484
# BATCH NUM: 230
# BATCH LOSS: 0.008668464608490467
# BATCH NUM: 240
# BATCH LOSS: 0.01629718765616417
# BATCH NUM: 250
# BATCH LOSS: 0.03365587815642357
# BATCH NUM: 260
# BATCH LOSS: 0.01882808655500412
# BATCH NUM: 270
# BATCH LOSS: 0.09071998298168182
# BATCH NUM: 280
# BATCH LOSS: 0.07396746426820755
# BATCH NUM: 290
# BATCH LOSS: 0.33922848105430603
# BATCH NUM: 300
# BATCH LOSS: 0.1518627107143402
# BATCH NUM: 310
# BATCH LOSS: 0.13252049684524536
# BATCH NUM: 320
# BATCH LOSS: 0.04871416836977005
# BATCH NUM: 330
# BATCH LOSS: 0.2615104615688324
# BATCH NUM: 340
# BATCH LOSS: 0.265693724155426
# BATCH NUM: 350
# BATCH LOSS: 0.17741753160953522
# BATCH NUM: 360
# BATCH LOSS: 0.4915052652359009
# BATCH NUM: 370
# BATCH LOSS: 0.004386180080473423
# BATCH NUM: 380
# BATCH LOSS: 0.5945771336555481
# BATCH NUM: 390
# BATCH LOSS: 0.053395725786685944
# BATCH NUM: 400
# BATCH LOSS: 0.06430429965257645
# BATCH NUM: 410
# BATCH LOSS: 0.37656521797180176
# BATCH NUM: 420
# BATCH LOSS: 0.7719666957855225
# BATCH NUM: 430
# BATCH LOSS: 0.01565246470272541
# BATCH NUM: 440
# BATCH LOSS: 0.319344162940979
# BATCH NUM: 450
# BATCH LOSS: 0.3413654565811157
# EPOCH:  15
# LOSS:  0.195771064095073
# TRAIN ACC:  0.9359756097560976
# EPOCH:  15
# LOSS:  2.316845715592456
# VALID ACC:  0.7966666666666666
# BATCH NUM: 0
# BATCH LOSS: 0.6178153157234192
# BATCH NUM: 10
# BATCH LOSS: 0.18601872026920319
# BATCH NUM: 20
# BATCH LOSS: 0.4134698212146759
# BATCH NUM: 30
# BATCH LOSS: 0.12575824558734894
# BATCH NUM: 40
# BATCH LOSS: 0.030224280431866646
# BATCH NUM: 50
# BATCH LOSS: 1.3857113122940063
# BATCH NUM: 60
# BATCH LOSS: 0.5923800468444824
# BATCH NUM: 70
# BATCH LOSS: 0.31236815452575684
# BATCH NUM: 80
# BATCH LOSS: 0.07420007884502411
# BATCH NUM: 90
# BATCH LOSS: 0.08416682481765747
# BATCH NUM: 100
# BATCH LOSS: 0.05105993524193764
# BATCH NUM: 110
# BATCH LOSS: 0.007153197657316923
# BATCH NUM: 120
# BATCH LOSS: 0.026838388293981552
# BATCH NUM: 130
# BATCH LOSS: 0.09593955427408218
# BATCH NUM: 140
# BATCH LOSS: 0.7547729015350342
# BATCH NUM: 150
# BATCH LOSS: 0.11301665753126144
# BATCH NUM: 160
# BATCH LOSS: 0.6318020224571228
# BATCH NUM: 170
# BATCH LOSS: 0.4391655921936035
# BATCH NUM: 180
# BATCH LOSS: 0.2352825403213501
# BATCH NUM: 190
# BATCH LOSS: 0.14489054679870605
# BATCH NUM: 200
# BATCH LOSS: 0.0113916527479887
# BATCH NUM: 210
# BATCH LOSS: 0.0026274120900779963
# BATCH NUM: 220
# BATCH LOSS: 0.027741732075810432
# BATCH NUM: 230
# BATCH LOSS: 0.0007675914675928652
# BATCH NUM: 240
# BATCH LOSS: 1.23526132106781
# BATCH NUM: 250
# BATCH LOSS: 0.948275089263916
# BATCH NUM: 260
# BATCH LOSS: 0.15665391087532043
# BATCH NUM: 270
# BATCH LOSS: 0.1099293977022171
# BATCH NUM: 280
# BATCH LOSS: 0.0026356608141213655
# BATCH NUM: 290
# BATCH LOSS: 0.021512452512979507
# BATCH NUM: 300
# BATCH LOSS: 0.2734818756580353
# BATCH NUM: 310
# BATCH LOSS: 0.021682292222976685
# BATCH NUM: 320
# BATCH LOSS: 0.002909249160438776
# BATCH NUM: 330
# BATCH LOSS: 0.20354905724525452
# BATCH NUM: 340
# BATCH LOSS: 0.1431489735841751
# BATCH NUM: 350
# BATCH LOSS: 0.15676268935203552
# BATCH NUM: 360
# BATCH LOSS: 0.2424440085887909
# BATCH NUM: 370
# BATCH LOSS: 0.13739877939224243
# BATCH NUM: 380
# BATCH LOSS: 0.02380470186471939
# BATCH NUM: 390
# BATCH LOSS: 0.5374055504798889
# BATCH NUM: 400
# BATCH LOSS: 0.04962630569934845
# BATCH NUM: 410
# BATCH LOSS: 0.2689259350299835
# BATCH NUM: 420
# BATCH LOSS: 0.06209308281540871
# BATCH NUM: 430
# BATCH LOSS: 0.0647369772195816
# BATCH NUM: 440
# BATCH LOSS: 0.19922491908073425
# BATCH NUM: 450
# BATCH LOSS: 2.4768943786621094
# EPOCH:  16
# LOSS:  0.2096683708602278
# TRAIN ACC:  0.9315410199556541
# EPOCH:  16
# LOSS:  2.3410594666368847
# VALID ACC:  0.8083333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.01808471418917179
# BATCH NUM: 10
# BATCH LOSS: 0.3262171149253845
# BATCH NUM: 20
# BATCH LOSS: 0.05842070281505585
# BATCH NUM: 30
# BATCH LOSS: 0.055642079561948776
# BATCH NUM: 40
# BATCH LOSS: 0.006625926587730646
# BATCH NUM: 50
# BATCH LOSS: 0.26472988724708557
# BATCH NUM: 60
# BATCH LOSS: 0.03639906644821167
# BATCH NUM: 70
# BATCH LOSS: 0.8752239942550659
# BATCH NUM: 80
# BATCH LOSS: 0.09468238800764084
# BATCH NUM: 90
# BATCH LOSS: 0.308662086725235
# BATCH NUM: 100
# BATCH LOSS: 0.07419226318597794
# BATCH NUM: 110
# BATCH LOSS: 0.11640055477619171
# BATCH NUM: 120
# BATCH LOSS: 0.05250604450702667
# BATCH NUM: 130
# BATCH LOSS: 0.03284788876771927
# BATCH NUM: 140
# BATCH LOSS: 0.5823475122451782
# BATCH NUM: 150
# BATCH LOSS: 0.09109564870595932
# BATCH NUM: 160
# BATCH LOSS: 0.17488819360733032
# BATCH NUM: 170
# BATCH LOSS: 0.04724520817399025
# BATCH NUM: 180
# BATCH LOSS: 0.05410283803939819
# BATCH NUM: 190
# BATCH LOSS: 0.017995161935687065
# BATCH NUM: 200
# BATCH LOSS: 0.030684446915984154
# BATCH NUM: 210
# BATCH LOSS: 0.4081222116947174
# BATCH NUM: 220
# BATCH LOSS: 0.012320409528911114
# BATCH NUM: 230
# BATCH LOSS: 0.10092946141958237
# BATCH NUM: 240
# BATCH LOSS: 0.11591769009828568
# BATCH NUM: 250
# BATCH LOSS: 0.01787078008055687
# BATCH NUM: 260
# BATCH LOSS: 0.0026666102930903435
# BATCH NUM: 270
# BATCH LOSS: 0.05209111049771309
# BATCH NUM: 280
# BATCH LOSS: 0.009538126178085804
# BATCH NUM: 290
# BATCH LOSS: 1.074080228805542
# BATCH NUM: 300
# BATCH LOSS: 0.0010403655469417572
# BATCH NUM: 310
# BATCH LOSS: 0.04853000119328499
# BATCH NUM: 320
# BATCH LOSS: 0.006435692310333252
# BATCH NUM: 330
# BATCH LOSS: 0.20679618418216705
# BATCH NUM: 340
# BATCH LOSS: 0.6800576448440552
# BATCH NUM: 350
# BATCH LOSS: 0.2714402675628662
# BATCH NUM: 360
# BATCH LOSS: 0.45709890127182007
# BATCH NUM: 370
# BATCH LOSS: 0.3125535249710083
# BATCH NUM: 380
# BATCH LOSS: 0.4550442695617676
# BATCH NUM: 390
# BATCH LOSS: 0.2089368999004364
# BATCH NUM: 400
# BATCH LOSS: 0.2527949810028076
# BATCH NUM: 410
# BATCH LOSS: 0.4559134542942047
# BATCH NUM: 420
# BATCH LOSS: 0.15644221007823944
# BATCH NUM: 430
# BATCH LOSS: 0.07047267258167267
# BATCH NUM: 440
# BATCH LOSS: 0.009525653906166553
# BATCH NUM: 450
# BATCH LOSS: 0.011431055143475533
# EPOCH:  17
# LOSS:  0.1882151152201954
# TRAIN ACC:  0.9451219512195121
# EPOCH:  17
# LOSS:  2.465292693104637
# VALID ACC:  0.805
# BATCH NUM: 0
# BATCH LOSS: 0.0057074218057096004
# BATCH NUM: 10
# BATCH LOSS: 0.21026672422885895
# BATCH NUM: 20
# BATCH LOSS: 0.1442236453294754
# BATCH NUM: 30
# BATCH LOSS: 0.013484775088727474
# BATCH NUM: 40
# BATCH LOSS: 0.3884509801864624
# BATCH NUM: 50
# BATCH LOSS: 0.0690213143825531
# BATCH NUM: 60
# BATCH LOSS: 0.12332117557525635
# BATCH NUM: 70
# BATCH LOSS: 0.05626705288887024
# BATCH NUM: 80
# BATCH LOSS: 0.4572240710258484
# BATCH NUM: 90
# BATCH LOSS: 0.2677280902862549
# BATCH NUM: 100
# BATCH LOSS: 0.535145103931427
# BATCH NUM: 110
# BATCH LOSS: 0.06807967275381088
# BATCH NUM: 120
# BATCH LOSS: 0.5887078642845154
# BATCH NUM: 130
# BATCH LOSS: 0.3245108127593994
# BATCH NUM: 140
# BATCH LOSS: 0.11491881310939789
# BATCH NUM: 150
# BATCH LOSS: 0.30108386278152466
# BATCH NUM: 160
# BATCH LOSS: 0.16350939869880676
# BATCH NUM: 170
# BATCH LOSS: 0.07168666273355484
# BATCH NUM: 180
# BATCH LOSS: 0.000925024738535285
# BATCH NUM: 190
# BATCH LOSS: 0.005777565762400627
# BATCH NUM: 200
# BATCH LOSS: 0.05093126744031906
# BATCH NUM: 210
# BATCH LOSS: 0.061350587755441666
# BATCH NUM: 220
# BATCH LOSS: 0.02623753808438778
# BATCH NUM: 230
# BATCH LOSS: 0.22621849179267883
# BATCH NUM: 240
# BATCH LOSS: 0.20828375220298767
# BATCH NUM: 250
# BATCH LOSS: 0.6358983516693115
# BATCH NUM: 260
# BATCH LOSS: 0.7516626119613647
# BATCH NUM: 270
# BATCH LOSS: 0.010937741957604885
# BATCH NUM: 280
# BATCH LOSS: 0.12109079211950302
# BATCH NUM: 290
# BATCH LOSS: 0.023089788854122162
# BATCH NUM: 300
# BATCH LOSS: 0.11301618814468384
# BATCH NUM: 310
# BATCH LOSS: 0.10237101465463638
# BATCH NUM: 320
# BATCH LOSS: 0.13267868757247925
# BATCH NUM: 330
# BATCH LOSS: 0.3720943331718445
# BATCH NUM: 340
# BATCH LOSS: 0.43836158514022827
# BATCH NUM: 350
# BATCH LOSS: 0.13388459384441376
# BATCH NUM: 360
# BATCH LOSS: 0.2676675021648407
# BATCH NUM: 370
# BATCH LOSS: 0.0040001352317631245
# BATCH NUM: 380
# BATCH LOSS: 0.2221437245607376
# BATCH NUM: 390
# BATCH LOSS: 0.004635465331375599
# BATCH NUM: 400
# BATCH LOSS: 0.28621944785118103
# BATCH NUM: 410
# BATCH LOSS: 0.028932303190231323
# BATCH NUM: 420
# BATCH LOSS: 0.010432797484099865
# BATCH NUM: 430
# BATCH LOSS: 0.028889305889606476
# BATCH NUM: 440
# BATCH LOSS: 0.5430759191513062
# BATCH NUM: 450
# BATCH LOSS: 0.0005412916652858257
# EPOCH:  18
# LOSS:  0.22990263531191482
# TRAIN ACC:  0.9271064301552107
# EPOCH:  18
# LOSS:  2.3771686660228983
# VALID ACC:  0.8083333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.2536690831184387
# BATCH NUM: 10
# BATCH LOSS: 0.018067840486764908
# BATCH NUM: 20
# BATCH LOSS: 0.014901024289429188
# BATCH NUM: 30
# BATCH LOSS: 0.7296237349510193
# BATCH NUM: 40
# BATCH LOSS: 0.01859469525516033
# BATCH NUM: 50
# BATCH LOSS: 0.19560784101486206
# BATCH NUM: 60
# BATCH LOSS: 0.019114013761281967
# BATCH NUM: 70
# BATCH LOSS: 0.16368190944194794
# BATCH NUM: 80
# BATCH LOSS: 0.2795655131340027
# BATCH NUM: 90
# BATCH LOSS: 0.016069509088993073
# BATCH NUM: 100
# BATCH LOSS: 0.014161840081214905
# BATCH NUM: 110
# BATCH LOSS: 1.0189467668533325
# BATCH NUM: 120
# BATCH LOSS: 0.28576335310935974
# BATCH NUM: 130
# BATCH LOSS: 0.0366247184574604
# BATCH NUM: 140
# BATCH LOSS: 0.2278076559305191
# BATCH NUM: 150
# BATCH LOSS: 0.07094055414199829
# BATCH NUM: 160
# BATCH LOSS: 0.01156664453446865
# BATCH NUM: 170
# BATCH LOSS: 0.060463715344667435
# BATCH NUM: 180
# BATCH LOSS: 0.11112212389707565
# BATCH NUM: 190
# BATCH LOSS: 0.10626206547021866
# BATCH NUM: 200
# BATCH LOSS: 0.07354080677032471
# BATCH NUM: 210
# BATCH LOSS: 0.0013674581423401833
# BATCH NUM: 220
# BATCH LOSS: 0.015604779124259949
# BATCH NUM: 230
# BATCH LOSS: 0.025204775854945183
# BATCH NUM: 240
# BATCH LOSS: 0.01456573698669672
# BATCH NUM: 250
# BATCH LOSS: 0.0007700749556533992
# BATCH NUM: 260
# BATCH LOSS: 0.34564730525016785
# BATCH NUM: 270
# BATCH LOSS: 0.1677318960428238
# BATCH NUM: 280
# BATCH LOSS: 0.007490435149520636
# BATCH NUM: 290
# BATCH LOSS: 0.0002407871070317924
# BATCH NUM: 300
# BATCH LOSS: 0.6879292726516724
# BATCH NUM: 310
# BATCH LOSS: 0.06905187666416168
# BATCH NUM: 320
# BATCH LOSS: 0.018532223999500275
# BATCH NUM: 330
# BATCH LOSS: 0.02895011566579342
# BATCH NUM: 340
# BATCH LOSS: 0.0395115464925766
# BATCH NUM: 350
# BATCH LOSS: 0.33644330501556396
# BATCH NUM: 360
# BATCH LOSS: 0.15696623921394348
# BATCH NUM: 370
# BATCH LOSS: 0.5317914485931396
# BATCH NUM: 380
# BATCH LOSS: 0.04241609200835228
# BATCH NUM: 390
# BATCH LOSS: 0.1293119639158249
# BATCH NUM: 400
# BATCH LOSS: 0.2771493196487427
# BATCH NUM: 410
# BATCH LOSS: 0.0036753893364220858
# BATCH NUM: 420
# BATCH LOSS: 0.007235303986817598
# BATCH NUM: 430
# BATCH LOSS: 0.017140811309218407
# BATCH NUM: 440
# BATCH LOSS: 0.5129075646400452
# BATCH NUM: 450
# BATCH LOSS: 0.08078750222921371
# EPOCH:  19
# LOSS:  0.17867402421336415
# TRAIN ACC:  0.9456762749445676
# EPOCH:  19
# LOSS:  2.4721368947257787
# VALID ACC:  0.8
# BATCH NUM: 0
# BATCH LOSS: 0.1831430345773697
# BATCH NUM: 10
# BATCH LOSS: 0.009461620822548866
# BATCH NUM: 20
# BATCH LOSS: 0.21635979413986206
# BATCH NUM: 30
# BATCH LOSS: 0.0025894921272993088
# BATCH NUM: 40
# BATCH LOSS: 0.02887345664203167
# BATCH NUM: 50
# BATCH LOSS: 0.002361016348004341
# BATCH NUM: 60
# BATCH LOSS: 0.12853817641735077
# BATCH NUM: 70
# BATCH LOSS: 0.2923085391521454
# BATCH NUM: 80
# BATCH LOSS: 0.13031154870986938
# BATCH NUM: 90
# BATCH LOSS: 0.7716681361198425
# BATCH NUM: 100
# BATCH LOSS: 0.045706529170274734
# BATCH NUM: 110
# BATCH LOSS: 0.022574417293071747
# BATCH NUM: 120
# BATCH LOSS: 0.020529985427856445
# BATCH NUM: 130
# BATCH LOSS: 0.008010643534362316
# BATCH NUM: 140
# BATCH LOSS: 0.04534442722797394
# BATCH NUM: 150
# BATCH LOSS: 0.003352987114340067
# BATCH NUM: 160
# BATCH LOSS: 0.16530391573905945
# BATCH NUM: 170
# BATCH LOSS: 0.34751200675964355
# BATCH NUM: 180
# BATCH LOSS: 0.11221829056739807
# BATCH NUM: 190
# BATCH LOSS: 0.0037815377581864595
# BATCH NUM: 200
# BATCH LOSS: 0.02368425577878952
# BATCH NUM: 210
# BATCH LOSS: 0.07663612067699432
# BATCH NUM: 220
# BATCH LOSS: 0.0033524208702147007
# BATCH NUM: 230
# BATCH LOSS: 0.09993509203195572
# BATCH NUM: 240
# BATCH LOSS: 0.3616503179073334
# BATCH NUM: 250
# BATCH LOSS: 0.030538782477378845
# BATCH NUM: 260
# BATCH LOSS: 0.12342460453510284
# BATCH NUM: 270
# BATCH LOSS: 0.0745016485452652
# BATCH NUM: 280
# BATCH LOSS: 0.035701069980859756
# BATCH NUM: 290
# BATCH LOSS: 0.1795276254415512
# BATCH NUM: 300
# BATCH LOSS: 0.2321709841489792
# BATCH NUM: 310
# BATCH LOSS: 0.003708179574459791
# BATCH NUM: 320
# BATCH LOSS: 0.02083670161664486
# BATCH NUM: 330
# BATCH LOSS: 0.14916148781776428
# BATCH NUM: 340
# BATCH LOSS: 0.1952381581068039
# BATCH NUM: 350
# BATCH LOSS: 0.04930422455072403
# BATCH NUM: 360
# BATCH LOSS: 0.31287893652915955
# BATCH NUM: 370
# BATCH LOSS: 0.006463731173425913
# BATCH NUM: 380
# BATCH LOSS: 0.03962454944849014
# BATCH NUM: 390
# BATCH LOSS: 0.5451997518539429
# BATCH NUM: 400
# BATCH LOSS: 0.7591649889945984
# BATCH NUM: 410
# BATCH LOSS: 0.48098278045654297
# BATCH NUM: 420
# BATCH LOSS: 0.013347091153264046
# BATCH NUM: 430
# BATCH LOSS: 0.05285459756851196
# BATCH NUM: 440
# BATCH LOSS: 0.1985587775707245
# BATCH NUM: 450
# BATCH LOSS: 0.02143862098455429
# EPOCH:  20
# LOSS:  0.1798878958199283
# TRAIN ACC:  0.9429046563192904
# EPOCH:  20
# LOSS:  2.592536947703428
# VALID ACC:  0.7933333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.1406448632478714
# BATCH NUM: 10
# BATCH LOSS: 0.04620811343193054
# BATCH NUM: 20
# BATCH LOSS: 0.1923196017742157
# BATCH NUM: 30
# ...
# BATCH NUM: 60
# BATCH LOSS: 0.06563864648342133
# BATCH NUM: 70
# BATCH LOSS: 0.03426431864500046
# BATCH NUM: 80
# BATCH LOSS: 0.5975565314292908
# BATCH NUM: 90
# BATCH LOSS: 0.0001192437339341268
# BATCH NUM: 100
# BATCH LOSS: 0.040044285356998444
# BATCH NUM: 110
# BATCH LOSS: 0.037895567715168
# BATCH NUM: 120
# BATCH LOSS: 0.04982047155499458
# BATCH NUM: 130
# BATCH LOSS: 0.22025229036808014
# BATCH NUM: 140
# BATCH LOSS: 0.0078964252024889
# BATCH NUM: 150
# BATCH LOSS: 0.048465874046087265
# BATCH NUM: 160
# BATCH LOSS: 0.0004293769598007202
# BATCH NUM: 170
# BATCH LOSS: 0.005465252324938774
# BATCH NUM: 180
# BATCH LOSS: 0.012896979227662086
# BATCH NUM: 190
# BATCH LOSS: 0.0004293966048862785
# BATCH NUM: 200
# BATCH LOSS: 0.011465776711702347
# BATCH NUM: 210
# BATCH LOSS: 0.003858463605865836
# BATCH NUM: 220
# BATCH LOSS: 0.08483090996742249
# BATCH NUM: 230
# BATCH LOSS: 0.02064445987343788
# BATCH NUM: 240
# BATCH LOSS: 0.01250382699072361
# BATCH NUM: 250
# BATCH LOSS: 0.6221805214881897
# BATCH NUM: 260
# BATCH LOSS: 0.8833260536193848
# BATCH NUM: 270
# BATCH LOSS: 0.0736009031534195
# BATCH NUM: 280
# BATCH LOSS: 0.027517301961779594
# BATCH NUM: 290
# BATCH LOSS: 0.41901707649230957
# BATCH NUM: 300
# BATCH LOSS: 0.00016875460278242826
# BATCH NUM: 310
# BATCH LOSS: 0.011289835907518864
# BATCH NUM: 320
# BATCH LOSS: 0.36656293272972107
# BATCH NUM: 330
# BATCH LOSS: 0.10214190185070038
# BATCH NUM: 340
# BATCH LOSS: 0.07526086270809174
# BATCH NUM: 350
# BATCH LOSS: 0.015597418881952763
# BATCH NUM: 360
# BATCH LOSS: 0.3661603033542633
# BATCH NUM: 370
# BATCH LOSS: 0.30038464069366455
# BATCH NUM: 380
# BATCH LOSS: 0.011002454906702042
# BATCH NUM: 390
# BATCH LOSS: 0.011254108510911465
# BATCH NUM: 400
# BATCH LOSS: 0.047308966517448425
# BATCH NUM: 410
# BATCH LOSS: 0.02695411443710327
# BATCH NUM: 420
# BATCH LOSS: 0.010518788360059261
# BATCH NUM: 430
# BATCH LOSS: 0.10583551973104477
# BATCH NUM: 440
# BATCH LOSS: 0.03712090477347374
# BATCH NUM: 450
# BATCH LOSS: 0.032165538519620895
# EPOCH:  33
# LOSS:  0.10893562267397404
# TRAIN ACC:  0.967849223946785
# EPOCH:  33
# LOSS:  2.783876121817913
# VALID ACC:  0.8016666666666666
# BATCH NUM: 0
# BATCH LOSS: 0.003057314781472087
# BATCH NUM: 10
# BATCH LOSS: 0.06250887364149094
# BATCH NUM: 20
# BATCH LOSS: 0.014594389125704765
# BATCH NUM: 30
# BATCH LOSS: 0.019512685015797615
# BATCH NUM: 40
# BATCH LOSS: 0.09298323839902878
# BATCH NUM: 50
# BATCH LOSS: 0.009272228926420212
# BATCH NUM: 60
# BATCH LOSS: 0.05260011926293373
# BATCH NUM: 70
# BATCH LOSS: 0.007972301915287971
# BATCH NUM: 80
# BATCH LOSS: 0.028186529874801636
# BATCH NUM: 90
# BATCH LOSS: 0.02623089961707592
# BATCH NUM: 100
# BATCH LOSS: 0.3373025953769684
# BATCH NUM: 110
# BATCH LOSS: 0.00035216950345784426
# BATCH NUM: 120
# BATCH LOSS: 0.026274453848600388
# BATCH NUM: 130
# BATCH LOSS: 0.4628151059150696
# BATCH NUM: 140
# BATCH LOSS: 0.2633220851421356
# BATCH NUM: 150
# BATCH LOSS: 0.0010076629696413875
# BATCH NUM: 160
# BATCH LOSS: 0.007621825207024813
# BATCH NUM: 170
# BATCH LOSS: 0.034218575805425644
# BATCH NUM: 180
# BATCH LOSS: 0.022783713415265083
# BATCH NUM: 190
# BATCH LOSS: 0.05956069752573967
# BATCH NUM: 200
# BATCH LOSS: 0.36474305391311646
# BATCH NUM: 210
# BATCH LOSS: 0.006584978196769953
# BATCH NUM: 220
# BATCH LOSS: 0.00700752530246973
# BATCH NUM: 230
# BATCH LOSS: 0.00032600475242361426
# BATCH NUM: 240
# BATCH LOSS: 0.9330610036849976
# BATCH NUM: 250
# BATCH LOSS: 0.4618498384952545
# BATCH NUM: 260
# BATCH LOSS: 0.005445909686386585
# BATCH NUM: 270
# BATCH LOSS: 0.01100020483136177
# BATCH NUM: 280
# BATCH LOSS: 0.016385890543460846
# BATCH NUM: 290
# BATCH LOSS: 0.007504330947995186
# BATCH NUM: 300
# BATCH LOSS: 0.5220955014228821
# BATCH NUM: 310
# BATCH LOSS: 0.00043167758849449456
# BATCH NUM: 320
# BATCH LOSS: 0.205506831407547
# BATCH NUM: 330
# BATCH LOSS: 0.0063864244148135185
# BATCH NUM: 340
# BATCH LOSS: 0.002007891424000263
# BATCH NUM: 350
# BATCH LOSS: 0.12309397757053375
# BATCH NUM: 360
# BATCH LOSS: 0.00036933328374288976
# BATCH NUM: 370
# BATCH LOSS: 0.2022639662027359
# BATCH NUM: 380
# BATCH LOSS: 0.005028367042541504
# BATCH NUM: 390
# BATCH LOSS: 0.23474907875061035
# BATCH NUM: 400
# BATCH LOSS: 0.19409145414829254
# BATCH NUM: 410
# BATCH LOSS: 0.0016791693633422256
# BATCH NUM: 420
# BATCH LOSS: 0.0030803775880485773
# BATCH NUM: 430
# BATCH LOSS: 0.12815876305103302
# BATCH NUM: 440
# BATCH LOSS: 0.6944177746772766
# BATCH NUM: 450
# BATCH LOSS: 0.005849007051438093
# EPOCH:  34
# LOSS:  0.12695570268259163
# TRAIN ACC:  0.9603658536585366
# EPOCH:  34
# LOSS:  2.8071778140416344
# VALID ACC:  0.815
# BATCH NUM: 0
# BATCH LOSS: 0.05166665092110634
# BATCH NUM: 10
# BATCH LOSS: 0.36694276332855225
# BATCH NUM: 20
# BATCH LOSS: 0.05354539304971695
# BATCH NUM: 30
# BATCH LOSS: 0.26861393451690674
# BATCH NUM: 40
# BATCH LOSS: 0.038683462888002396
# BATCH NUM: 50
# BATCH LOSS: 0.0020873798057436943
# BATCH NUM: 60
# BATCH LOSS: 0.0010059827473014593
# BATCH NUM: 70
# BATCH LOSS: 0.0023402234073728323
# BATCH NUM: 80
# BATCH LOSS: 0.0019566952250897884
# BATCH NUM: 90
# BATCH LOSS: 0.07250435650348663
# BATCH NUM: 100
# BATCH LOSS: 0.014899116940796375
# BATCH NUM: 110
# BATCH LOSS: 0.10024191439151764
# BATCH NUM: 120
# BATCH LOSS: 0.0008309201803058386
# BATCH NUM: 130
# BATCH LOSS: 0.033028725534677505
# BATCH NUM: 140
# BATCH LOSS: 0.06713882833719254
# BATCH NUM: 150
# BATCH LOSS: 0.05594133213162422
# BATCH NUM: 160
# BATCH LOSS: 0.8490928411483765
# BATCH NUM: 170
# BATCH LOSS: 0.02482503466308117
# BATCH NUM: 180
# BATCH LOSS: 0.22044064104557037
# BATCH NUM: 190
# BATCH LOSS: 0.021108636632561684
# BATCH NUM: 200
# BATCH LOSS: 1.679160714149475
# BATCH NUM: 210
# BATCH LOSS: 0.0004285761096980423
# BATCH NUM: 220
# BATCH LOSS: 0.004035136196762323
# BATCH NUM: 230
# BATCH LOSS: 0.23490436375141144
# BATCH NUM: 240
# BATCH LOSS: 0.5270694494247437
# BATCH NUM: 250
# BATCH LOSS: 0.024274596944451332
# BATCH NUM: 260
# BATCH LOSS: 0.15519553422927856
# BATCH NUM: 270
# BATCH LOSS: 0.01077056024223566
# BATCH NUM: 280
# BATCH LOSS: 0.0004482356598600745
# BATCH NUM: 290
# BATCH LOSS: 0.0007867052336223423
# BATCH NUM: 300
# BATCH LOSS: 0.005151497200131416
# BATCH NUM: 310
# BATCH LOSS: 0.08201881498098373
# BATCH NUM: 320
# BATCH LOSS: 0.004677537363022566
# BATCH NUM: 330
# BATCH LOSS: 0.25057879090309143
# BATCH NUM: 340
# BATCH LOSS: 0.04345410317182541
# BATCH NUM: 350
# BATCH LOSS: 0.00040929697570391
# BATCH NUM: 360
# BATCH LOSS: 0.0005826062988489866
# BATCH NUM: 370
# BATCH LOSS: 0.1942487508058548
# BATCH NUM: 380
# BATCH LOSS: 0.04819729924201965
# BATCH NUM: 390
# BATCH LOSS: 0.0020068767480552197
# BATCH NUM: 400
# BATCH LOSS: 0.08040919899940491
# BATCH NUM: 410
# BATCH LOSS: 0.030614735558629036
# BATCH NUM: 420
# BATCH LOSS: 0.08653261512517929
# BATCH NUM: 430
# BATCH LOSS: 0.0014937128871679306
# BATCH NUM: 440
# BATCH LOSS: 1.3304692506790161
# BATCH NUM: 450
# BATCH LOSS: 0.043420396745204926
# EPOCH:  35
# LOSS:  0.1369495038826062
# TRAIN ACC:  0.9598115299334812
# EPOCH:  35
# LOSS:  2.9058737404292327
# VALID ACC:  0.8083333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.029565155506134033
# BATCH NUM: 10
# BATCH LOSS: 0.037708133459091187
# BATCH NUM: 20
# BATCH LOSS: 0.01535045262426138
# BATCH NUM: 30
# BATCH LOSS: 0.004700277931988239
# BATCH NUM: 40
# BATCH LOSS: 0.06680526584386826
# BATCH NUM: 50
# BATCH LOSS: 0.8069546222686768
# BATCH NUM: 60
# BATCH LOSS: 0.12375952303409576
# BATCH NUM: 70
# BATCH LOSS: 0.09290121495723724
# BATCH NUM: 80
# BATCH LOSS: 0.9073898196220398
# BATCH NUM: 90
# BATCH LOSS: 0.19763478636741638
# BATCH NUM: 100
# BATCH LOSS: 0.20317846536636353
# BATCH NUM: 110
# BATCH LOSS: 0.3382861912250519
# BATCH NUM: 120
# BATCH LOSS: 0.021589243784546852
# BATCH NUM: 130
# BATCH LOSS: 0.0009879159042611718
# BATCH NUM: 140
# BATCH LOSS: 0.007667869329452515
# BATCH NUM: 150
# BATCH LOSS: 0.008681908249855042
# BATCH NUM: 160
# BATCH LOSS: 0.008948640897870064
# BATCH NUM: 170
# BATCH LOSS: 0.002833253238350153
# BATCH NUM: 180
# BATCH LOSS: 0.07032749056816101
# BATCH NUM: 190
# BATCH LOSS: 0.004227907862514257
# BATCH NUM: 200
# BATCH LOSS: 0.003656478598713875
# BATCH NUM: 210
# BATCH LOSS: 0.8150540590286255
# BATCH NUM: 220
# BATCH LOSS: 0.0035282722674310207
# BATCH NUM: 230
# BATCH LOSS: 0.0011954151559621096
# BATCH NUM: 240
# BATCH LOSS: 0.03439267352223396
# BATCH NUM: 250
# BATCH LOSS: 0.2474983036518097
# BATCH NUM: 260
# BATCH LOSS: 0.0039507681503891945
# BATCH NUM: 270
# BATCH LOSS: 0.7387150526046753
# BATCH NUM: 280
# BATCH LOSS: 0.2973669469356537
# BATCH NUM: 290
# BATCH LOSS: 0.0031830272637307644
# BATCH NUM: 300
# BATCH LOSS: 0.14787916839122772
# BATCH NUM: 310
# BATCH LOSS: 0.286948561668396
# BATCH NUM: 320
# BATCH LOSS: 1.1030786037445068
# BATCH NUM: 330
# BATCH LOSS: 0.2781832218170166
# BATCH NUM: 340
# BATCH LOSS: 0.24986989796161652
# BATCH NUM: 350
# BATCH LOSS: 0.000589780043810606
# BATCH NUM: 360
# BATCH LOSS: 0.2715044915676117
# BATCH NUM: 370
# BATCH LOSS: 0.08741432428359985
# BATCH NUM: 380
# BATCH LOSS: 0.002941648242995143
# BATCH NUM: 390
# BATCH LOSS: 0.1171160638332367
# BATCH NUM: 400
# BATCH LOSS: 0.35322704911231995
# BATCH NUM: 410
# BATCH LOSS: 0.052520982921123505
# BATCH NUM: 420
# BATCH LOSS: 0.019344240427017212
# BATCH NUM: 430
# BATCH LOSS: 0.0015339883975684643
# BATCH NUM: 440
# BATCH LOSS: 0.00022243859712034464
# BATCH NUM: 450
# BATCH LOSS: 0.8805342316627502
# EPOCH:  36
# LOSS:  0.15986457955970157
# TRAIN ACC:  0.9564855875831486
# EPOCH:  36
# LOSS:  2.8005176316255054
# VALID ACC:  0.8091666666666667
# BATCH NUM: 0
# BATCH LOSS: 0.22382709383964539
# BATCH NUM: 10
# BATCH LOSS: 0.07034384459257126
# BATCH NUM: 20
# BATCH LOSS: 0.0020496128126978874
# BATCH NUM: 30
# BATCH LOSS: 0.0013878033496439457
# BATCH NUM: 40
# BATCH LOSS: 0.05113217979669571
# BATCH NUM: 50
# BATCH LOSS: 0.07195336371660233
# BATCH NUM: 60
# BATCH LOSS: 0.004182770382612944
# BATCH NUM: 70
# BATCH LOSS: 0.0036066549364477396
# BATCH NUM: 80
# BATCH LOSS: 0.011156762950122356
# BATCH NUM: 90
# BATCH LOSS: 0.00039890228072181344
# BATCH NUM: 100
# BATCH LOSS: 0.3515896201133728
# BATCH NUM: 110
# BATCH LOSS: 0.3365304172039032
# BATCH NUM: 120
# BATCH LOSS: 0.20709450542926788
# BATCH NUM: 130
# BATCH LOSS: 0.007173648104071617
# BATCH NUM: 140
# BATCH LOSS: 0.0014804241945967078
# BATCH NUM: 150
# BATCH LOSS: 0.052272453904151917
# BATCH NUM: 160
# BATCH LOSS: 0.0002877080696634948
# BATCH NUM: 170
# BATCH LOSS: 0.004025925882160664
# BATCH NUM: 180
# BATCH LOSS: 0.028329771012067795
# BATCH NUM: 190
# BATCH LOSS: 0.09240441769361496
# BATCH NUM: 200
# BATCH LOSS: 0.005556419957429171
# BATCH NUM: 210
# BATCH LOSS: 0.005397641099989414
# BATCH NUM: 220
# BATCH LOSS: 0.011621857061982155
# BATCH NUM: 230
# BATCH LOSS: 0.610842764377594
# BATCH NUM: 240
# BATCH LOSS: 0.002407357096672058
# BATCH NUM: 250
# BATCH LOSS: 0.0019938454497605562
# BATCH NUM: 260
# BATCH LOSS: 0.0023342163767665625
# BATCH NUM: 270
# BATCH LOSS: 0.8356367349624634
# BATCH NUM: 280
# BATCH LOSS: 0.0009032040252350271
# BATCH NUM: 290
# BATCH LOSS: 0.0944480448961258
# BATCH NUM: 300
# BATCH LOSS: 0.009836267679929733
# BATCH NUM: 310
# BATCH LOSS: 0.0026778930332511663
# BATCH NUM: 320
# BATCH LOSS: 0.007305265869945288
# BATCH NUM: 330
# BATCH LOSS: 0.13375797867774963
# BATCH NUM: 340
# BATCH LOSS: 0.0009574875584803522
# BATCH NUM: 350
# BATCH LOSS: 0.001548032509163022
# BATCH NUM: 360
# BATCH LOSS: 0.00010298119013896212
# BATCH NUM: 370
# BATCH LOSS: 0.0030943250749260187
# BATCH NUM: 380
# BATCH LOSS: 0.0978950709104538
# BATCH NUM: 390
# BATCH LOSS: 0.009695117361843586
# BATCH NUM: 400
# BATCH LOSS: 0.0002693874412216246
# BATCH NUM: 410
# BATCH LOSS: 0.7779384255409241
# BATCH NUM: 420
# BATCH LOSS: 0.011576415039598942
# BATCH NUM: 430
# BATCH LOSS: 0.009225886315107346
# BATCH NUM: 440
# BATCH LOSS: 0.37581154704093933
# BATCH NUM: 450
# BATCH LOSS: 0.1749500334262848
# EPOCH:  37
# LOSS:  0.11282683948832326
# TRAIN ACC:  0.9664634146341463
# Epoch    38: reducing learning rate of group 0 to 5.0000e-04.
# EPOCH:  37
# LOSS:  2.9600614230738413
# VALID ACC:  0.8108333333333333
# BATCH NUM: 0
# BATCH LOSS: 0.0005920930416323245
# BATCH NUM: 10
# BATCH LOSS: 0.021231060847640038
# BATCH NUM: 20
# BATCH LOSS: 0.00014343767543323338
# BATCH NUM: 30
# BATCH LOSS: 0.0005619300063699484
# BATCH NUM: 40
# BATCH LOSS: 0.0008506958256475627
# BATCH NUM: 50
# BATCH LOSS: 0.02817116118967533
# BATCH NUM: 60
# BATCH LOSS: 0.0018046721816062927
# BATCH NUM: 70
# BATCH LOSS: 0.0037060489412397146
# BATCH NUM: 80
# BATCH LOSS: 0.09112408757209778
# BATCH NUM: 90
# BATCH LOSS: 0.2875064015388489
# BATCH NUM: 100
# BATCH LOSS: 0.00844365730881691
# BATCH NUM: 110
# BATCH LOSS: 0.00025963157531805336
# BATCH NUM: 120
# BATCH LOSS: 5.88585908189998e-06
# BATCH NUM: 130
# BATCH LOSS: 0.00820381660014391
# BATCH NUM: 140
# BATCH LOSS: 0.5081974864006042
# BATCH NUM: 150
# BATCH LOSS: 0.011220524087548256
# BATCH NUM: 160
# BATCH LOSS: 0.002617147285491228
# BATCH NUM: 170
# BATCH LOSS: 0.005927748046815395
# BATCH NUM: 180
# BATCH LOSS: 0.26240864396095276
# BATCH NUM: 190
# BATCH LOSS: 0.08165481686592102
# BATCH NUM: 200
# BATCH LOSS: 0.005017509683966637
# BATCH NUM: 210
# BATCH LOSS: 0.0004840334295295179
# BATCH NUM: 220
# BATCH LOSS: 0.0639737918972969
# BATCH NUM: 230
# BATCH LOSS: 0.004294002428650856
# BATCH NUM: 240
# BATCH LOSS: 0.0011168619384989142
# BATCH NUM: 250
# BATCH LOSS: 1.054908037185669
# BATCH NUM: 260
# BATCH LOSS: 0.002986764535307884
# BATCH NUM: 270
# BATCH LOSS: 0.3994011878967285
# BATCH NUM: 280
# BATCH LOSS: 0.006577507592737675
# BATCH NUM: 290
# BATCH LOSS: 0.008826607838273048
# BATCH NUM: 300
# BATCH LOSS: 0.00022793575772084296
# BATCH NUM: 310
# BATCH LOSS: 0.0023702378384768963
# BATCH NUM: 320
# BATCH LOSS: 0.0045722657814621925
# BATCH NUM: 330
# BATCH LOSS: 0.06224984675645828
# BATCH NUM: 340
# BATCH LOSS: 0.6023860573768616
# BATCH NUM: 350
# BATCH LOSS: 0.027615651488304138
# BATCH NUM: 360
# BATCH LOSS: 0.00045706136734224856
# BATCH NUM: 370
# BATCH LOSS: 0.007571081165224314
# BATCH NUM: 380
# BATCH LOSS: 0.003087483812123537
# BATCH NUM: 390
# BATCH LOSS: 0.015187014825642109
# BATCH NUM: 400
# BATCH LOSS: 0.0008427418069913983
# BATCH NUM: 410
# BATCH LOSS: 0.48240330815315247
# BATCH NUM: 420
# BATCH LOSS: 0.060581106692552567
# BATCH NUM: 430
# BATCH LOSS: 0.022751107811927795
# BATCH NUM: 440
# BATCH LOSS: 0.00032461719820275903
# BATCH NUM: 450
# BATCH LOSS: 1.8775405123960809e-06
# EPOCH:  38
# LOSS:  0.09770896167355027
# TRAIN ACC:  0.9722838137472284
# EPOCH:  38
# LOSS:  2.9242307190975736
# VALID ACC:  0.81
# BATCH NUM: 0
# BATCH LOSS: 0.0009614261798560619
# BATCH NUM: 10
# BATCH LOSS: 0.05749531835317612
# BATCH NUM: 20
# BATCH LOSS: 0.00862821377813816
# BATCH NUM: 30
# BATCH LOSS: 0.000649644760414958
# BATCH NUM: 40
# BATCH LOSS: 0.009570131078362465
# BATCH NUM: 50
# BATCH LOSS: 0.0018673992017284036
# BATCH NUM: 60
# BATCH LOSS: 0.004006031900644302
# BATCH NUM: 70
# BATCH LOSS: 0.00021257132175378501
# BATCH NUM: 80
# BATCH LOSS: 0.015126112848520279
# BATCH NUM: 90
# BATCH LOSS: 0.00600992189720273
# BATCH NUM: 100
# BATCH LOSS: 0.003585472237318754
# BATCH NUM: 110
# BATCH LOSS: 0.006520457100123167
# BATCH NUM: 120
# BATCH LOSS: 0.07791437208652496
# BATCH NUM: 130
# BATCH LOSS: 0.002928170608356595
# BATCH NUM: 140
# BATCH LOSS: 0.13642267882823944
# BATCH NUM: 150
# BATCH LOSS: 0.003323522163555026
# BATCH NUM: 160
# BATCH LOSS: 0.0017966990126296878
# BATCH NUM: 170
# BATCH LOSS: 0.0011116864625364542
# BATCH NUM: 180
# BATCH LOSS: 0.0154562471434474
# BATCH NUM: 190
# BATCH LOSS: 0.34020593762397766
# BATCH NUM: 200
# BATCH LOSS: 0.0040490212850272655
# BATCH NUM: 210
# BATCH LOSS: 0.00034534293808974326
# BATCH NUM: 220
# BATCH LOSS: 0.0410192534327507
# BATCH NUM: 230
# BATCH LOSS: 0.04599170386791229
# BATCH NUM: 240
# BATCH LOSS: 0.054754745215177536
# BATCH NUM: 250
# BATCH LOSS: 0.04621002823114395
# BATCH NUM: 260
# BATCH LOSS: 0.0035132255870848894
# BATCH NUM: 270
# BATCH LOSS: 0.018350549042224884
# BATCH NUM: 280
# BATCH LOSS: 0.27222421765327454
# BATCH NUM: 290
# BATCH LOSS: 0.031784333288669586
# BATCH NUM: 300
# BATCH LOSS: 0.003319994080811739
# BATCH NUM: 310
# BATCH LOSS: 0.0006152323330752552
# BATCH NUM: 320
# BATCH LOSS: 0.005149404983967543
# BATCH NUM: 330
# BATCH LOSS: 0.001457182806916535
# BATCH NUM: 340
# BATCH LOSS: 0.00795900821685791
# BATCH NUM: 350
# BATCH LOSS: 0.0010422044433653355
# BATCH NUM: 360
# BATCH LOSS: 0.0014515776420012116
# BATCH NUM: 370
# BATCH LOSS: 0.3527851700782776
# BATCH NUM: 380
# BATCH LOSS: 0.0051497360691428185
# BATCH NUM: 390
# BATCH LOSS: 0.15676568448543549
# BATCH NUM: 400
# BATCH LOSS: 0.007422632072120905
# BATCH NUM: 410
# BATCH LOSS: 0.36233603954315186
# BATCH NUM: 420
# BATCH LOSS: 0.0199525598436594
# BATCH NUM: 430
# BATCH LOSS: 0.0016582803800702095
# BATCH NUM: 440
# BATCH LOSS: 0.020088713616132736
# BATCH NUM: 450
# BATCH LOSS: 0.7157698273658752
# EPOCH:  39
# LOSS:  0.06842994633462796
# TRAIN ACC:  0.9800443458980045
# EPOCH:  39
# LOSS:  2.938900845186431
# VALID ACC:  0.8133333333333334

# %%
network.eval()
correct = 0.0
total = 0.0
with torch.no_grad():
  for batch_num, (x, y, x_len) in enumerate(test_loader):
      y = torch.Tensor(y)
      x, y = x.to(device), y.to(device)
      out = network(x, x_len, 'test')
      loss = criterion(out, y.long())
      avg_loss += loss.item()
      pred = torch.argmax(out, dim = 1).cpu().numpy()
      true = y.cpu().numpy()
      correct += np.sum(pred == true)
      total += batch_size
print(correct/total)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 0.9056291390728477
